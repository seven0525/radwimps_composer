# %%
text = open("rad_code.txt","r").read()

# %%
text
# Out:
# 'D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,Bm,A,D,G,Bm,A,D,Bm,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,G,A,Bm,D,G,A,Bm,Bm,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm,D,G,A,Bm.\n\nG,C,G,C,G,D,Em,C,G,D,Em,C,G,D,Em,C,G,D,Em,C,G,D,Em,C,G,D,C,D,G,C,D,Em,G,C,D,G,Em,D,C,G,Em,D,C,D,G,C,G,C,G,D,Em,C,G,D,Em,G,D,Em,C,G,D,Em,C,G,D,Em,C,G,D,Em,C,G,D,Em,C,G,D,Em,C,D,G,C,D,Em,G,C,D,G,Em,D,C,G,Em,D,C,D,Em,C,D,G,Em,C,D,G,Em,C,D,G,Em,C,D,A,F.\n\n\nEm,D,C,G,Em,Bm,C,D,G,Em,D,C,G,Em,Bm,C,D,G,Em,D,C,G,Em,D,C,D,G,Em,D,C,G,Em,Bm,C,D,G,Em,D,C,G,Em,Bm,C,D,G,Em,D,C,G,Em,Bm,C,D,G,C,D,G,Em,C,D,Em,C,D,G,Em,Am,Bm,Em,D,C,D,Em,D,C,G,Em,Bm,C,D,G,Em,D,C,G,Em,Bm,C,D,G,Em,D,C,D,Em,Bm,C,D,G,C,D,G,Em,C,D,Em,Bm,C,D,G,Em,Am,Bm,Em,D,C,D,Em,D,C,G,Em,Bm,C,D,G,Em,D,C,G,Em,Bm,C,D,G,Em,C,D,Em,C,D,G,Em,C,D,EmC,D,G,Em,C,D,C,D,C,D,Am,Bm,Em,D,C,D,Em,D,G,Em,D,G,,Em,D,G,,Em,D,G.\n\n\nC,C/F,C,C/A,C,C/F,C,C,C/F,C,C/A,C,C/F,C,C,C/F,C,C/A,C,C/F,C,C/A,C/F,C,C/A,C/A,C/F,C,C/A,C,C/F,C,C,C,C,C,C,C/A,C/F,C,C,C/F,C,C/A,C/F,C,C,C/F,C,C/A,C/F,C,C/A,C/F,C,C,C/F,C,C/A,C,C/F,C,C,C/F,C,C/A,C,C/F,C,C/A,C/F,C,C,C/F,C/D,C,C/F,C,C/A,C/F,C,C,C/F,C,C,C/F,C,Am,C,C/F,C,C/D,C/F,C/A,C,C,C,C/A,C/F,C,C/F,C,C/A,C/F,C,C,C/F,C,C,C,C,C/F.\n\n\nF,C,G,Am7,F,C,G,C,F,C,G,Am7,F,C,F,G,C,F,C,F,C,F,C,G,Am7,C,F,C,F,C,F,C,F,G,C,Am7,F,C,G,Am7,F,G,F,C,G,Am7,F,C,G,Am7,F,C,G,Am7,F,C,F,G,C,C,F,G,C,F,C,F,C,F,C,G,Am,C,F,C,F,CF,C,F,G,C,C#,D#,C#,D#,C,C,G,Am7,F,C,G,F,G,C,G,F,G,Am7,F,G,G,F,C,G,Am7,F,C,G,Am7,F,C,G,Am7,F,C,G,C,F,C,G,Am7,F,C,G,Am7,F,C,G,Am7,F,C,F,G,C,C.\n\n\nG,A,D,G,A,D,G,A,D,Bm,G,A,D,G,A,D,G,A,D,G,A,D,G,A,D,G,A,D,Bm,G,A,D,G,A,D,G,A,D,G,A,D,G,A,D,G,A,D,Bm,G,A,D,G,A,D,Bm,G,A,D,G,A,D,D,D,D,D,G,D,G,A,D,Bm,G,A,D,D,G,A,D,Bm,G,A,D,D,G,A,D,Bm,G,A,D,D,G,A,D,Bm,G,A,D,D,G,A,D,Bm,G,A,D,Bm,G,D,D,G,A,D.\n\n\nA,Aaug,A,Aaug,F,E,D,E,A,A,F,E,B,A,D,E,Dm,F,A,D,E,E,A,G,F,E,F,A/B,A,D,E,A,Aaug,A,Aaug,F,E,D,E,A,A,F,B,A,E,Dm,F,A,D,E,E,A,G,F,E,F,A/B,A,D,E,E,A,A/D,E,E,A,A/D,E,A,A,A/D,E,F,A,A/D,E,A,Asus4,A,Aaug,A,Asus4,A,Aaug,A,Aaug,A,Aaug,F,E,D,E,A,A,F,E,B,A,E,F,F,D,E,A,G,F,E,F,A/B,A,D,E,E,A,A/D,E,F,A,A/D,E,A,A,A/D,E,F,A,A/D,E,D,A,A/B,F,D,A,F,E,A,F,F6,A,D,A,D,A,D,A,D,A,D,A,D,A,D,A,D,A,A/D,A,A/D,A,A/D,A,Aaug,A,Asus4,A,Asus4,A,Asus4,A,Asus4,A,Asus4,A,Asus4,A,Asus4,A.\n\n\nBm,A,G,D,Bm,A,G,D,Bm,A,G,D,Bm,A,G,D,Bm,A,G,D,Bm,A,G,D,Bm,G,A,Bm,Bm,G,D,D,G,A,BmEm7,Gm7,G,D,G,A,Bm,G,A,D,C,Gm7,G,A,Bm,G,A,G,A,Bm,A/C,D,Gm,G,G,A,Bm,A/C,D,E,G,Bm,A,G,D,Bm,Gm,G,D,Bm,A,G,D,Bm,Gm7,G,D,Bm,A,G,D,Bm,A,G,D,Bm,Gm7,G,D,Bm,A,G,D,Bm,Gm7,G,D,D/G,G,A,Bm,D/G,G,D,D/G,G,A,Bm,Em7,Gm7,G,D,G,A,Bm,G,A,C,D,E,D,Cm7,Bm7,A,D,Cm7,Bm7,A,D,Cm7,Bm7,A,D,Cm7,Bm7,E,D,E,Gm,E/G,A,Cm7,D,D,E,Gm,E/G,A,Cm7,D,G,A,G,A,Bm,G,A,D,C,Gm7,G,A,Bm,G,G#,A#,Cm,G#,A#,D#,C#,Am7,G#,A#,Cm,G#,A#,Cm,G#,A#,D#,C#,Am7,G#,A#,Cm,G#,A#,Cm,G#,A#,D#,C#,Am7,G#,A#,Cm,G#,A#,G#,A#,Cm,A/D,D#,Fm,Gm,G#.\n\n\nBm,F#m,G,A,Bm,F#m,G,G/A,Bm,Asus4,G,D,Bm,Asus4,G,G/A,D,Asus4,Bm7,Em7,D,Asus4,Bm,G,Asus4,G,D,G,D,G,A,A,Bm,Em7,F,G,A,G,D,G,D,G,A,A,Bm,Em7,F,G,A,G,D,G,D,G,D,G,D,Bm,A,G,D,Bm,A,G,D,Asus4,Bm,Asus4,G,D,Bm,Asus4,G,G/A,D,Asus4,Bm7,Em7,D,Asus4,Bm,G,Asus4,G,D,G,D,G,A,A,Bm,Em7,F,G,A,G,D,G,D,G,A,A,Bm,Em7,F,G,A,A#,Dm7,C,Dm7,C,Dm7,C,Dm7,C,A7,Am,C,A7,F,C,D,G,D,G,D,G,D,A,Asus4,A,G,D,G,D,G,D,A,Asus4,A,Asus4,A,Bm7,Em7,F,A,Bm,G,A,G,D,G,D,G,AA,B,Em7,G,AG,D,G,D,G,A,A,Bm,Em7,F,G,A,G,D,G,D,G,A,A,Bm,Em7,F,G,A,G,D,Asus4,Bm7,G,D,Asus4.\n\n\nEm,D,A,C,D,Em7,Em,G,D,C,D,Em7,Em,D,A,C,D,Em7,Em,G,D,C,D.F#sys4,F#,Bm,A,E,F#,G,A,D,C#,F#m,G,A,Bm,G,A,Em,G,D,Em,G,D,,Em,G,D,,Em,G,D,,Em,G,D,A,Bm,Em,D,C,Bm,,Em,D,C,D,Em,D,A,C,D,Em7,Em,G,A,C,D,F#sus4,F#,Bm,A,E,F#,G,A,D,C#,F#m,E,Bm,C#,D,E,F#sus4,F#,G,Em,F#sus4,F#,G,A,Bm,A,E,F#,G,A,D,C#,F#m,G,A,Bm,G,A,F#,Bm,A,E,F#,G,A,D,C#,F#m,G,A,Bm,G,A.'

# %%
import re

# %%
#text = list(text)

# %%
type(text)
# Out:
# str

# %%
text = text.replace(","," ")

# %%
text
# Out:
# 'D G A Bm D G A Bm D G A Bm D G A Bm D G A Bm D G A Bm D G A Bm D G A Bm D G A Bm D G A Bm D G A Bm D G A Bm D G A Bm D G A Bm D G A Bm D G A Bm D G A Bm D G A Bm D G A Bm D G A Bm D G A Bm D G A Bm D G A Bm D G A Bm D G A Bm D G A Bm D G A Bm D G A Bm D G A Bm D G A Bm D G Bm A D G Bm A D Bm G A Bm D G A Bm D G A Bm D G A Bm D G A Bm D G A Bm D G A Bm D G A Bm D G A Bm D G A Bm D G A Bm D G A Bm D G A Bm G A Bm D G A Bm Bm G A Bm D G A Bm D G A Bm D G A Bm D G A Bm D G A Bm D G A Bm.\n\nG C G C G D Em C G D Em C G D Em C G D Em C G D Em C G D C D G C D Em G C D G Em D C G Em D C D G C G C G D Em C G D Em G D Em C G D Em C G D Em C G D Em C G D Em C G D Em C D G C D Em G C D G Em D C G Em D C D Em C D G Em C D G Em C D G Em C D A F.\n\n\nEm D C G Em Bm C D G Em D C G Em Bm C D G Em D C G Em D C D G Em D C G Em Bm C D G Em D C G Em Bm C D G Em D C G Em Bm C D G C D G Em C D Em C D G Em Am Bm Em D C D Em D C G Em Bm C D G Em D C G Em Bm C D G Em D C D Em Bm C D G C D G Em C D Em Bm C D G Em Am Bm Em D C D Em D C G Em Bm C D G Em D C G Em Bm C D G Em C D Em C D G Em C D EmC D G Em C D C D C D Am Bm Em D C D Em D G Em D G  Em D G  Em D G.\n\n\nC C/F C C/A C C/F C C C/F C C/A C C/F C C C/F C C/A C C/F C C/A C/F C C/A C/A C/F C C/A C C/F C C C C C C C/A C/F C C C/F C C/A C/F C C C/F C C/A C/F C C/A C/F C C C/F C C/A C C/F C C C/F C C/A C C/F C C/A C/F C C C/F C/D C C/F C C/A C/F C C C/F C C C/F C Am C C/F C C/D C/F C/A C C C C/A C/F C C/F C C/A C/F C C C/F C C C C C/F.\n\n\nF C G Am7 F C G C F C G Am7 F C F G C F C F C F C G Am7 C F C F C F C F G C Am7 F C G Am7 F G F C G Am7 F C G Am7 F C G Am7 F C F G C C F G C F C F C F C G Am C F C F CF C F G C C# D# C# D# C C G Am7 F C G F G C G F G Am7 F G G F C G Am7 F C G Am7 F C G Am7 F C G C F C G Am7 F C G Am7 F C G Am7 F C F G C C.\n\n\nG A D G A D G A D Bm G A D G A D G A D G A D G A D G A D Bm G A D G A D G A D G A D G A D G A D Bm G A D G A D Bm G A D G A D D D D D G D G A D Bm G A D D G A D Bm G A D D G A D Bm G A D D G A D Bm G A D D G A D Bm G A D Bm G D D G A D.\n\n\nA Aaug A Aaug F E D E A A F E B A D E Dm F A D E E A G F E F A/B A D E A Aaug A Aaug F E D E A A F B A E Dm F A D E E A G F E F A/B A D E E A A/D E E A A/D E A A A/D E F A A/D E A Asus4 A Aaug A Asus4 A Aaug A Aaug A Aaug F E D E A A F E B A E F F D E A G F E F A/B A D E E A A/D E F A A/D E A A A/D E F A A/D E D A A/B F D A F E A F F6 A D A D A D A D A D A D A D A D A A/D A A/D A A/D A Aaug A Asus4 A Asus4 A Asus4 A Asus4 A Asus4 A Asus4 A Asus4 A.\n\n\nBm A G D Bm A G D Bm A G D Bm A G D Bm A G D Bm A G D Bm G A Bm Bm G D D G A BmEm7 Gm7 G D G A Bm G A D C Gm7 G A Bm G A G A Bm A/C D Gm G G A Bm A/C D E G Bm A G D Bm Gm G D Bm A G D Bm Gm7 G D Bm A G D Bm A G D Bm Gm7 G D Bm A G D Bm Gm7 G D D/G G A Bm D/G G D D/G G A Bm Em7 Gm7 G D G A Bm G A C D E D Cm7 Bm7 A D Cm7 Bm7 A D Cm7 Bm7 A D Cm7 Bm7 E D E Gm E/G A Cm7 D D E Gm E/G A Cm7 D G A G A Bm G A D C Gm7 G A Bm G G# A# Cm G# A# D# C# Am7 G# A# Cm G# A# Cm G# A# D# C# Am7 G# A# Cm G# A# Cm G# A# D# C# Am7 G# A# Cm G# A# G# A# Cm A/D D# Fm Gm G#.\n\n\nBm F#m G A Bm F#m G G/A Bm Asus4 G D Bm Asus4 G G/A D Asus4 Bm7 Em7 D Asus4 Bm G Asus4 G D G D G A A Bm Em7 F G A G D G D G A A Bm Em7 F G A G D G D G D G D Bm A G D Bm A G D Asus4 Bm Asus4 G D Bm Asus4 G G/A D Asus4 Bm7 Em7 D Asus4 Bm G Asus4 G D G D G A A Bm Em7 F G A G D G D G A A Bm Em7 F G A A# Dm7 C Dm7 C Dm7 C Dm7 C A7 Am C A7 F C D G D G D G D A Asus4 A G D G D G D A Asus4 A Asus4 A Bm7 Em7 F A Bm G A G D G D G AA B Em7 G AG D G D G A A Bm Em7 F G A G D G D G A A Bm Em7 F G A G D Asus4 Bm7 G D Asus4.\n\n\nEm D A C D Em7 Em G D C D Em7 Em D A C D Em7 Em G D C D.F#sys4 F# Bm A E F# G A D C# F#m G A Bm G A Em G D Em G D  Em G D  Em G D  Em G D A Bm Em D C Bm  Em D C D Em D A C D Em7 Em G A C D F#sus4 F# Bm A E F# G A D C# F#m E Bm C# D E F#sus4 F# G Em F#sus4 F# G A Bm A E F# G A D C# F#m G A Bm G A F# Bm A E F# G A D C# F#m G A Bm G A.'

# %%
text = text.split(\n)
# Out:
#   File "<ipython-input-26-ac0400cabbf5>", line 1
#     text = text.split(\n)
#                          ^
# SyntaxError: unexpected character after line continuation character

# %%
#夏目漱石のやつ

# %%
# https://github.com/fchollet/keras/blob/master/examples/lstm_text_generation.py

from __future__ import print_function
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys

# path = get_file('nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
# path = "souseki.txt"
# text = open(path).read().lower()
# print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

print('Vectorization...')
X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1

# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)


def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# train the model, output generated text after each iteration
for iteration in range(1, 10):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    model.fit(X, y,
              # batch_size=128,
              batch_size=512,
              epochs=1)

    start_index = random.randint(0, len(text) - maxlen - 1)

    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print()
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(40):
            x = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x[0, t, char_indices[char]] = 1.

            preds = model.predict(x, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()

            print()
# Out:
# total chars: 21
# nb sequences: 1285
# Vectorization...
# Build model...
#
# --------------------------------------------------
# Iteration 1
# Epoch 1/1
# 1285/1285 [==============================] - 2s 2ms/step - loss: 3.2647
#
# ----- diversity: 0.2
# ----- Generating with seed: "Bm D G A Bm D G A Bm D G A Bm D G A Bm D"
# Bm D G A Bm D G A Bm D G A Bm D G A Bm D
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "Bm D G A Bm D G A Bm D G A Bm D G A Bm D"
# Bm D G A Bm D G A Bm D G A Bm D G A Bm D
# G
#
#
#
#
#
#
# D
# C
#
# /
#
#
#
#
#
#
#
# D
#
#
#
#
#
#
#
#
#
#
# A
#
#
#
# #
#
#
#
#
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "Bm D G A Bm D G A Bm D G A Bm D G A Bm D"
# Bm D G A Bm D G A Bm D G A Bm D G A Bm DG
#
# C
#
# 4
# 4
# A
# g
# B
#
# G
# s
#
#
#
#
# G
#
#
# s
# G
# /
# E
#
# D
# C
#
# E
# D
# D
# G
# u
# G
# 4
#
#
#
# A
#
#
# A
#
# ----- diversity: 1.2
# ----- Generating with seed: "Bm D G A Bm D G A Bm D G A Bm D G A Bm D"
# Bm D G A Bm D G A Bm D G A Bm D G A Bm D4
# B
#
#
# u
# C
#
#
# D
# D
# #
#
#
# y
# 4
#
# G
# m
# a
# 7
# #
#
# D
# B
#
#
#
#
#
# 4
# m
#
# A
# A
# g
# m
# C
# C
# 7
#
# D
#
# --------------------------------------------------
# Iteration 2
# Epoch 1/1
# 1285/1285 [==============================] - 1s 1ms/step - loss: 2.2043
#
# ----- diversity: 0.2
# ----- Generating with seed: "F G C C F G C F C F C F C G Am C F C F C"
# F G C C F G C F C F C F C G Am C F C F C
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "F G C C F G C F C F C F C G Am C F C F C"
# F G C C F G C F C F C F C G Am C F C F C
#
#
#
#
#
# m
# m
#
#
# #
#
# A
#
#
#
#
#
# m
#
#
# m
#
#
#
#
# G
#
#
#
# m
#
#
#
# A
#
#
#
# D
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "F G C C F G C F C F C F C G Am C F C F C"
# F G C C F G C F C F C F C G Am C F C F C
# A
# A
#
# D
# B
# F
# F
# u
# C
# C
# 4
# D
# G
# D
#
# F
# C
# A
# G
# m
# D
# 7
# D
# C
#
# m
# C
# /
#
# E
# A
# s
#
# /
# A
#
#
#
# A
#
# ----- diversity: 1.2
# ----- Generating with seed: "F G C C F G C F C F C F C G Am C F C F C"
# F G C C F G C F C F C F C G Am C F C F CF
# D
#
# A
#
# m
#
# u
# G
#
# G
# C
# C
# C
#
# E
#
# F
# G
# C
# /
# 4
# E
#
# m
#
# m
#
# u
# C
# G
# A
# m
# u
# m
#
# F
#
# F
# D
#
# --------------------------------------------------
# Iteration 3
# Epoch 1/1
# 1285/1285 [==============================] - 1s 1ms/step - loss: 2.0806
#
# ----- diversity: 0.2
# ----- Generating with seed: "/F C C C/F C C/A C C/F C C/A C/F C C C/F"
# /F C C C/F C C/A C C/F C C/A C/F C C C/F
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "/F C C C/F C C/A C C/F C C/A C/F C C C/F"
# /F C C C/F C C/A C C/F C C/A C/F C C C/F
#
#
#
# A
#
#
#
#
#
#
#
#
#
# G
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# G
#
#
#
#
#
#
#
#
#
# G
#
# ----- diversity: 1.0
# ----- Generating with seed: "/F C C C/F C C/A C C/F C C/A C/F C C C/F"
# /F C C C/F C C/A C C/F C C/A C/F C C C/FF
# A
# G
#
#
# A
# C
#
# G
# G
#
# 7
# D
#
# G
#
# A
#
#
#
#
# /
# D
#
# F
# D
#
# G
# C
# 7
# .
#
#
# A
# A
# D
#
# D
# m
# C
# C
#
# ----- diversity: 1.2
# ----- Generating with seed: "/F C C C/F C C/A C C/F C C/A C/F C C C/F"
# /F C C C/F C C/A C C/F C C/A C/F C C C/F#
# 7
# C
#
#
#
#
#
# C
#
# /
# F
# E
# 7
# G
# C
#
#
# E
# G
# C
# A
# A
#
#
#
# C
#
# C
# C
# A
#
#
# A
# #
#
#
#
#
# 7
#
#
#
#
# --------------------------------------------------
# Iteration 4
# Epoch 1/1
# 1285/1285 [==============================] - 1s 1ms/step - loss: 2.0060
#
# ----- diversity: 0.2
# ----- Generating with seed: " Aaug A Asus4 A Asus4 A Asus4 A Asus4 A "
#  Aaug A Asus4 A Asus4 A Asus4 A Asus4 A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# m
#
#
#
#
#
#
#
#
#
#
#
#
# ----- diversity: 0.5
# ----- Generating with seed: " Aaug A Asus4 A Asus4 A Asus4 A Asus4 A "
#  Aaug A Asus4 A Asus4 A Asus4 A Asus4 A
#
# D
#
#
# m
#
#
#
#
# 7
# s
#
#
#
#
# D
#
# D
# C
# E
#
#
# m
#
# B
#
#
# m
#
# m
#
#
#
#
#
# m
# A
#
# G
#
# ----- diversity: 1.0
# ----- Generating with seed: " Aaug A Asus4 A Asus4 A Asus4 A Asus4 A "
#  Aaug A Asus4 A Asus4 A Asus4 A Asus4 A C
# /
# E
#
# m
# m
# #
#
# F
#
# s
# E
#
# E
# C
# A
# m
# G
# m
#
#
#
# C
#
# E
# m
# G
# B
# B
# u
# m
# m
# E
#
# A
# F
# D
# /
# E
# E
#
# ----- diversity: 1.2
# ----- Generating with seed: " Aaug A Asus4 A Asus4 A Asus4 A Asus4 A "
#  Aaug A Asus4 A Asus4 A Asus4 A Asus4 A u
#
# /
# A
# m
# B
#
# C
# s
#
# G
# m
# m
# A
# g
# m
#
#
# A
# s
#
#
#
# 4
# F
#
#
# /
# A
# m
# F
#
#
# E
# a
# A
# m
# /
# m
#
#
# --------------------------------------------------
# Iteration 5
# Epoch 1/1
# 1285/1285 [==============================] - 2s 1ms/step - loss: 1.8582
#
# ----- diversity: 0.2
# ----- Generating with seed: "F F D E A G F E F A/B A D E E A A/D E F "
# F F D E A G F E F A/B A D E E A A/D E F
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "F F D E A G F E F A/B A D E E A A/D E F "
# F F D E A G F E F A/B A D E E A A/D E F
#
#
#
#
#
#
# C
#
# C
#
#
#
# G
#
# G
#
# D
#
# G
#
#
#
#
#
# m
#
#
#
# A
#
#
#
#
#
# G
#
# G
#
# D
#
# ----- diversity: 1.0
# ----- Generating with seed: "F F D E A G F E F A/B A D E E A A/D E F "
# F F D E A G F E F A/B A D E E A A/D E F B
#
#
# 7
#
#
# /
# C
#
# C
#
# E
#
# G
# m
# 4
# m
#
#
# A
#
# m
#
# A
#
# C
# 4
# G
# C
# A
#
# G
#
# m
#
# /
#
#
# s
# D
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "F F D E A G F E F A/B A D E E A A/D E F "
# F F D E A G F E F A/B A D E E A A/D E F
# B
#
#
# F
# C
#
# G
# E
#
# /
# a
# /
# m
# D
#
# u
#
# G
# G
# F
# D
# m
# G
# A
#
# m
#
# G
# m
# #
#
# C
#
# G
# D
#
# a
# u
# C
#
# --------------------------------------------------
# Iteration 6
# Epoch 1/1
# 1285/1285 [==============================] - 1s 1ms/step - loss: 1.7124
#
# ----- diversity: 0.2
# ----- Generating with seed: "/A C/A C/F C C/A C C/F C C C C C C C/A C"
# /A C/A C/F C C/A C C/F C C C C C C C/A C
# C
#
# C
#
# C
#
# A
#
# A
#
# A
#
# A
#
# A
#
# C
#
# C
#
# C
#
# C
#
# A
#
# C
#
# C
#
# C
#
# C
#
# C
#
# C
#
# A
#
# ----- diversity: 0.5
# ----- Generating with seed: "/A C/A C/F C C/A C C/F C C C C C C C/A C"
# /A C/A C/F C C/A C C/F C C C C C C C/A C
# A
#
# D
#
# C
#
# A
#
# C
#
#
#
#
# C
#
# G
#
# A
#
# D
#
# G
#
# C
#
# A
#
# C
#
# A
#
# C
#
# G
#
# A
#
# A
# m
#
# ----- diversity: 1.0
# ----- Generating with seed: "/A C/A C/F C C/A C C/F C C C C C C C/A C"
# /A C/A C/F C C/A C C/F C C C C C C C/A C
# A
# #
# A
#
# G
# G
# A
# G
#
# C
#
# C
#
# F
#
# s
# m
#
# A
#
# A
#
# /
# C
# /
# D
#
# D
#
# #
# /
# E
#
#
# F
#
#
# F
# C
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "/A C/A C/F C C/A C C/F C C C C C C C/A C"
# /A C/A C/F C C/A C C/F C C C C C C C/A Cm
# D
# s
# A
# F
# /
#
# m
# A
# C
# A
#
#
# .
# u
# G
# D
#
# C
#
# C
#
# C
#
# G
#
# A
#
# E
# C
# F
#
# G
# C
#
# m
# m
# C
# C
# B
#
# --------------------------------------------------
# Iteration 7
# Epoch 1/1
# 1285/1285 [==============================] - 1s 982us/step - loss: 1.5938
#
# ----- diversity: 0.2
# ----- Generating with seed: " A Bm D G A Bm D G A Bm D G A Bm D G A B"
#  A Bm D G A Bm D G A Bm D G A Bm D G A Bm
#
# G
#
# G
#
# G
#
# A
#
# G
#
# A
#
# G
#
# G
#
# A
#
# A
#
# A
#
# D
#
# G
#
# A
#
# G
#
# A
#
# G
#
# G
#
# A
#
#
# ----- diversity: 0.5
# ----- Generating with seed: " A Bm D G A Bm D G A Bm D G A Bm D G A B"
#  A Bm D G A Bm D G A Bm D G A Bm D G A Bm
#
# G
#
# G
#
# G
#
# C
#
# A
#
# D
#
# u
#
# 7
#
# G
#
# E
#
#
# A
#
# G
#
# A
#
# G
#
# A
#
# G
#
# G
#
# G
#
# C
#
# ----- diversity: 1.0
# ----- Generating with seed: " A Bm D G A Bm D G A Bm D G A Bm D G A B"
#  A Bm D G A Bm D G A Bm D G A Bm D G A B
# u
# C
#
# E
# s
# 4
#
# D
# m
# C
# /
# B
# m
#
# A
# #
# A
# .
#
# E
# E
# a
# F
# s
# B
#
# F
# A
# u
#
# G
# m
# G
#
# G
#
#
#
# B
#
# ----- diversity: 1.2
# ----- Generating with seed: " A Bm D G A Bm D G A Bm D G A Bm D G A B"
#  A Bm D G A Bm D G A Bm D G A Bm D G A B
# 7
# #
# /
# 6
#
# B
#
# C
#
# G
#
# u
#
# G
# C
#
# D
#
# B
# m
# m
#
# u
#
# u
# A
# F
#
# D
# #
# .
#
# u
# s
# E
# G
# s
# A
#
#
# --------------------------------------------------
# Iteration 8
# Epoch 1/1
# 1285/1285 [==============================] - 1s 1ms/step - loss: 1.4451
#
# ----- diversity: 0.2
# ----- Generating with seed: " A E F# G A D C# F#m G A Bm G A Em G D E"
#  A E F# G A D C# F#m G A Bm G A Em G D E
# D
#
# D
#
# C
#
# A
#
# G
#
# A
#
# G
#
# A
#
# A
#
# A
#
# G
#
# A
#
# D
#
# A
#
# A
#
# G
#
# D
#
# A
#
# C
#
# G
#
# ----- diversity: 0.5
# ----- Generating with seed: " A E F# G A D C# F#m G A Bm G A Em G D E"
#  A E F# G A D C# F#m G A Bm G A Em G D Em
#
# E
#
#
#
# E
#
#
# C
#
# C
# /
# D
#
# C
#
# A
#
# D
#
# C
#
# B
# m
#
# C
#
# B
# m
#
# B
#
#
# F
#
# D
#
# A
#
#
# ----- diversity: 1.0
# ----- Generating with seed: " A E F# G A D C# F#m G A Bm G A Em G D E"
#  A E F# G A D C# F#m G A Bm G A Em G D E
# G
#
# G
#
# E
# .
# E
# G
#
# F
#
# C
#
# D
# m
# A
#
# B
#
# m
#
# C
#
# D
#
# B
# m
#
# G
#
# G
#
# #
#
# A
#
# C
#
#
#
# ----- diversity: 1.2
# ----- Generating with seed: " A E F# G A D C# F#m G A Bm G A Em G D E"
#  A E F# G A D C# F#m G A Bm G A Em G D E
# G
# u
# F
#
# A
#
# #
#
# C
# s
# F
#
# F
#
# D
#
# D
# D
#
# C
# C
# C
#
# F
#
# D
# s
# 7
# #
# E
#
#
# 4
#
# A
#
# C
# A
#
#
# --------------------------------------------------
# Iteration 9
# Epoch 1/1
# 1285/1285 [==============================] - 1s 1ms/step - loss: 1.3528
#
# ----- diversity: 0.2
# ----- Generating with seed: " D D G A D Bm G A D D G A D Bm G A D D G"
#  D D G A D Bm G A D D G A D Bm G A D D G
# C
#
# C
#
# C
#
# G
#
# G
#
# G
#
# C
#
# C
#
# C
#
# G
#
# C
#
# G
#
# G
#
# G
#
# C
#
# C
#
# C
#
# G
#
# G
#
# C
#
# ----- diversity: 0.5
# ----- Generating with seed: " D D G A D Bm G A D D G A D Bm G A D D G"
#  D D G A D Bm G A D D G A D Bm G A D D G
# C
#
# C
#
# G
#
# C
#
# G
#
# G
#
# G
#
# G
#
# A
#
# C
#
# C
#
# C
#
# G
#
# G
#
# D
#
# C
#
# G
#
# C
#
# C
#
# G
#
# ----- diversity: 1.0
# ----- Generating with seed: " D D G A D Bm G A D D G A D Bm G A D D G"
#  D D G A D Bm G A D D G A D Bm G A D D G
# C
#
# G
#
# C
#
# E
# #
# /
#
# m
#
# F
#
# A
#
# F
# #
# D
#
# D
#
# G
# #
# C
# m
# C
#
# G
#
# C
#
# A
#
# C
#
# F
#
# A
#
# ----- diversity: 1.2
# ----- Generating with seed: " D D G A D Bm G A D D G A D Bm G A D D G"
#  D D G A D Bm G A D D G A D Bm G A D D G
# A
#
# E
# m
#
# C
#
# A
# /
# G
#
# D
#
# G
#
# B
#
# B
#
#
# m
#
# C
#
# C
#
# A
#
#
# A
#
# C
# /
# B
# m
# D
#
# C

# %%
#風の又三郎

# %%
from keras.layers import Dense, Activation, LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys

chars = sorted(list(set(text)))
print('Total chars:', len(chars))

char_indices = dict((c,i) for i,c in enumerate(chars))
indices_char = dict((i,c) for i,c in enumerate(chars))

maxlen = 1
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
    
# テキストのベクトル化
X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
    

# モデルを定義する
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))
optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

for iteration in range(1,50):
    print()
    print('-' *50)
    print('繰り返し回数: ', iteration)
    model.fit(X, y, batch_size=128, epochs=1)
    
    start_index = random.randint(0, len(text)-maxlen-1)

    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print()
        print('-----diveristy', diversity)
    
        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Seedを生成しました: "' + sentence + '"')
        sys.stdout.write(generated)
    
        for i in range(24):
            x = np.zeros((1,maxlen,len(chars)))
            for t, char in enumerate(sentence):
                x[0, t, char_indices[char]] = 1.
            
            preds = model.predict(x, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]
        
            generated += next_char
            sentence = sentence[1:] + next_char
        
            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# Total chars: 21
#
# --------------------------------------------------
# 繰り返し回数:  1
# Epoch 1/1
# 1298/1298 [==============================] - 2s 1ms/step - loss: 2.2362
#
# -----diveristy 0.2
# ----- Seedを生成しました: "A"
# A A A A A A A A  A A A C
#
# -----diveristy 0.5
# ----- Seedを生成しました: "A"
# A  CAm C E A A  GA  C D G
#
# -----diveristy 1.0
# ----- Seedを生成しました: "A"
# A A B7 #/EmEG  /s4 .4  /A
#
# -----diveristy 1.2
# ----- Seedを生成しました: "A"
# A.
# Bm / aG G .yC FC AE7EC
#
# --------------------------------------------------
# 繰り返し回数:  2
# Epoch 1/1
# 1298/1298 [==============================] - 0s 90us/step - loss: 1.3970
#
# -----diveristy 0.2
# ----- Seedを生成しました: " "
#  A G G G G G G G G G G G
#
# -----diveristy 0.5
# ----- Seedを生成しました: " "
#  A G Em C C A G G A D G G
#
# -----diveristy 1.0
# ----- Seedを生成しました: " "
#  A# Em Em E A# BC G#m A C
#
# -----diveristy 1.2
# ----- Seedを生成しました: " "
#  GuE4 F Em F A C#.y# Bms/
#
# --------------------------------------------------
# 繰り返し回数:  3
# Epoch 1/1
# 1298/1298 [==============================] - 0s 93us/step - loss: 1.2554
#
# -----diveristy 0.2
# ----- Seedを生成しました: "G"
# G C D C C C C C D D A D D
#
# -----diveristy 0.5
# ----- Seedを生成しました: "G"
# G D E G C A D A D E D C B
#
# -----diveristy 1.0
# ----- Seedを生成しました: "G"
# G D F E# C# D G D G B G D
#
# -----diveristy 1.2
# ----- Seedを生成しました: "G"
# G7 C F# A Dm D D A D A C
#
# --------------------------------------------------
# 繰り返し回数:  4
# Epoch 1/1
# 1298/1298 [==============================] - 0s 91us/step - loss: 1.1961
#
# -----diveristy 0.2
# ----- Seedを生成しました: "B"
# Bm G A A A A A G A A G G
#
# -----diveristy 0.5
# ----- Seedを生成しました: "B"
# Bm A G G A C C Em C C A F
#
# -----diveristy 1.0
# ----- Seedを生成しました: "B"
# Bm7 C G F G# A Asu/ Csusu
#
# -----diveristy 1.2
# ----- Seedを生成しました: "B"
# Bm As4 Em G7 C G G G A A/
#
# --------------------------------------------------
# 繰り返し回数:  5
# Epoch 1/1
# 1298/1298 [==============================] - 0s 76us/step - loss: 1.1705
#
# -----diveristy 0.2
# ----- Seedを生成しました: "B"
# Bm Em D Em G Em C A C A E
#
# -----diveristy 0.5
# ----- Seedを生成しました: "B"
# Bm D G Em G D G D A C G E
#
# -----diveristy 1.0
# ----- Seedを生成しました: "B"
# Bm7 E C C E F A G E Em Cm
#
# -----diveristy 1.2
# ----- Seedを生成しました: "B"
# Bm E C D E D Asus4 Bm7 AD
#
# --------------------------------------------------
# 繰り返し回数:  6
# Epoch 1/1
# 1298/1298 [==============================] - 0s 91us/step - loss: 1.1467
#
# -----diveristy 0.2
# ----- Seedを生成しました: "C"
# C D A C C D A D D A C A D
#
# -----diveristy 0.5
# ----- Seedを生成しました: "C"
# C G G Bm C A C A D D A D
#
# -----diveristy 1.0
# ----- Seedを生成しました: "C"
# C Bm7 Bm E Bm E A D A Bm7
#
# -----diveristy 1.2
# ----- Seedを生成しました: "C"
# Cm C# G G D G/.C D C Em D
#
# --------------------------------------------------
# 繰り返し回数:  7
# Epoch 1/1
# 1298/1298 [==============================] - 0s 87us/step - loss: 1.1332
#
# -----diveristy 0.2
# ----- Seedを生成しました: " "
#  C A C C C C C C C C C A
#
# -----diveristy 0.5
# ----- Seedを生成しました: " "
#  G G C A C C G A C C A C
#
# -----diveristy 1.0
# ----- Seedを生成しました: " "
#  G Bm C F Em C C D F A# G
#
# -----diveristy 1.2
# ----- Seedを生成しました: " "
#  Bm# D D Bm D F C C A C/A
#
# --------------------------------------------------
# 繰り返し回数:  8
# Epoch 1/1
# 1298/1298 [==============================] - 0s 80us/step - loss: 1.1316
#
# -----diveristy 0.2
# ----- Seedを生成しました: " "
#  G G G G C C D G G C C G
#
# -----diveristy 0.5
# ----- Seedを生成しました: " "
#  D G C D Bm G G Bm D C C
#
# -----diveristy 1.0
# ----- Seedを生成しました: " "
#  Em Bm Bm D Bm G Em C A C
#
# -----diveristy 1.2
# ----- Seedを生成しました: " "
#  C C G F Bm G D C/F Em Em
#
# --------------------------------------------------
# 繰り返し回数:  9
# Epoch 1/1
# 1298/1298 [==============================] - 0s 103us/step - loss: 1.1330
#
# -----diveristy 0.2
# ----- Seedを生成しました: "A"
# A G A G G C G G A G G G G
#
# -----diveristy 0.5
# ----- Seedを生成しました: "A"
# A G G C G G G A C G G A G
#
# -----diveristy 1.0
# ----- Seedを生成しました: "A"
# A G G Am G G A C G F G G
#
# -----diveristy 1.2
# ----- Seedを生成しました: "A"
# Am G C G A C A Gm A D G C
#
# --------------------------------------------------
# 繰り返し回数:  10
# Epoch 1/1
# 1298/1298 [==============================] - 0s 90us/step - loss: 1.1285
#
# -----diveristy 0.2
# ----- Seedを生成しました: "E"
# E G G A A G G G G A A A A
#
# -----diveristy 0.5
# ----- Seedを生成しました: "E"
# E C E E G A A A C C G D G
#
# -----diveristy 1.0
# ----- Seedを生成しました: "E"
# E G D D G G C E A C/As4 D
#
# -----diveristy 1.2
# ----- Seedを生成しました: "E"
# E  C B G D# E C G D Asus4
#
# --------------------------------------------------
# 繰り返し回数:  11
# Epoch 1/1
# 1298/1298 [==============================] - 0s 122us/step - loss: 1.1214
#
# -----diveristy 0.2
# ----- Seedを生成しました: "G"
# G A D C A A A A A D A A A
#
# -----diveristy 0.5
# ----- Seedを生成しました: "G"
# G A A D A A A C G A A C A
#
# -----diveristy 1.0
# ----- Seedを生成しました: "G"
# G C A D C/F D Cm Bm A# C
#
# -----diveristy 1.2
# ----- Seedを生成しました: "G"
# G C F D D  D Am7 C/As4 D
#
# --------------------------------------------------
# 繰り返し回数:  12
# Epoch 1/1
# 1298/1298 [==============================] - 0s 106us/step - loss: 1.1254
#
# -----diveristy 0.2
# ----- Seedを生成しました: "D"
# D A Bm A G A C A A A A A
#
# -----diveristy 0.5
# ----- Seedを生成しました: "D"
# D C A/F A D Em C F A C As
#
# -----diveristy 1.0
# ----- Seedを生成しました: "D"
# D A C# C/Bm  G C A#m D A
#
# -----diveristy 1.2
# ----- Seedを生成しました: "D"
# D A C G Em A D G A G C C#
#
# --------------------------------------------------
# 繰り返し回数:  13
# Epoch 1/1
# 1298/1298 [==============================] - 0s 77us/step - loss: 1.1160
#
# -----diveristy 0.2
# ----- Seedを生成しました: "G"
# G A A A A A A A A A A A A
#
# -----diveristy 0.5
# ----- Seedを生成しました: "G"
# G# A Em7 C A G G C G A A
#
# -----diveristy 1.0
# ----- Seedを生成しました: "G"
# G G D D A D Am Bm7 C/A As
#
# -----diveristy 1.2
# ----- Seedを生成しました: "G"
# G Gm.
#
#
# 4 C As4 A G E.
# E
#
# --------------------------------------------------
# 繰り返し回数:  14
# Epoch 1/1
# 1298/1298 [==============================] - 0s 83us/step - loss: 1.1210
#
# -----diveristy 0.2
# ----- Seedを生成しました: "A"
# A A A C C A A C C A C C C
#
# -----diveristy 0.5
# ----- Seedを生成しました: "A"
# A D C G A G C A C A A G A
#
# -----diveristy 1.0
# ----- Seedを生成しました: "A"
# A Bm G G C F Em7 A7 D C B
#
# -----diveristy 1.2
# ----- Seedを生成しました: "A"
# A Aausus4 E G Bm Em A A7
#
# --------------------------------------------------
# 繰り返し回数:  15
# Epoch 1/1
# 1298/1298 [==============================] - 0s 92us/step - loss: 1.1166
#
# -----diveristy 0.2
# ----- Seedを生成しました: "D"
# D G G G G G G G G G G A G
#
# -----diveristy 0.5
# ----- Seedを生成しました: "D"
# D Em G G G Em A Em G A C
#
# -----diveristy 1.0
# ----- Seedを生成しました: "D"
# D G D G D G C G F Em7 D A
#
# -----diveristy 1.2
# ----- Seedを生成しました: "D"
# D G Bm G G  G Bm F G C Gm
#
# --------------------------------------------------
# 繰り返し回数:  16
# Epoch 1/1
# 1298/1298 [==============================] - 0s 83us/step - loss: 1.1165
#
# -----diveristy 0.2
# ----- Seedを生成しました: " "
#  D D A D D D A A A A A A
#
# -----diveristy 0.5
# ----- Seedを生成しました: " "
#  D C A C/D Em7 D G Em7 A
#
# -----diveristy 1.0
# ----- Seedを生成しました: " "
#  A/F A Am D Aaus4 G D G C
#
# -----diveristy 1.2
# ----- Seedを生成しました: " "
#  Bm C D Bm A D C/D G Dsug
#
# --------------------------------------------------
# 繰り返し回数:  17
# Epoch 1/1
# 1298/1298 [==============================] - 0s 87us/step - loss: 1.1239
#
# -----diveristy 0.2
# ----- Seedを生成しました: "B"
# Bm A D A C C G A C G C D
#
# -----diveristy 0.5
# ----- Seedを生成しました: "B"
# Bm G G G Em Em C/D G D C
#
# -----diveristy 1.0
# ----- Seedを生成しました: "B"
# Bm A D C# C/F Bm G C C C
#
# -----diveristy 1.2
# ----- Seedを生成しました: "B"
# Bm D C/A C C  D  G C/D D
#
# --------------------------------------------------
# 繰り返し回数:  18
# Epoch 1/1
# 1298/1298 [==============================] - 0s 92us/step - loss: 1.1181
#
# -----diveristy 0.2
# ----- Seedを生成しました: "/"
# /F C G A A C C C A A A G
#
# -----diveristy 0.5
# ----- Seedを生成しました: "/"
# /F C G Em C A G A G C D G
#
# -----diveristy 1.0
# ----- Seedを生成しました: "/"
# / A# Bm A A A C F G Bm G
#
# -----diveristy 1.2
# ----- Seedを生成しました: "/"
# /AF F D A Em G D G C A G
#
# --------------------------------------------------
# 繰り返し回数:  19
# Epoch 1/1
# 1298/1298 [==============================] - 0s 94us/step - loss: 1.1172
#
# -----diveristy 0.2
# ----- Seedを生成しました: "G"
# G A A G G G G G G G G A A
#
# -----diveristy 0.5
# ----- Seedを生成しました: "G"
# G G D A G A C C G A G D E
#
# -----diveristy 1.0
# ----- Seedを生成しました: "G"
# G# E A B Bm A G G G C/A.
#
#
# -----diveristy 1.2
# ----- Seedを生成しました: "G"
# G D G A Bm G Asus4 G A D
#
# --------------------------------------------------
# 繰り返し回数:  20
# Epoch 1/1
# 1298/1298 [==============================] - 0s 111us/step - loss: 1.1124
# -----diveristy 0.2
# ----- Seedを生成しました: "B"
# Bm7 G G G G G G C G G G C
#
# -----diveristy 0.5
# ----- Seedを生成しました: "B"
# Bm7 A D A G G D G D G A G
#
# -----diveristy 1.0
# ----- Seedを生成しました: "B"
# Bm C G D Em D A Bm7 A# D
#
# -----diveristy 1.2
# ----- Seedを生成しました: "B"
# Bm E G D Em7 F A G G Bm/F
#
# --------------------------------------------------
# 繰り返し回数:  21
# Epoch 1/1
# 1298/1298 [==============================] - 0s 89us/step - loss: 1.1218
#
# -----diveristy 0.2
# ----- Seedを生成しました: " "
#  G D G G G C G G C A C C
#
# -----diveristy 0.5
# ----- Seedを生成しました: " "
#  G C A G D D G G A C A E
#
# -----diveristy 1.0
# ----- Seedを生成しました: " "
#  G D Bm.
# Bm7 Bm7 A/F G A
#
# -----diveristy 1.2
# ----- Seedを生成しました: " "
#  G A G D E Em.
# G Bm7 Em G
#
# --------------------------------------------------
# 繰り返し回数:  22
# Epoch 1/1
# 1298/1298 [==============================] - 0s 91us/step - loss: 1.1165
#
# -----diveristy 0.2
# ----- Seedを生成しました: " "
#  G D G G G C G A G G C G
#
# -----diveristy 0.5
# ----- Seedを生成しました: " "
#  D C A G A A G D Bm E G C
#
# -----diveristy 1.0
# ----- Seedを生成しました: " "
#  A D G C G C#m G D G C D
#
# -----diveristy 1.2
# ----- Seedを生成しました: " "
#  Em Bm D C G A C C G D A
#
# --------------------------------------------------
# 繰り返し回数:  23
# Epoch 1/1
# 1298/1298 [==============================] - 0s 92us/step - loss: 1.1215
#
# -----diveristy 0.2
# ----- Seedを生成しました: "E"
# Em A A C A A A G A D A A
#
# -----diveristy 0.5
# ----- Seedを生成しました: "E"
# Em D A A A A A A F A Bm A
#
# -----diveristy 1.0
# ----- Seedを生成しました: "E"
# Em As4 C G A E Bm F Bm A
#
# -----diveristy 1.2
# ----- Seedを生成しました: "E"
# Em F Em Bm# C A A.
# G D Bm
#
# --------------------------------------------------
# 繰り返し回数:  24
# Epoch 1/1
# 1298/1298 [==============================] - 0s 77us/step - loss: 1.1105
#
# -----diveristy 0.2
# ----- Seedを生成しました: " "
#  A A A G A A D A A A A A
#
# -----diveristy 0.5
# ----- Seedを生成しました: " "
#  G A A A G A Em A A A A C
#
# -----diveristy 1.0
# ----- Seedを生成しました: " "
#  Asus4 A D A# A A C/F.
#
#
#
#
# -----diveristy 1.2
# ----- Seedを生成しました: " "
#  G C# G# A G G F C E A As
#
# --------------------------------------------------
# 繰り返し回数:  25
# Epoch 1/1
# 1298/1298 [==============================] - 0s 87us/step - loss: 1.1189
#
# -----diveristy 0.2
# ----- Seedを生成しました: "G"
# G G G G G G G A A A G A A
#
# -----diveristy 0.5
# ----- Seedを生成しました: "G"
# G# Bm G G Em G C C G G A
#
# -----diveristy 1.0
# ----- Seedを生成しました: "G"
# G C D C D C Em C G F C Bm
#
# -----diveristy 1.2
# ----- Seedを生成しました: "G"
# G A D A Cm C F Asus4 G C
#
# --------------------------------------------------
# 繰り返し回数:  26
# Epoch 1/1
# 1298/1298 [==============================] - 0s 71us/step - loss: 1.1167
#
# -----diveristy 0.2
# ----- Seedを生成しました: "F"
# F A A A A A A A A A A A A
#
# -----diveristy 0.5
# ----- Seedを生成しました: "F"
# F G G A A A A Em A A D A
#
# -----diveristy 1.0
# ----- Seedを生成しました: "F"
# F Bm F D Bm Em A# Bm G A/
#
# -----diveristy 1.2
# ----- Seedを生成しました: "F"
# F# D#m A G# Bm A A D F G
#
# --------------------------------------------------
# 繰り返し回数:  27
# Epoch 1/1
# 1298/1298 [==============================] - 0s 95us/step - loss: 1.1144
#
# -----diveristy 0.2
# ----- Seedを生成しました: " "
#  G G G G G G G D G G G G
#
# -----diveristy 0.5
# ----- Seedを生成しました: " "
#  A A G G G G G G A G A G
#
# -----diveristy 1.0
# ----- Seedを生成しました: " "
#  A A E C As4 G G A A G Em
#
# -----diveristy 1.2
# ----- Seedを生成しました: " "
#   G F D G G G G F Em A G
#
# --------------------------------------------------
# 繰り返し回数:  28
# Epoch 1/1
# 1298/1298 [==============================] - 0s 85us/step - loss: 1.1109
#
# -----diveristy 0.2
# ----- Seedを生成しました: "C"
# C A A A C A A A A A C A A
#
# -----diveristy 0.5
# ----- Seedを生成しました: "C"
# C A A A A A A A A A A A A
#
# -----diveristy 1.0
# ----- Seedを生成しました: "C"
# C As4 A C A Cm D F C F C
#
# -----diveristy 1.2
# ----- Seedを生成しました: "C"
# C D G Cm E Em G# Bm C/F A
#
# --------------------------------------------------
# 繰り返し回数:  29
# Epoch 1/1
# 1298/1298 [==============================] - 0s 78us/step - loss: 1.1185
#
# -----diveristy 0.2
# ----- Seedを生成しました: "
# "
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----diveristy 0.5
# ----- Seedを生成しました: "
# "
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----diveristy 1.0
# ----- Seedを生成しました: "
# "
#
#
#
#
#
#
#
# Em C/D A Bm D Em7
#
# -----diveristy 1.2
# ----- Seedを生成しました: "
# "
#
#
# .
# Em C A# C G A A F# Bm
#
# --------------------------------------------------
# 繰り返し回数:  30
# Epoch 1/1
# 1298/1298 [==============================] - 0s 101us/step - loss: 1.1190
#
# -----diveristy 0.2
# ----- Seedを生成しました: "D"
# D C Em G G A G G A G G G
#
# -----diveristy 0.5
# ----- Seedを生成しました: "D"
# D A Em A D A D C D D G A
#
# -----diveristy 1.0
# ----- Seedを生成しました: "D"
# D C F D G G A C A Bm G D
#
# -----diveristy 1.2
# ----- Seedを生成しました: "D"
# D A A G Bm F G A A# A/D B
#
# --------------------------------------------------
# 繰り返し回数:  31
# Epoch 1/1
# 1298/1298 [==============================] - 0s 69us/step - loss: 1.1156
#
# -----diveristy 0.2
# ----- Seedを生成しました: "
# "
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----diveristy 0.5
# ----- Seedを生成しました: "
# "
#
#
#
#
# Em G A C F Bm A G G E
#
# -----diveristy 1.0
# ----- Seedを生成しました: "
# "
#
#
#
#
#
# G Dm Em A C/F G G G
#
# -----diveristy 1.2
# ----- Seedを生成しました: "
# "
#
#
# G Bm7 Gm A G D G F.
# G B
#
# --------------------------------------------------
# 繰り返し回数:  32
# Epoch 1/1
# 1298/1298 [==============================] - 0s 74us/step - loss: 1.1122
#
# -----diveristy 0.2
# ----- Seedを生成しました: "s"
# susus4 A A A D A A A A A
#
# -----diveristy 0.5
# ----- Seedを生成しました: "s"
# susus4 G A G G A D A A D
#
# -----diveristy 1.0
# ----- Seedを生成しました: "s"
# s4 Em7 Bm G Em D C C Em A
#
# -----diveristy 1.2
# ----- Seedを生成しました: "s"
# sus4 G D A A D D# G G Em
#
# --------------------------------------------------
# 繰り返し回数:  33
# Epoch 1/1
# 1298/1298 [==============================] - 0s 64us/step - loss: 1.1186
#
# -----diveristy 0.2
# ----- Seedを生成しました: " "
#  D D A Em Em G Em D Em7 E
#
# -----diveristy 0.5
# ----- Seedを生成しました: " "
#  D Em A A G G Em7 Em7 Em7
#
# -----diveristy 1.0
# ----- Seedを生成しました: " "
#  D C B Bm7 usus4 G C C Em
#
# -----diveristy 1.2
# ----- Seedを生成しました: " "
#  C C F E Cm7 C D D Gm.
# Em
#
# --------------------------------------------------
# 繰り返し回数:  34
# Epoch 1/1
# 1298/1298 [==============================] - 0s 73us/step - loss: 1.1143
#
# -----diveristy 0.2
# ----- Seedを生成しました: " "
#  A A C A D D D A D D D D
#
# -----diveristy 0.5
# ----- Seedを生成しました: " "
#  D Bm C/F D F C/F# C/F G
#
# -----diveristy 1.0
# ----- Seedを生成しました: " "
#  D G A.
# Bm D F A# Em A# G
#
# -----diveristy 1.2
# ----- Seedを生成しました: " "
#  A G A A D Gm7 A D E C D/
#
# --------------------------------------------------
# 繰り返し回数:  35
# Epoch 1/1
# 1298/1298 [==============================] - 0s 85us/step - loss: 1.1191
#
# -----diveristy 0.2
# ----- Seedを生成しました: " "
#  A C A A A D A A A D A A
#
# -----diveristy 0.5
# ----- Seedを生成しました: " "
#  D G G C/F A G A G D F A
#
# -----diveristy 1.0
# ----- Seedを生成しました: " "
#  A D A Bm E Asusug As4 G
#
# -----diveristy 1.2
# ----- Seedを生成しました: " "
#  Bm7 D Bm7 F C G A # Cm F
#
# --------------------------------------------------
# 繰り返し回数:  36
# Epoch 1/1
# 1298/1298 [==============================] - 0s 74us/step - loss: 1.1156
#
# -----diveristy 0.2
# ----- Seedを生成しました: " "
#  G G A G Em7 A G G G A G
#
# -----diveristy 0.5
# ----- Seedを生成しました: " "
#  G G C G C C F G A A G G
#
# -----diveristy 1.0
# ----- Seedを生成しました: " "
#  A A G D G A A A G B/A A
#
# -----diveristy 1.2
# ----- Seedを生成しました: " "
#  D B Bm7 Bm7 D D A F A F
#
# --------------------------------------------------
# 繰り返し回数:  37
# Epoch 1/1
# 1298/1298 [==============================] - 0s 74us/step - loss: 1.1182
#
# -----diveristy 0.2
# ----- Seedを生成しました: "D"
# D A C G G A G A D A A G A
#
# -----diveristy 0.5
# ----- Seedを生成しました: "D"
# D A G G C G G G Em7 G D A
#
# -----diveristy 1.0
# ----- Seedを生成しました: "D"
# D E G D A A Em G E G A G
#
# -----diveristy 1.2
# ----- Seedを生成しました: "D"
# D A A C G C C G C/D Gm7 G
#
# --------------------------------------------------
# 繰り返し回数:  38
# Epoch 1/1
# 1298/1298 [==============================] - 0s 83us/step - loss: 1.1131
#
# -----diveristy 0.2
# ----- Seedを生成しました: " "
#  A A A A A A A A A A A A
#
# -----diveristy 0.5
# ----- Seedを生成しました: " "
#  G A G G A A A D Bm A A A
#
# -----diveristy 1.0
# ----- Seedを生成しました: " "
#  Asus4 C D A C# Aaus4 D A
#
# -----diveristy 1.2
# ----- Seedを生成しました: " "
#  D D G# F G Bm C/D Em Am
#
# --------------------------------------------------
# 繰り返し回数:  39
# Epoch 1/1
# 1298/1298 [==============================] - 0s 90us/step - loss: 1.1123
#
# -----diveristy 0.2
# ----- Seedを生成しました: "#"
# # G G G G G G G G G A G G
#
# -----diveristy 0.5
# ----- Seedを生成しました: "#"
# # C A A G G Bm D G G A G
#
# -----diveristy 1.0
# ----- Seedを生成しました: "#"
# # C G G G C Gm Cm As4 A A
#
# -----diveristy 1.2
# ----- Seedを生成しました: "#"
# # G E E/G A Bm G A C# E C
#
# --------------------------------------------------
# 繰り返し回数:  40
# Epoch 1/1
# 1298/1298 [==============================] - 0s 71us/step - loss: 1.1119
#
# -----diveristy 0.2
# ----- Seedを生成しました: "B"
# Bm A A A A D A A D A G D
#
# -----diveristy 0.5
# ----- Seedを生成しました: "B"
# Bm Bm7 A C D D G D A A A
#
# -----diveristy 1.0
# ----- Seedを生成しました: "B"
# Bm Em7 D G D D D G D G C
#
# -----diveristy 1.2
# ----- Seedを生成しました: "B"
# Bm E G Cm7 Ag G A G# A A
#
# --------------------------------------------------
# 繰り返し回数:  41
# Epoch 1/1
# 1298/1298 [==============================] - 0s 93us/step - loss: 1.1140
#
# -----diveristy 0.2
# ----- Seedを生成しました: " "
#  G G G G G G C G G G G G
#
# -----diveristy 0.5
# ----- Seedを生成しました: " "
#  C A A G C/F C G C G C G
#
# -----diveristy 1.0
# ----- Seedを生成しました: " "
#  F D A Em A/F F C G G A#
#
# -----diveristy 1.2
# ----- Seedを生成しました: " "
#  E/F G Bm G E Bm m Em C C
#
# --------------------------------------------------
# 繰り返し回数:  42
# Epoch 1/1
# 1298/1298 [==============================] - 0s 95us/step - loss: 1.1178
#
# -----diveristy 0.2
# ----- Seedを生成しました: "C"
# C G G G G G G A A G G G A
#
# -----diveristy 0.5
# ----- Seedを生成しました: "C"
# C G G G G A G A G G Bm G
#
# -----diveristy 1.0
# ----- Seedを生成しました: "C"
# C B G# F#m7 A A D A G Em
#
# -----diveristy 1.2
# ----- Seedを生成しました: "C"
# C G A# G G A C# C F# Em E
#
# --------------------------------------------------
# 繰り返し回数:  43
# Epoch 1/1
# 1298/1298 [==============================] - 0s 102us/step - loss: 1.1092
#
# -----diveristy 0.2
# ----- Seedを生成しました: " "
#  A C/F A A G G A Em G A A
#
# -----diveristy 0.5
# ----- Seedを生成しました: " "
#  A C/F C D A G G A A A A
#
# -----diveristy 1.0
# ----- Seedを生成しました: " "
#  D.
#
# G#m C G A A A G Bm7
#
# -----diveristy 1.2
# ----- Seedを生成しました: " "
#  A C As4 F# Am C A C GEm
#
# --------------------------------------------------
# 繰り返し回数:  44
# Epoch 1/1
# 1298/1298 [==============================] - 0s 70us/step - loss: 1.1103
#
# -----diveristy 0.2
# ----- Seedを生成しました: "m"
# m A A A A A A A A A A A A
#
# -----diveristy 0.5
# ----- Seedを生成しました: "m"
# m7 F G A A D G Bm7 A C/F
#
# -----diveristy 1.0
# ----- Seedを生成しました: "m"
# m7 C F G G Bm C Bm A F D
#
# -----diveristy 1.2
# ----- Seedを生成しました: "m"
# m Gm F D Em D#m7 G Am7 G
#
# --------------------------------------------------
# 繰り返し回数:  45
# Epoch 1/1
# 1298/1298 [==============================] - 0s 80us/step - loss: 1.1151
#
# -----diveristy 0.2
# ----- Seedを生成しました: "F"
# F G A A G A G G C A A A D
#
# -----diveristy 0.5
# ----- Seedを生成しました: "F"
# F C G Em G G G A F G G G
#
# -----diveristy 1.0
# ----- Seedを生成しました: "F"
# F A Em7 A A A A G A C/As4
#
# -----diveristy 1.2
# ----- Seedを生成しました: "F"
# F A FBm F Am A D C C Bm A
#
# --------------------------------------------------
# 繰り返し回数:  46
# Epoch 1/1
# 1298/1298 [==============================] - 0s 109us/step - loss: 1.1120
#
# -----diveristy 0.2
# ----- Seedを生成しました: " "
#  G G C C G A A A A A A G
#
# -----diveristy 0.5
# ----- Seedを生成しました: " "
#  C# G D C C C G A G C A C
#
# -----diveristy 1.0
# ----- Seedを生成しました: " "
#  Bm A G A D C A G A G G C
#
# -----diveristy 1.2
# ----- Seedを生成しました: " "
#  G G G A D E G# E Em As4
#
# --------------------------------------------------
# 繰り返し回数:  47
# Epoch 1/1
# 1298/1298 [==============================] - 0s 84us/step - loss: 1.1123
#
# -----diveristy 0.2
# ----- Seedを生成しました: " "
#  G A G A G G A G G G G G
#
# -----diveristy 0.5
# ----- Seedを生成しました: " "
#  A G D A G G A Em D G C F
#
# -----diveristy 1.0
# ----- Seedを生成しました: " "
#  C/F A G A D G Bm C Asusu
#
# -----diveristy 1.2
# ----- Seedを生成しました: " "
#  F#m G A G D Bm D C A A C
#
# --------------------------------------------------
# 繰り返し回数:  48
# Epoch 1/1
# 1298/1298 [==============================] - 0s 115us/step - loss: 1.1096
#
# -----diveristy 0.2
# ----- Seedを生成しました: "B"
# Bm G D G G A A G G D D G
#
# -----diveristy 0.5
# ----- Seedを生成しました: "B"
# Bm G A A A G G G D A A G
#
# -----diveristy 1.0
# ----- Seedを生成しました: "B"
# B G A D A G G D C D C G F
#
# -----diveristy 1.2
# ----- Seedを生成しました: "B"
# Bm7 C  A F G C A D G F Bm
#
# --------------------------------------------------
# 繰り返し回数:  49
# Epoch 1/1
# 1298/1298 [==============================] - 0s 89us/step - loss: 1.1114
#
# -----diveristy 0.2
# ----- Seedを生成しました: "F"
# F G G G G G G G G G G G G
#
# -----diveristy 0.5
# ----- Seedを生成しました: "F"
# F G A G Em G G A Bm E A G
#
# -----diveristy 1.0
# ----- Seedを生成しました: "F"
# F G A D Bm G G# A D C B A
#
# -----diveristy 1.2
# ----- Seedを生成しました: "F"
# F A D G A.
# Bm A A G C/F F

# %%
#マルコフ

# %%
from janome.tokenizer import Tokenizer

# %%
# テキストファイルを読み込む
sjis = open('rad_code.txt', 'rb').read()
text = sjis.decode('utf_8')

# %%
# テキストを形態素解析読み込みます

t = Tokenizer()
words = t.tokenize(text)

# %%
import json

# %%
# 辞書を生成します
def make_dic(words):
    tmp = ["@"]
    dic = {}
    for i in words:
        word = i.surface
        if word == "" or word == "\r\n" or word == "\n": continue
        tmp.append(word)
        if len(tmp) < 3: continue
        if len(tmp) > 3: tmp = tmp[1:]
        set_word3(dic, tmp)
        if word == ".":
            tmp = ["@"]
            continue
    return dic

# 三要素のリストを辞書として登録しています
def set_word3(dic, s3):
    w1, w2, w3 = s3
    if not w1 in dic: dic[w1] = {}
    if not w2 in dic[w1]: dic[w1][w2] = {}
    if not w3 in dic[w1][w2]: dic[w1][w2][w3] = 0
    dic[w1][w2][w3] += 1

dic = make_dic(words)
json.dump(dic, open("markov-blog.json", "w", encoding="utf-8"))

# %%
import json
dic = open("markov-blog.json" , "r")
dic = json.load(dic)

tweets_list = []
import random
def word_choice(sel):
    keys = sel.keys()
    ran = random.choice(list(keys))
    return ran

def make_sentence(dic):
    ret = []
    if not "@" in dic: return "no dic"
    top = dic["@"]
    w1 = word_choice(top)
    w2 = word_choice(top[w1])
    ret.append(w1)
    ret.append(w2)
    while True:
        w3 = word_choice(dic[w1][w2])
        ret.append(w3)
        if w3 == ".": break
        w1, w2 = w2, w3
    tweets_list.append(ret)
    return "".join(ret)
    
for i in range(1):
    s = make_sentence(dic)
    tweets_list.append(s)
    print(s)
# Out:
# G,AA,B,A7,G/A,A7,Am7,C,Bm.
