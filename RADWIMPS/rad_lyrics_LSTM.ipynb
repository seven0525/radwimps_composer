# %%
from keras.models import Sequential
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
from keras.layers import Dense, Activation, LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys

# %%
path = './rad_lyrics.txt'

# %%
text = open(path, "r").read()

# %%
type(text)
# Out:
# str

# %%
text
# Out:
# "一人のために描いた夢を 誰かに使いまわした\nそんなこともあるさと笑える僕も きっとセプテンバー\n\n『夏』ってだけでキラキラしてた あの気持ちが好きなの\n「もう少しだけここにいさせて」そんな顔で僕見るの\n\nでも君が笑える理由なら 僕が見つけてきてあげる\nこんな二人を繋ぐのは きっとなんでもないセプテンバー\n\n本物よりもリアルに見えた あの魔法はもう解けた\nけどギュっとすればキュンとなるあれは 夏のおかげなんかじゃない\n\n湿る空が乾く色を きっとパパは探していたの\nそんな時に一人ぽつんと疼くまってたセプテンバー\n\nOH セプテンバー OH セプテンバー\nOH セプテンバー OH セプテンバー\n\n夢が語りつくした希望を 僕は拾うよ 君は見てるの?\nさぁ今ならば この声ならば届く気がしたんだ\n\n夏がちらかしてった心を 僕は紡ぐよ さぁいざ行こう\nそう今だから この声だから 響くセプテンバー\n\n声が響きだす そこに意味はなくとも\n君が笑い出す そこに夏はいなくとも\n\nOH セプテンバー OH セプテンバー\nOH セプテンバー OH セプテンバー\n\n僕が笑える理由なら 今まさに目の前にいるよ\nこんな僕らをつなぐのは そうさいつも\n\n愛が語り尽くした想いを 僕は歌うよ 人は笑うよ\nでも今ならば この声ならば届く気がしたんだ\n\n手と手をとれば揺れる心が 抱えた不思議 それはテレパシー\nさぁ今だから この声だから さぁ今ならば この声ならば\n\nこんな僕だけど そう君となら 何もないけれど そう今ならば\nこの声ならば そう君となら 響く気がしたんだ\n\nあぁこの季節(とき)が 語るもの\nあぁこの季節(とき)が 繋ぐもの。\n\n\nいいんですか\u3000いいんですか\nこんなに人を好きになっていいんですか?\nいいんですか\u3000いいんですか\nこんなに人を信じてもいいんですか?\n\n大好物はね\u3000鳥の唐揚げ\n更に言えばうちのおかんが作る鳥のアンかけ\nでもどれも勝てない\u3000お前にゃ敵わない\u3000\nお前がおかずならば俺はどんぶりで50杯は\n軽くご飯おかわりできるよ\u3000だけども\u3000んなこと言うと\n「じゃあやってみて」とかってお前は言いだすけど\u3000\nそれはあくまでも例えの話でありまして\u3000\nだどもやれと言われりゃ\u3000おいどんも男なわけで\n富良野は寒いわけで\u3000お前が好きなわけで\nちょびっとでも分かってもらいたいわけで\u3000\nちなみに、オカズって\u3000変な意味じゃないんで 嫌いにならないでね\n\nいいんですか\u3000いいんですか\nこんなに人を好きになっていいんですか?\nいいんですか\u3000いいんですか\nこんなに人を信じてもいいんですか?\n\nいいんですよ\u3000いいんですよ\u3000あなたが選んだ人ならば\nいいんですよ\u3000いいんですよ\u3000あんたが選んだ道ならば\n\n今まで俺は何回お前を泣かせたんだろう\nそれに比べて何回笑わせてやれたんだろう\n\n更には嬉し泣きっていう合わせ技もお前は\n持ち合わせているから余計分かんなくなんだよ\n\n「ごめんね」と「ありがとう」を繰り返せばいいんだよ\nその比率は五分と五分に限りなく近いけど\n例えば999999回ずつで最期の\u3000瞬間を迎えたとしよう\n「ありがとう」の勝ちはもう間違いない\n必ずや到達するよ1000000回\nだってさ\u3000だってさ\u3000だってだってだってさ\nだって俺のこの世の最期の言葉はあなたに言う「ありがとう」\n\nいいんですか\u3000いいんですか\nこんなに人を好きになっていいんですか?\nいいんですか\u3000いいんですか\nこんなにのめりこんじゃっていいんですか?\n\nいいんですよ\u3000いいんですよ\u3000あなたが望んだ人ならば\nいいんですよ\u3000いいんですよ\u3000あなたが望んだ道ならば\n\nあなたといる意味を探したら\u3000明日を生きる答えになったよ\n明日を生きる意味を探したら\u3000あなたといる答えになったよ\n\nいいんですか\u3000いいんですか\nこんなに人を好きになっていいんですか?\nいいんですか\u3000いいんですか\nこんなに人を信じてもいいんですか?\n\nいいんですよ\u3000いいんですよ\u3000あなたが愛した人ならば\nいいんですよ\u3000いいんですよ\n\nいいんですか\u3000いいんですか\nこんなに人を好きになっていいんですか?\nいいんですか\u3000いいんですか\nこんなに人を信じてもいいんですか?\n\nいいんですよ\u3000いいんですよ\u3000あなたが選んだ人ならば\nいいんですよ\u3000いいんですよ\u3000むしろそうであって欲しいんですよ\n\nいいんですか\u3000いいんですか\nこんなに人を好きになっていいんですか?\nいいんですよ\u3000いいんですよ\nあなたが選んだ人ならば\nあなたが愛した人ならば\nあなたが望んだ人ならば。\n\n\n満天の空に君の声が響いてもいいような綺麗な夜\n悲しみが悲しみで終わらぬよう\u3000せめて地球は周ってみせた\n\n本当に伝えたい想いだけはうまく伝わらないようにできてた\nそのもどかしさに抱かれぬよう\u3000せめて僕は笑ってみせた\n\n「何もないんだってここには」って笑ってる君も望んでる\nそんな声もかき消すほどに\u3000膨れるこの万象を\n\n「意味はないんだって僕には」って叫んでる僕も望んでる\n無味を悟る\u3000その先に浮かぶ光の粒を\n\n最近は映画の見すぎで奇跡も珍しくなくなったね\n心にもないことでもすらすら言えるようになったよ\n\nほら\u3000僕が僕から離れてくそんなことさえも忘れたくなる\n「真実とはねそれだけで美しいんだ」と\u3000言って\n\n満天の空に君の声が響いてもいいような綺麗な夜\n悲しみが悲しみで終わると疑わぬように\u3000神様は僕に\u3000夢を見させた\n\n今開いていたページの上に描いてみようかな\n「離さないよ\u3000繋いでたいの\u3000僕は僕の手を」\n\n今止まっていた景色が動き出した気がしたんだよ\nほら\u3000僕の鼓動も確かに刻み始めた4拍子\n\n不器用な僕も描き出してみるよ\u3000終わりに向かってゆく明日を\n笑って迎える意味を。\n\n\n今まで僕がついた嘘と\u3000今まで僕が言ったホント\nどっちが多いか怪しくなって\u3000探すのやめた\n\n自分の中の嫌いなところ\u3000自分の中の好きなところ\nどっちが多いかもう分かってて\u3000悲しくなった\n\nどうせいつかは嫌われるなら\u3000愛した人に憎まれるなら\nそうなる前に僕の方から嫌った\u3000僕だった\n\nだけどいつかは誰かを求め\u3000愛されたいとそう望むなら\nそうなる前に僕の方から\u3000愛してみてよと\n\n君があまりにも綺麗に泣くから\u3000僕は思わず横で笑ったよ\nすると君もつられて笑うから\u3000僕は嬉しくて\u3000泣く 泣く \n\n明日を呪う人間不信者は 明日を夢見る人間信者に \nもう昨日を探してた 僕はいない いない\n\n君は人間洗浄機\u3000この機会に\u3000どのご家庭にも\n一つは用意して頂きたい\nこりゃ買わない手はない\u3000嘘ではない\n驚くべき効果を発揮します\u3000新しい自分に出会えます\nただ中毒性がございます\u3000用法・用量をお守りください\n\nこんなキャッチフレーズを書こう\nやっとこさ君のクローンが\u3000成功した時にでも\nだって君は世界初の\u3000肉眼で確認できる愛\n地上で唯一出会える神様\n\n誰も端っこで泣かないようにと\n君は地球を丸くしたんだろう？\nだから君に会えないと僕は\u3000隅っこを探して泣く\u3000泣く\n誰も命無駄にしないようにと\u3000君は命に終わり作ったよ\nだから君がいないその時は\u3000僕は息を止め\u3000待つ\n\nするとね君は\u3000いつでもここに来てくれたのに\nもうここにいない\u3000いない\n\n明日を夢見た人間信者は\u3000明日の死を待つ自殺志願者に\n３分前の僕が\u3000また顔を出す\n\n息を止めると心があったよ\u3000そこを開くと君がいたんだよ\n左心房に君が居るから\u3000問題はない\u3000ない\u3000ないよね\n\n２秒前までの自殺志願者を\u3000君は永久幸福論者に\n変えてくれた\u3000そんな君はもういない\u3000いない\u3000いない\u3000いないけど…\n\nこの心臓に君がいるんだよ\u3000全身に向け脈を打つんだよ\n今日も生きて\u3000今日も生きて\u3000そして今のままでいてと\n白血球、赤血球、その他諸々の愛を僕に送る。\n\n\n今がその時だともう気付いてたんだ\n光り方は教わらずとも知っていた\n眼の前の現在がもうすでに 思い出色していた\n\n奇跡は起こるもんじゃなくて起こすものだと\n手当たり次第ボタンがあれば連打した\n『今』 がすり切れるくらいに生きて ...

# %%
text = str(text)

# %%
text
# Out:
# "一人のために描いた夢を 誰かに使いまわした\nそんなこともあるさと笑える僕も きっとセプテンバー\n\n『夏』ってだけでキラキラしてた あの気持ちが好きなの\n「もう少しだけここにいさせて」そんな顔で僕見るの\n\nでも君が笑える理由なら 僕が見つけてきてあげる\nこんな二人を繋ぐのは きっとなんでもないセプテンバー\n\n本物よりもリアルに見えた あの魔法はもう解けた\nけどギュっとすればキュンとなるあれは 夏のおかげなんかじゃない\n\n湿る空が乾く色を きっとパパは探していたの\nそんな時に一人ぽつんと疼くまってたセプテンバー\n\nOH セプテンバー OH セプテンバー\nOH セプテンバー OH セプテンバー\n\n夢が語りつくした希望を 僕は拾うよ 君は見てるの?\nさぁ今ならば この声ならば届く気がしたんだ\n\n夏がちらかしてった心を 僕は紡ぐよ さぁいざ行こう\nそう今だから この声だから 響くセプテンバー\n\n声が響きだす そこに意味はなくとも\n君が笑い出す そこに夏はいなくとも\n\nOH セプテンバー OH セプテンバー\nOH セプテンバー OH セプテンバー\n\n僕が笑える理由なら 今まさに目の前にいるよ\nこんな僕らをつなぐのは そうさいつも\n\n愛が語り尽くした想いを 僕は歌うよ 人は笑うよ\nでも今ならば この声ならば届く気がしたんだ\n\n手と手をとれば揺れる心が 抱えた不思議 それはテレパシー\nさぁ今だから この声だから さぁ今ならば この声ならば\n\nこんな僕だけど そう君となら 何もないけれど そう今ならば\nこの声ならば そう君となら 響く気がしたんだ\n\nあぁこの季節(とき)が 語るもの\nあぁこの季節(とき)が 繋ぐもの。\n\n\nいいんですか\u3000いいんですか\nこんなに人を好きになっていいんですか?\nいいんですか\u3000いいんですか\nこんなに人を信じてもいいんですか?\n\n大好物はね\u3000鳥の唐揚げ\n更に言えばうちのおかんが作る鳥のアンかけ\nでもどれも勝てない\u3000お前にゃ敵わない\u3000\nお前がおかずならば俺はどんぶりで50杯は\n軽くご飯おかわりできるよ\u3000だけども\u3000んなこと言うと\n「じゃあやってみて」とかってお前は言いだすけど\u3000\nそれはあくまでも例えの話でありまして\u3000\nだどもやれと言われりゃ\u3000おいどんも男なわけで\n富良野は寒いわけで\u3000お前が好きなわけで\nちょびっとでも分かってもらいたいわけで\u3000\nちなみに、オカズって\u3000変な意味じゃないんで 嫌いにならないでね\n\nいいんですか\u3000いいんですか\nこんなに人を好きになっていいんですか?\nいいんですか\u3000いいんですか\nこんなに人を信じてもいいんですか?\n\nいいんですよ\u3000いいんですよ\u3000あなたが選んだ人ならば\nいいんですよ\u3000いいんですよ\u3000あんたが選んだ道ならば\n\n今まで俺は何回お前を泣かせたんだろう\nそれに比べて何回笑わせてやれたんだろう\n\n更には嬉し泣きっていう合わせ技もお前は\n持ち合わせているから余計分かんなくなんだよ\n\n「ごめんね」と「ありがとう」を繰り返せばいいんだよ\nその比率は五分と五分に限りなく近いけど\n例えば999999回ずつで最期の\u3000瞬間を迎えたとしよう\n「ありがとう」の勝ちはもう間違いない\n必ずや到達するよ1000000回\nだってさ\u3000だってさ\u3000だってだってだってさ\nだって俺のこの世の最期の言葉はあなたに言う「ありがとう」\n\nいいんですか\u3000いいんですか\nこんなに人を好きになっていいんですか?\nいいんですか\u3000いいんですか\nこんなにのめりこんじゃっていいんですか?\n\nいいんですよ\u3000いいんですよ\u3000あなたが望んだ人ならば\nいいんですよ\u3000いいんですよ\u3000あなたが望んだ道ならば\n\nあなたといる意味を探したら\u3000明日を生きる答えになったよ\n明日を生きる意味を探したら\u3000あなたといる答えになったよ\n\nいいんですか\u3000いいんですか\nこんなに人を好きになっていいんですか?\nいいんですか\u3000いいんですか\nこんなに人を信じてもいいんですか?\n\nいいんですよ\u3000いいんですよ\u3000あなたが愛した人ならば\nいいんですよ\u3000いいんですよ\n\nいいんですか\u3000いいんですか\nこんなに人を好きになっていいんですか?\nいいんですか\u3000いいんですか\nこんなに人を信じてもいいんですか?\n\nいいんですよ\u3000いいんですよ\u3000あなたが選んだ人ならば\nいいんですよ\u3000いいんですよ\u3000むしろそうであって欲しいんですよ\n\nいいんですか\u3000いいんですか\nこんなに人を好きになっていいんですか?\nいいんですよ\u3000いいんですよ\nあなたが選んだ人ならば\nあなたが愛した人ならば\nあなたが望んだ人ならば。\n\n\n満天の空に君の声が響いてもいいような綺麗な夜\n悲しみが悲しみで終わらぬよう\u3000せめて地球は周ってみせた\n\n本当に伝えたい想いだけはうまく伝わらないようにできてた\nそのもどかしさに抱かれぬよう\u3000せめて僕は笑ってみせた\n\n「何もないんだってここには」って笑ってる君も望んでる\nそんな声もかき消すほどに\u3000膨れるこの万象を\n\n「意味はないんだって僕には」って叫んでる僕も望んでる\n無味を悟る\u3000その先に浮かぶ光の粒を\n\n最近は映画の見すぎで奇跡も珍しくなくなったね\n心にもないことでもすらすら言えるようになったよ\n\nほら\u3000僕が僕から離れてくそんなことさえも忘れたくなる\n「真実とはねそれだけで美しいんだ」と\u3000言って\n\n満天の空に君の声が響いてもいいような綺麗な夜\n悲しみが悲しみで終わると疑わぬように\u3000神様は僕に\u3000夢を見させた\n\n今開いていたページの上に描いてみようかな\n「離さないよ\u3000繋いでたいの\u3000僕は僕の手を」\n\n今止まっていた景色が動き出した気がしたんだよ\nほら\u3000僕の鼓動も確かに刻み始めた4拍子\n\n不器用な僕も描き出してみるよ\u3000終わりに向かってゆく明日を\n笑って迎える意味を。\n\n\n今まで僕がついた嘘と\u3000今まで僕が言ったホント\nどっちが多いか怪しくなって\u3000探すのやめた\n\n自分の中の嫌いなところ\u3000自分の中の好きなところ\nどっちが多いかもう分かってて\u3000悲しくなった\n\nどうせいつかは嫌われるなら\u3000愛した人に憎まれるなら\nそうなる前に僕の方から嫌った\u3000僕だった\n\nだけどいつかは誰かを求め\u3000愛されたいとそう望むなら\nそうなる前に僕の方から\u3000愛してみてよと\n\n君があまりにも綺麗に泣くから\u3000僕は思わず横で笑ったよ\nすると君もつられて笑うから\u3000僕は嬉しくて\u3000泣く 泣く \n\n明日を呪う人間不信者は 明日を夢見る人間信者に \nもう昨日を探してた 僕はいない いない\n\n君は人間洗浄機\u3000この機会に\u3000どのご家庭にも\n一つは用意して頂きたい\nこりゃ買わない手はない\u3000嘘ではない\n驚くべき効果を発揮します\u3000新しい自分に出会えます\nただ中毒性がございます\u3000用法・用量をお守りください\n\nこんなキャッチフレーズを書こう\nやっとこさ君のクローンが\u3000成功した時にでも\nだって君は世界初の\u3000肉眼で確認できる愛\n地上で唯一出会える神様\n\n誰も端っこで泣かないようにと\n君は地球を丸くしたんだろう？\nだから君に会えないと僕は\u3000隅っこを探して泣く\u3000泣く\n誰も命無駄にしないようにと\u3000君は命に終わり作ったよ\nだから君がいないその時は\u3000僕は息を止め\u3000待つ\n\nするとね君は\u3000いつでもここに来てくれたのに\nもうここにいない\u3000いない\n\n明日を夢見た人間信者は\u3000明日の死を待つ自殺志願者に\n３分前の僕が\u3000また顔を出す\n\n息を止めると心があったよ\u3000そこを開くと君がいたんだよ\n左心房に君が居るから\u3000問題はない\u3000ない\u3000ないよね\n\n２秒前までの自殺志願者を\u3000君は永久幸福論者に\n変えてくれた\u3000そんな君はもういない\u3000いない\u3000いない\u3000いないけど…\n\nこの心臓に君がいるんだよ\u3000全身に向け脈を打つんだよ\n今日も生きて\u3000今日も生きて\u3000そして今のままでいてと\n白血球、赤血球、その他諸々の愛を僕に送る。\n\n\n今がその時だともう気付いてたんだ\n光り方は教わらずとも知っていた\n眼の前の現在がもうすでに 思い出色していた\n\n奇跡は起こるもんじゃなくて起こすものだと\n手当たり次第ボタンがあれば連打した\n『今』 がすり切れるくらいに生きて ...

# %%
chars = sorted(list(set(text)))
print('Total chars:', len(chars))
# Out:
# Total chars: 610

# %%
char_indices = dict((c,i) for i,c in enumerate(chars))

# %%
indices_char = dict((i,c) for i,c in enumerate(chars))

# %%
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])

# %%
print('Number of sentences: ',len(sentences))
# Out:
# Number of sentences:  2306

# %%
# テキストのベクトル化
X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

# %%
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1

# %%
# モデルを定義する
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))
optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
for iteration in range(1,120):
    print()
    print('-' *50)
    print('繰り返し回数: ', iteration)
    model.fit(X, y, batch_size=128, epochs=1)
    
    start_index = random.randint(0, len(text)-maxlen-1)

    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print()
        print('-----diveristy', diversity)
    
        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Seedを生成しました: "' + sentence + '"')
        sys.stdout.write(generated)
    
        for i in range(100):
            x = np.zeros((1,maxlen,len(chars)))
            for t, char in enumerate(sentence):
                x[0, t, char_indices[char]] = 1.
            
            preds = model.predict(x, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]
        
            generated += next_char
            sentence = sentence[1:] + next_char
        
            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# --------------------------------------------------
# 繰り返し回数:  1
# Epoch 1/1
# 2306/2306 [==============================] - 8s 3ms/step - loss: 0.0014
#
# -----diveristy 0.2
# ----- Seedを生成しました: "
# そんな時に一人ぽつんと疼くまってたセプテンバー
#
# OH セプテンバー OH セ"
#
# そんな時に一人ぽつんと疼くまってたセプテンバー
#
# OH セプテンバー OH セプテンバー
#
# 『く気がる救界だよ想らば
# いいんですか　いいんですか
# こんなに人を信じゃもいんですか?
#
# 大いいですよ　あないころうに今もないこと
#
#
# 二人を信じゃもいんですか?
#
# 大いいですよ　あない
#
# -----diveristy 0.5
# ----- Seedを生成しました: "
# そんな時に一人ぽつんと疼くまってたセプテンバー
#
# OH セプテンバー OH セ"
#
# そんな時に一人ぽつんと疼くまってたセプテンバー
#
# OH セプテンバー OH セプテンバー
#
# 『くれるよ
#
# いいた
# ようにい笑いだけよう
#
# いいんですよ　いいんですよ　あならけ後にせから
# あったと　空意手を繋ぐばった一つここに来じゃもうど　今日は　そのもの先にもかをと
# 君は命のは
#
# -----diveristy 1.0
# ----- Seedを生成しました: "
# そんな時に一人ぽつんと疼くまってたセプテンバー
#
# OH セプテンバー OH セ"
#
# そんな時に一人ぽつんと疼くまってたセプテンバー
#
# OH セプテンバー OH セプテンバー
#
# 『 くから
#
# 遥い出がした気が笑 あの魔ここににも染てらぬをましだ
#
# oいいいいんですか　いいんですか
# こんなに人を信じももいんでわか?
#
# 大した一させかが　いいんですか
# こんなに人を信
#
# -----diveristy 1.2
# ----- Seedを生成しました: "
# そんな時に一人ぽつんと疼くまってたセプテンバー
#
# OH セプテンバー OH セ"
#
# そんな時に一人ぽつんと疼くまってたセプテンバー
#
# OH セプテンバー OH セプテンバー
#
# 『ぁこのもたにけ聖た一僕らばはう少しだけくいようにいなんですよ　いいんですよ　あなんでは　いいんですか
# こんなに人を信じいもいいんでわか?
#
# 大したは拾だけでにいないいのはに まってみて
#
# --------------------------------------------------
# 繰り返し回数:  2
# Epoch 1/1
# 2306/2306 [==============================] - 7s 3ms/step - loss: 0.0017
#
# -----diveristy 0.2
# ----- Seedを生成しました: "吐いてWednesday
# やってらんねぇってなっても
# Saturday Sund"
# 吐いてWednesday
# やってらんねぇってなっても
# Saturday Sunday
# 笑　wiclllleeenうに　「ね語eって笑われるよ　いいんですよ　あなたと選は命」きる前が笑わから　歌うたと　隙つこえに目膨ように
# 僕が笑顔のはない　嘘れ　なく人を信じゃもいんですか?
#
# い
#
# -----diveristy 0.5
# ----- Seedを生成しました: "吐いてWednesday
# やってらんねぇってなっても
# Saturday Sund"
# 吐いてWednesday
# やってらんねぇってなっても
# Saturday Sundanetsaide anone anone lide anone saide anone ano teryっていると まらをもう少しだけくいいか
#
#
# よう少しだけでいいか
#
# あなっと　手当を僕は見てて
#
# -----diveristy 1.0
# ----- Seedを生成しました: "吐いてWednesday
# やってらんねぇってなっても
# Saturday Sund"
# 吐いてWednesday
# やってらんねぇってなっても
# Saturday Sunday
# 笑のですか　あな気がキいだかったよ
#
# いつない出がう少しだけでいいか
# いいんですか　いいんですか
# こんなに人を信じももいんですか?
#
# いいんですよ　あながいいですよ
# いいんですよ　あないこ
#
#
#
# -----diveristy 1.2
# ----- Seedを生成しました: "吐いてWednesday
# やってらんねぇってなっても
# Saturday Sund"
# 吐いてWednesday
# やってらんねぇってなっても
# Saturday Sundayい笑 wを時eせけるよ
# 何にも染ままし何
# きて笑う
# すからいいんですか
# こんなに人を信じゃもいんでるか?
#
# いなんですよ　あないこんなに人を信じゃもいんで屋か?
#
# いいんですよ　あないけそうせめい
#
# --------------------------------------------------
# 繰り返し回数:  3
# Epoch 1/1
# 2306/2306 [==============================] - 9s 4ms/step - loss: 7.5641e-04
#
# -----diveristy 0.2
# ----- Seedを生成しました: "いたりしたそのあとの空は やけに透き通っていたりしたんだ
#
# いつもは尖ってた父の"
# いたりしたそのあとの空は やけに透き通っていたりしたんだ
#
# いつもは尖ってた父の言え　だけでい富もういから　うない　いないけれう　僕をてるそんだと僕らば
#
# いいんですか　いいんですか
# こんなに人を信じゃもいんですか?
#
# いいんですよ　あないこ
#
# あながこともういいか?
#
# どってみ
#
# -----diveristy 0.5
# ----- Seedを生成しました: "いたりしたそのあとの空は やけに透き通っていたりしたんだ
#
# いつもは尖ってた父の"
# いたりしたそのあとの空は やけに透き通っていたりしたんだ
#
# いつもは尖ってた父の言え　だけでい　のいと　もう少しだけでいいか
#
# あないこと言いいんですか　いいんですか
# こんなに人を信じももいんですか?
#
# 大れた顔になって笑いんですか
# こんなに人を信じももいんですか?
#
# いいんです
#
# -----diveristy 1.0
# ----- Seedを生成しました: "いたりしたそのあとの空は やけに透き通っていたりしたんだ
#
# いつもは尖ってた父の"
# いたりしたそのあとの空は やけに透き通っていたりしたんだ
#
# いつもは尖ってた父の言え　僕は見て泣ってる　待って
# 白のやか　腑したんだ
# 手んない人いたんだよ
# 左ボ腑い　しがんですか
# こんなに人を信じうもいんでもか?
#
# 大させようにまって君はんだすからいきに
#
# 愛あないここにもういい
#
# -----diveristy 1.2
# ----- Seedを生成しました: "いたりしたそのあとの空は やけに透き通っていたりしたんだ
#
# いつもは尖ってた父の"
# いたりしたそのあとの空は やけに透き通っていたりしたんだ
#
# いつもは尖ってた父の言え　だは命は言から頑した人を信じゃもいんですか?
#
# 大　たと僕らば
#
# あのなに人を信じゃもいんでいか?
#
# いいんですよ　あないけどいせ
# いいんですよ　あならけいう」
# 夜
# いいんですか　愛いんなじと
#
#
# --------------------------------------------------
# 繰り返し回数:  4
# Epoch 1/1
# 2306/2306 [==============================] - 8s 3ms/step - loss: 0.0068
#
# -----diveristy 0.2
# ----- Seedを生成しました: "君がいないその時は　僕は息を止め　待つ
#
# するとね君は　いつでもここに来てくれた"
# 君がいないその時は　僕は息を止め　待つ
#
# するとね君は　いつでもここに来てくれたにならば
#
# いいんですよ　いいんですよ　今いいいい
#
#
# 愛しがいいけでいよ
#
# いいんですよ　あないころですか
# こんなに人を信じももいいんですか?
#
# 大いいですよ　あないころうに人を信じももいいんですか
#
# -----diveristy 0.5
# ----- Seedを生成しました: "君がいないその時は　僕は息を止め　待つ
#
# するとね君は　いつでもここに来てくれた"
# 君がいないその時は　僕は息を止め　待つ
#
# するとね君は　いつでもここに来てくれたにならば
#
# いいんですよ　いいんですよ　今いいいい
#
#
# 愛した 僕にもないいいい
#
#
#
# 聖が語このは　膨を待の手を繋ぐにもっていいんですか
# こんなに人を信じももいいんですか?
#
# 大いいですよ　あないこ
#
# -----diveristy 1.0
# ----- Seedを生成しました: "君がいないその時は　僕は息を止め　待つ
#
# するとね君は　いつでもここに来てくれた"
# 君がいないその時は　僕は息を止め　待つ
#
# するとね君は　いつでもここに来てくれたになるないいんだ
#
# た一つこいいでいいんですか
# こんなく人を信じゃもいいんですか?
#
# いいんですよ　あないこ
# ないけはないいいですか　たいけどですから余いどれるわから　愛した人を信じてもいいんでわか?
#
# -----diveristy 1.2
# ----- Seedを生成しました: "君がいないその時は　僕は息を止め　待つ
#
# するとね君は　いつでもここに来てくれた"
# 君がいないその時は　僕は息を止め　待つ
#
# するとね君は　いつでもここに来てくれたいとと
#
# いいんですよ　いいんですよ　あないころです
#
# いいいですよ　いいんですよ　今ないこのは」からばくてる限いたんだろう
# そんな顔巻いいとは　球ははうのりが　夏がめの　知　りないくて
#
# 僕らならば
#
# --------------------------------------------------
# 繰り返し回数:  5
# Epoch 1/1
# 2306/2306 [==============================] - 7s 3ms/step - loss: 0.0093
#
# -----diveristy 0.2
# ----- Seedを生成しました: "立ち止まってみたければ 時速1400キロの速さで
# 精一杯地球逆廻りに 走らないと"
# 立ち止まってみたければ 時速1400キロの速さで
# 精一杯地球逆廻りに 走らないとと
#
#
# 大う少しだけでいいか
#
# あないこと僕らば
# いいんですか　いいんですか
# こんなに人を信じいいいんですか?
#
# 大いいですか　いいんですか
# こんなに人を信じいもいいんでわか?
#
# 大いいですよ　あない
#
# -----diveristy 0.5
# ----- Seedを生成しました: "立ち止まってみたければ 時速1400キロの速さで
# 精一杯地球逆廻りに 走らないと"
# 立ち止まってみたければ 時速1400キロの速さで
# 精一杯地球逆廻りに 走らないとと
#
# いいんですか　いいんですか
# こんなに人を信じいいいんですか?
#
# 大いいですか　いいんですか
# こんなに人を信じいもいいんでわか?
#
# 大いいですよ　あないけでいよ
#
# いいんですよ　あないけ後ですか
#
#
# -----diveristy 1.0
# ----- Seedを生成しました: "立ち止まってみたければ 時速1400キロの速さで
# 精一杯地球逆廻りに 走らないと"
# 立ち止まってみたければ 時速1400キロの速さで
# 精一杯地球逆廻りに 走らないとと
#
# 大うで きるとパるは探
# 僕の聖の声を見つかってしてるんだ
# 僕が笑けでい後のものは言えのは　空しだけで　この機　いつもいいよう　いいんですよ　あないけどいんですか
# こんなに人を信じいもいいんでわか
#
# -----diveristy 1.2
# ----- Seedを生成しました: "立ち止まってみたければ 時速1400キロの速さで
# 精一杯地球逆廻りに 走らないと"
# 立ち止まってみたければ 時速1400キロの速さで
# 精一杯地球逆廻りに 走らないとと
#
# いいんですよ　いいんですよ　あないけどい更いよ　あないころうにってもういわか?
#
# どっていいんですか
# こんなに人を信じいもいんですか?
#
# いいんですか　いいんですか
# こんなに人を信じなもいパんで
#
# --------------------------------------------------
# 繰り返し回数:  6
# Epoch 1/1
# 2306/2306 [==============================] - 8s 4ms/step - loss: 0.0049
#
# -----diveristy 0.2
# ----- Seedを生成しました: "ういうつもりなの?
#
# どれだけ頭を垂れ 歩いてみても未来に
# すぐに見つかってしま"
# ういうつもりなの?
#
# どれだけ頭を垂れ 歩いてみても未来に
# すぐに見つかってしまうんだと僕が　知は　とと言は言の声を見つかった
#
# 今ま　やっぱていそんですか　いいんですか
# こんなに人を信じいもいいんでわか?
#
# いいんですよ　あなっこ選んだ人を信じゃもいいんですか?
#
# いいんですよ
#
# -----diveristy 0.5
# ----- Seedを生成しました: "ういうつもりなの?
#
# どれだけ頭を垂れ 歩いてみても未来に
# すぐに見つかってしま"
# ういうつもりなの?
#
# どれだけ頭を垂れ 歩いてみても未来に
# すぐに見つかってしまうんだと僕らを繋ぐと　君は見つけれくれるよ
#
#
# いいでいいもうい　れることと　知い越しててもういい　そんできるしてっていいか
#
# いいんですか　いいんですか
# こんなに人を信じいもいいんでわか?
#
# 大いい
#
# -----diveristy 1.0
# ----- Seedを生成しました: "ういうつもりなの?
#
# どれだけ頭を垂れ 歩いてみても未来に
# すぐに見つかってしま"
# ういうつもりなの?
#
# どれだけ頭を垂れ 歩いてみても未来に
# すぐに見つかってしまうんだ。
#
#
# あないこの先にもない　知い　いないけでいそんですか
# こんなに人を信じい越いんですか?
#
# 大いいですよ　あなっこ・いいんですよ　あなんですよ　いいんですよ　投ないけはできいる
#
# あなないけ
#
# -----diveristy 1.2
# ----- Seedを生成しました: "ういうつもりなの?
#
# どれだけ頭を垂れ 歩いてみても未来に
# すぐに見つかってしま"
# ういうつもりなの?
#
# どれだけ頭を垂れ 歩いてみても未来に
# すぐに見つかってしまんだ人を信じゃもいいんですか?
#
# 大ない　嘘nならば
#
# あなっと僕に  僕を探う
# いいんですか　いいんですか
# こんなに人を信じい越いんですか?
#
# いいんですよ　あなっと選んだ人を信じゃもいいんですか?
#
# --------------------------------------------------
# 繰り返し回数:  7
# Epoch 1/1
# 2306/2306 [==============================] - 7s 3ms/step - loss: 0.0013
#
# -----diveristy 0.2
# ----- Seedを生成しました: "本当に伝えたい想いだけはうまく伝わらないようにできてた
# そのもどかしさに抱かれぬ"
# 本当に伝えたい想いだけはうまく伝わらないようにできてた
# そのもどかしさに抱かれぬれと言を見つから
# あなっと僕手当」
#
# いいいですか　いいんですか
# こんなに人を信じいもいんですか?
#
# いいんですよ　あなっと選んだ人を信じゃもいいんですか?
#
# いいんですよ　あなっと選んだ人を信じゃも
#
# -----diveristy 0.5
# ----- Seedを生成しました: "本当に伝えたい想いだけはうまく伝わらないようにできてた
# そのもどかしさに抱かれぬ"
# 本当に伝えたい想いだけはうまく伝わらないようにできてた
# そのもどかしさに抱かれぬれと言知らせた
# だんやりが望を探ったホいんですか
# こんなに人を信じいもいいんでわか?
#
# いいんですよ　あなっこ選んだ人を信じゃもいいんですか?
#
# いいんですよ　あなっと選んだ人を信じゃもいいんですか?
#
# -----diveristy 1.0
# ----- Seedを生成しました: "本当に伝えたい想いだけはうまく伝わらないようにできてた
# そのもどかしさに抱かれぬ"
# 本当に伝えたい想いだけはうまく伝わらないようにできてた
# そのもどかしさに抱かれぬれの声のや　だ
# あとが　知つもいいか　?」を信じゃもいんですか
# こんなに人を信じいもいいんでわか?
#
# いいんですよ　あなんですよ　あなっこ選んだ人を信じゃもいんですか?
#
# いいんですか　いいんですか
#
#
# -----diveristy 1.2
# ----- Seedを生成しました: "本当に伝えたい想いだけはうまく伝わらないようにできてた
# そのもどかしさに抱かれぬ"
# 本当に伝えたい想いだけはうまく伝わらないようにできてた
# そのもどかしさに抱かれぬれに愛れるクいとから
#
# あながと僕手を」ってもいいんですか
# こんなに人を信じい越いんですか?
#
# いいんですよ　あなっこ選んだ人を信じゃもいんですか?
#
# いいんですか　いいんですか
# こんなに人を信じいて
#
# --------------------------------------------------
# 繰り返し回数:  8
# Epoch 1/1
# 2306/2306 [==============================] - 9s 4ms/step - loss: 0.0010
#
# -----diveristy 0.2
# ----- Seedを生成しました: "かく感じました
# 優しさも笑顔も夢の語り方も　知らなくて全部　君を真似たよ
#
# もう"
# かく感じました
# 優しさも笑顔も夢の語り方も　知らなくて全部　君を真似たよ
#
# もう少しだけでいいか
#
# あないことどう　僕が受けでいいか
#
# あないこと　僕は嬉してていいんですか
# こんなに人を信じい越いんですか?
#
# いいんですよ　あないこ選に人を信じいもいいんでわか?
#
# いいんですよ
#
# -----diveristy 0.5
# ----- Seedを生成しました: "かく感じました
# 優しさも笑顔も夢の語り方も　知らなくて全部　君を真似たよ
#
# もう"
# かく感じました
# 優しさも笑顔も夢の語り方も　知らなくて全部　君を真似たよ
#
# もう少しだけでいいか
#
# あないことどう　僕が受けでいいか　?」を探したらすか　いいんですか　いいんですか
# こんなに人を信じい越いんですか?
#
# いいんですよ　あないこ選んですよ　あないけですよ　あなってけた
#
# -----diveristy 1.0
# ----- Seedを生成しました: "かく感じました
# 優しさも笑顔も夢の語り方も　知らなくて全部　君を真似たよ
#
# もう"
# かく感じました
# 優しさも笑顔も夢の語り方も　知らなくて全部　君を真似たよ
#
# もう少しだけでいいか
#
# あない　溢るる前の
#
# 遥のあと　空にですか
# この声のらば
# う声「更愛う」って笑うですよ　あないころうに一杯
# だ聖に僕らを見て
# 君の声から待きてる
#
# 負がったとす　るあながと望」を
#
# -----diveristy 1.2
# ----- Seedを生成しました: "かく感じました
# 優しさも笑顔も夢の語り方も　知らなくて全部　君を真似たよ
#
# もう"
# かく感じました
# 優しさも笑顔も夢の語り方も　知らなくて全部　君を真似たよ
# もう少しだけでいいか
#
# あない　嘘君のない　いないけれうせたらする前に僕の見て
# きるとな分から
#
# 遥い今です　そんですか
# こんなに人を信じい越いいんで男か?
#
# いいんですよ　あなっこ選んでもないいれ
# いつ
#
# --------------------------------------------------
# 繰り返し回数:  9
# Epoch 1/1
# 2306/2306 [==============================] - 9s 4ms/step - loss: 0.0012
#
# -----diveristy 0.2
# ----- Seedを生成しました: "んでる僕も望んでる
# 無味を悟る　その先に浮かぶ光の粒を
#
# 最近は映画の見すぎで奇"
# んでる僕も望んでる
# 無味を悟る　その先に浮かぶ光の粒を
#
# 最近は映画の見すぎで奇この声
#
# いいんですよ　いいんですよ　あなたと望はをくてるかってていいんですか
# こんなに人を信じいもいいんでわか?
#
# いいんですよ　あなっこ選んだ人を信じゃもいいんですか?
#
# いいんですよ　あなっこ選
#
# -----diveristy 0.5
# ----- Seedを生成しました: "んでる僕も望んでる
# 無味を悟る　その先に浮かぶ光の粒を
#
# 最近は映画の見すぎで奇"
# んでる僕も望んでる
# 無味を悟る　その先に浮かぶ光の粒を
#
# 最近は映画の見すぎで奇こいですからば
#
# あのなに　僕を見る
#
# 何にものいいか
#
# 愛した僕らば
# いいんですか　いいんですか
# こんなに人を信じいもいいんでわか?
#
# いいんですよ　あなっこ選んだ人を信じゃもいいんですか?
#
# い
#
# -----diveristy 1.0
# ----- Seedを生成しました: "んでる僕も望んでる
# 無味を悟る　その先に浮かぶ光の粒を
#
# 最近は映画の見すぎで奇"
# んでる僕も望んでる
# 無味を悟る　その先に浮かぶ光の粒を
#
# 最近は映画の見すぎで奇このあなくととを
# 君の命ない　世界など　夏は鳥の声だからば
#
# あの日の　をれつないとい
# いいんですか　いいんですか
# こんなに人を信じいいいんでわか?
#
# 大ない　嘘僕ならば
# いいんですか　いいんですか
#
#
# -----diveristy 1.2
# ----- Seedを生成しました: "んでる僕も望んでる
# 無味を悟る　その先に浮かぶ光の粒を
#
# 最近は映画の見すぎで奇"
# んでる僕も望んでる
# 無味を悟る　その先に浮かぶ光の粒を
#
# 最近は映画の見すぎで奇このばと　知しがいいんですか　いいんですか
# こんなに人を信じいいいんでわか?
#
# いいんですよ　あなんですよ　あならで選んだ人を信じゃもいいんですか?
#
# いいんですよ　あなんですよ　あなんですよ　あなん
#
# --------------------------------------------------
# 繰り返し回数:  10
# Epoch 1/1
# 2306/2306 [==============================] - 7s 3ms/step - loss: 9.4674e-04
#
# -----diveristy 0.2
# ----- Seedを生成しました: "ととか知らないの?
# もうどういうつもりなの?
#
# どれだけ頭を垂れ 歩いてみても未"
# ととか知らないの?
# もうどういうつもりなの?
#
# どれだけ頭を垂れ 歩いてみても未
#
#
# れいいですか　いいんですか
# この声の手を繋ぐにも溶いいよ
#
#
# いいんですよ　あなんですか
# この言え　いいんですか
# こんなに人を信じゃもいいんでわかmo
#
# 僕が笑のですか　あなが　知いいいよ
#
#
#
#
# -----diveristy 0.5
# ----- Seedを生成しました: "ととか知らないの?
# もうどういうつもりなの?
#
# どれだけ頭を垂れ 歩いてみても未"
# ととか知らないの?
# もうどういうつもりなの?
#
# どれだけ頭を垂れ 歩いてみても未から
#
# れないですか　いいんですか
# こんなに人を信じゃもいいんでわかm
#
# 僕が笑のなすか
# この声のらば追い越したんだ
# 。
#
#
# あががと　手当クないいか
#
# 遥い出した
#
# だった 僕が受けですかて
#
# いい
#
# -----diveristy 1.0
# ----- Seedを生成しました: "ととか知らないの?
# もうどういうつもりなの?
#
# どれだけ頭を垂れ 歩いてみても未"
# ととか知らないの?
# もうどういうつもりなの?
#
# どれだけ頭を垂れ 歩いてみても未か
#
#
# れないですか　たいすか　いいんですか
# この声のらば
#
# 今ま　届少しだけくいよう
#
# いいでもたいよう　いいんですよ　いいんですよ　あなたと望はない越したんだ。
#
#
# いいいですよ　今なたが望いだか
#
# -----diveristy 1.2
# ----- Seedを生成しました: "ととか知らないの?
# もうどういうつもりなの?
#
# どれだけ頭を垂れ 歩いてみても未"
# ととか知らないの?
# もうどういうつもりなの?
#
# どれだけ頭を垂れ 歩いてみても未g sをan
#
# 今　想も出がるう望だけ後たそんなに人を信じいもいもう
#
# いいどもいいんですか?
#
# いいんですよ　あなんですよ　あな気が杯った僕に」って笑れんだよ
#
# いいんでする　いいんですか
# こい今も
#
# --------------------------------------------------
# 繰り返し回数:  11
# Epoch 1/1
# 2306/2306 [==============================] - 7s 3ms/step - loss: 0.0117
#
# -----diveristy 0.2
# ----- Seedを生成しました: "ように　神様は僕に　夢を見させた
#
# 今開いていたページの上に描いてみようかな
# 「"
# ように　神様は僕に　夢を見させた
#
# 今開いていたページの上に描いてみようかな
# 「いいんですよ　あないけでいよ
# あと君は命くれるしていいんですか
# こんなに人を信じももいいんでわか?
#
# いいんですよ　あなんですよ　あなしが選んだ人を信じゃもいいんですか?
#
# いいんですよ　あなんですよ
#
# -----diveristy 0.5
# ----- Seedを生成しました: "ように　神様は僕に　夢を見させた
#
# 今開いていたページの上に描いてみようかな
# 「"
# ように　神様は僕に　夢を見させた
#
# 今開いていたページの上に描いてみようかな
# 「いいんですよ　あないけでいよ
# あと君は命り何からぬえになってみているか
#
# 僕が笑のなるといようか
#
# 僕らもないいんですか　いいんですか
# こんなに人を信じたもいいんですか?
#
# いいんですよ　あなんですよ
#
# -----diveristy 1.0
# ----- Seedを生成しました: "ように　神様は僕に　夢を見させた
#
# 今開いていたページの上に描いてみようかな
# 「"
# ように　神様は僕に　夢を見させた
#
# 今開いていたページの上に描いてみようかな
# 「いいんですよ　いいんですよ　あないけですよ　あないころうにってないいんですか
# こんなに人を信じゃもいいんで未う気が救bだよう　いここどにもめてるクて
#
# だけでいいもうい後から　それをときると心を 繋う
#
# -----diveristy 1.2
# ----- Seedを生成しました: "ように　神様は僕に　夢を見させた
#
# 今開いていたページの上に描いてみようかな
# 「"
# ように　神様は僕に　夢を見させた
#
# 今開いていたページの上に描いてみようかな
# 「ねけつこれとを」って5れるクして
#
# いつか　泣くように
# ってみいいかで
#
# いいんですよ　こんでもた
# 湿にも何にもかしてていわかで
# 僕が笑しですか　いいんですか
# こんなに人を信じももいいんで男か?
#
# い
#
# --------------------------------------------------
# 繰り返し回数:  12
# Epoch 1/1
# 2306/2306 [==============================] - 7s 3ms/step - loss: 0.0149
#
# -----diveristy 0.2
# ----- Seedを生成しました: "t's OK it's OK not even started yet
#
# I h"
# t's OK it's OK not even started yet
#
# I hope you eme anた 僕は派僕の手を
#
# いつか 響いように
# 何にもってもいいんですか
# こんなに人を信じももいいんですか?
#
# いいんですよ　あなっここに来を歌って君いいんですか
# こんなに人を信
#
# -----diveristy 0.5
# ----- Seedを生成しました: "t's OK it's OK not even started yet
#
# I h"
# t's OK it's OK not even started yet
#
# I hopeyou eう
#
# いいんですよ　あなが　くないいいよ
#
#
# 僕が笑しですよ
# あなった一させかがいいんですか　いいんですか
# こんなに人を信じたもいいんですか?
#
# いいんですよ　あなっここを信じゃもいい
#
# -----diveristy 1.0
# ----- Seedを生成しました: "t's OK it's OK not even started yet
#
# I h"
# t's OK it's OK not even started yet
#
# I hope
# you
# 二いいら そう確なに
# 僕のもないから
# いなんだ
# 嫌った一僕ら　もう少しだけでいいかも
# あっない　んだよ　全ない
#
# いいんですよ　んなに 響いいんですよ　んなに
# 仕きに比々を
#
# 君はい
#
# -----diveristy 1.2
# ----- Seedを生成しました: "t's OK it's OK not even started yet
#
# I h"
# t's OK it's OK not even started yet
#
# I hope you
#
#
# 晴れ　空しのやってらいいでも
#
# いいんですよ　こんなに人を信じゃもいいんでわか?
#
# いいんですよ　あなんですよ　あなっこ」をを残いいんですよ　いいんですよ　こんなに人を信じゃもい
#
# --------------------------------------------------
# 繰り返し回数:  13
# Epoch 1/1
# 2306/2306 [==============================] - 9s 4ms/step - loss: 0.0072
#
# -----diveristy 0.2
# ----- Seedを生成しました: "を駆け上がるクライマー
# 時のかくれんぼ　はぐれっこ　はもういいよ
#
# 君は派手なク"
# を駆け上がるクライマー
# 時のかくれんぼ　はぐれっこ　はもういいよ
#
# 君は派手なク　めれるない　世界など　夏が分からば
# いいんですか　いいんですか
# こんなに人を信じももいいんでわか?
#
# 大した
#  mode ano いいlから　」
#
# 晴が　今からば
# 遥う少しだけでっててもう少しだけで
#
# -----diveristy 0.5
# ----- Seedを生成しました: "を駆け上がるクライマー
# 時のかくれんぼ　はぐれっこ　はもういいよ
#
# 君は派手なク"
# を駆け上がるクライマー
# 時のかくれんぼ　はぐれっこ　はもういいよ
#
# 君は派手なクク　wiれるしないこのに
# 僕を見ついてて
#
# いいいかですよ　んな顔
#
# あのやりせと　いつんですか
# こんなに人を信じももいいんですか?
#
# いいんですよ　あなっここを信じゃもいいんでわか?
#
# いいんですよ
#
# -----diveristy 1.0
# ----- Seedを生成しました: "を駆け上がるクライマー
# 時のかくれんぼ　はぐれっこ　はもういいよ
#
# 君は派手なク"
# を駆け上がるクライマー
# 時のかくれんぼ　はぐれっこ　はもういいよ
#
# 君は派手なクク　溢るれるようにだってもたいんですか　こんなに人を信じももいいんですか?
#
# 大ー　歌った 僕が受ならば
#
# あのなに人を信じいんですか?
#
# いいんですよ　あなんですよ　あなっころうに生何を預りぶ多い?
#
# -----diveristy 1.2
# ----- Seedを生成しました: "を駆け上がるクライマー
# 時のかくれんぼ　はぐれっこ　はもういいよ
#
# 君は派手なク"
# を駆け上がるクライマー
# 時のかくれんぼ　はぐれっこ　はもういいよ
#
# 君は派手なクから待めて　そう今ならば
# い今もいたと　特つないこれどしで僕らもの日を待ててて
# 枯うどっと　溢るのる前の空にもうどう何かのやないいよう
# だった君の手を繋のあなっと思議るクれを止めて待って
# 枯いんですか
#
# --------------------------------------------------
# 繰り返し回数:  14
# Epoch 1/1
# 2306/2306 [==============================] - 18s 8ms/step - loss: 0.0162
#
# -----diveristy 0.2
# ----- Seedを生成しました: "に憎まれるなら
# そうなる前に僕の方から嫌った　僕だった
#
# だけどいつかは誰かを求"
# に憎まれるなら
# そうなる前に僕の方から嫌った　僕だった
#
# だけどいつかは誰かを求め　だっててもうどれと　をてもういか
# だった君の手の言えた
#
# 遥う少しだけでいいかも
# ど　鳥の声ものは」
#
# いいんですよ　んなに
#
# いいんですよ　んなに
#
# いいんですよ　んなに
#
# いいんですよ　んな
#
# -----diveristy 0.5
# ----- Seedを生成しました: "に憎まれるなら
# そうなる前に僕の方から嫌った　僕だった
#
# だけどいつかは誰かを求"
# に憎まれるなら
# そうなる前に僕の方から嫌った　僕だった
#
# だけどいつかは誰かを求め　だって君もいいか　た僕が笑顔ですよ　あなしたよ
#
# いいいですよ　んな顔の言え　いされと言　ていいんですか
# こんなに人を信じいもも未れるとない　々が　そんですか
# こんなに人を信じいもいもう
#
# 大した
#
# -----diveristy 1.0
# ----- Seedを生成しました: "に憎まれるなら
# そうなる前に僕の方から嫌った　僕だった
#
# だけどいつかは誰かを求"
# に憎まれるなら
# そうなる前に僕の方から嫌った　僕だった
#
# だけどいつかは誰かを求め　いいんですか
# こんなに人を信じたもいいんですか?
#
# いいんですよ　あなんですよ　あなっこ
#
# いいんですよ　いいんですよ　あなたと思は」
# いいんですよ　いいんですよ　あなたと思は」
# いいんですよ　ん
#
# -----diveristy 1.2
# ----- Seedを生成しました: "に憎まれるなら
# そうなる前に僕の方から嫌った　僕だった
#
# だけどいつかは誰かを求"
# に憎まれるなら
# そうなる前に僕の方から嫌った　僕だった
#
# だけどいつかは誰かを求め　だをてもういいんだった僕にもも溶いだよう言ったホされるしと後　箱を信じつもいいんですか?
#
# いいんですよ　あなんですよ　あなたが選んだ人人を信じゃもいいんで anetsayode
#
# e れくれると
#
# --------------------------------------------------
# 繰り返し回数:  15
# Epoch 1/1
# 2306/2306 [==============================] - 11s 5ms/step - loss: 0.0062
#
# -----diveristy 0.2
# ----- Seedを生成しました: "ろう
# 歩まないで 歩こう
#
# 愛さないで 愛でよう
# 飾らないで 飾ろう
# 変わらない"
# ろう
# 歩まないで 歩こう
#
# 愛さないで 愛でよう
# 飾らないで 飾ろう
# 変わらない 響いないいいよ
#
# 大した想 だけでいいも いつんですか
# こんなに人を信じいもいいんでわか?
#
# いいんですよ　あなんですよ　あなんですよ　あなんですよ　あなんですよ　あなんですよ　あなんですよ　あなん
#
# -----diveristy 0.5
# ----- Seedを生成しました: "ろう
# 歩まないで 歩こう
#
# 愛さないで 愛でよう
# 飾らないで 飾ろう
# 変わらない"
# ろう
# 歩まないで 歩こう
#
# 愛さないで 愛でよう
# 飾らないで 飾ろう
# 変わらない 響いないいいよ
#
# 大hですよ　いいんですよ　あならけ後にも染まらぬをた
#
# いいんですよ　んなに僕を見ていこんだに
# 僕の言えた
#
# いつもは尖 たよ　声もう
# 失おかなやと　溢がるるとなもう少しだけくはつ
#
# -----diveristy 1.0
# ----- Seedを生成しました: "ろう
# 歩まないで 歩こう
#
# 愛さないで 愛でよう
# 飾らないで 飾ろう
# 変わらない"
# ろう
# 歩まないで 歩こう
#
# 愛さないで 愛でよう
# 飾らないで 飾ろう
# 変わらない もううならば
#
# いいんですよ　あながけ後うにもういいんですか
# こんなに人を信じゃもいいんでわか?
#
# 大ないけできてる限りがだようにだ色てた
#
# 大ついけができるよ ならを
# いいんですか　いいんですか
#
#
# -----diveristy 1.2
# ----- Seedを生成しました: "ろう
# 歩まないで 歩こう
#
# 愛さないで 愛でよう
# 飾らないで 飾ろう
# 変わらない"
# ろう
# 歩まないで 歩こう
#
# 愛さないで 愛でよう
# 飾らないで 飾ろう
# 変わらない 響い信はないいかに
# いるんなに僕ら待を
# きるしたセプテンバー
#
# 手当もいいんですか　いいんですか
# こんなに人を信じいもいいんでわか?
#
# いいんですよ　あなんですよ　あなんですよ　あなんですよ　あなん
#
# --------------------------------------------------
# 繰り返し回数:  16
# Epoch 1/1
# 2306/2306 [==============================] - 9s 4ms/step - loss: 0.0153
#
# -----diveristy 0.2
# ----- Seedを生成しました: "もないや　やっぱりなんでもないや
# 今から行くよ
#
# 僕らタイムフライヤー　時を駆け"
# もないや　やっぱりなんでもないや
# 今から行くよ
#
# 僕らタイムフライヤー　時を駆け上上を　知らば
#
# あが　この手ないけは　ないですか
# こんなに人を信じいもいいんでわか?
#
# いいんですよ　あなんですよ　あなんですよ　あなんですよ　あなっと思は」
# いいんですよ　んなに 僕を見ていくは
#
# -----diveristy 0.5
# ----- Seedを生成しました: "もないや　やっぱりなんでもないや
# 今から行くよ
#
# 僕らタイムフライヤー　時を駆け"
# もないや　やっぱりなんでもないや
# 今から行くよ
#
# 僕らタイムフライヤー　時を駆け上上を　知らせた
#
# 本が　知は嬉してる
# い今まですか　そんな顔でいいも
# だった君手を」
# いいんですよ　あながと」を見いいかも
# ずえ　伝君はか知らば
#
# あがしだけでいいかも
#
# 大二人を信じいで 僕が受
#
# -----diveristy 1.0
# ----- Seedを生成しました: "もないや　やっぱりなんでもないや
# 今から行くよ
#
# 僕らタイムフライヤー　時を駆け"
# もないや　やっぱりなんでもないや
# 今から行くよ
#
# 僕らタイムフライヤー　時を駆け上上を　を見つかった
#
# いつんですか　いいんですか
# こんなに人を信じいもいいんでわか?
#
# 大したよ
# あなっなっていいかも
#
# 君が笑顔なくて　もう少しだけでいい　も
# 気が居だけ後にも染てらぬうにもう少し
#
# -----diveristy 1.2
# ----- Seedを生成しました: "もないや　やっぱりなんでもないや
# 今から行くよ
#
# 僕らタイムフライヤー　時を駆け"
# もないや　やっぱりなんでもないや
# 今から行くよ
# 僕らタイムフライヤー　時を駆け上上に
#
# 更今ならば
# そんな顔に僕らばくきるからば
# きと心を 響いいんですか?
#
# あっこ一僕らもううとなって
#
# っついわれと　を　知ががくよう　いいんですよ　あなたとは」けですか
#
# いいんですか
#
# --------------------------------------------------
# 繰り返し回数:  17
# Epoch 1/1
# 2306/2306 [==============================] - 8s 3ms/step - loss: 0.0034
#
# -----diveristy 0.2
# ----- Seedを生成しました: "け上がるクライマー
# 時のかくれんぼ　はぐれっこはもういやなんだ
#
# なんでもないや"
# け上がるクライマー
# 時のかくれんぼ　はぐれっこはもういやなんだ
#
# なんでもないや　あないころよう見いいかか
#
#
# いいかですか　いいんですか
# こんなに人を信じいもいいんでわか?
#
# いいんですよ　あなんですよ　あなんですよ　あなんですよ　いいんですよ　んなに
#
# いいんですよ　いいんで
#
# -----diveristy 0.5
# ----- Seedを生成しました: "け上がるクライマー
# 時のかくれんぼ　はぐれっこはもういやなんだ
#
# なんでもないや"
# け上がるクライマー
# 時のかくれんぼ　はぐれっこはもういやなんだ
#
# なんでもないや　あないころうに見込んですか　いいんですか
# こんなに人を信じいいいんですか?
#
# 大したよけないわれが　らを追ない　あなが　いいんですよ　あないけ後に目を見て
# 枯う　言えたら
# 愛したい　いいんですか
# こ
#
# -----diveristy 1.0
# ----- Seedを生成しました: "け上がるクライマー
# 時のかくれんぼ　はぐれっこはもういやなんだ
#
# なんでもないや"
# け上がるクライマー
# 時のかくれんぼ　はぐれっこはもういやなんだ
#
# なんでもないや　あなが　いないけれうそんな顔久いいかで
#
# いいんですよ　あなたと望はで1らか
# を信じゃもいいんですか
# こんなに人を信じいもいいんでわか?
#
# いいんですよ　あなんですよ　あないころうに一歌っていいい
#
# -----diveristy 1.2
# ----- Seedを生成しました: "け上がるクライマー
# 時のかくれんぼ　はぐれっこはもういやなんだ
#
# なんでもないや"
# け上がるクライマー
# 時のかくれんぼ　はぐれっこはもういやなんだ
#
# なんでもないや　特とないかくよ
#
# いいいもは尖 そう確とないいかも
#
#
# 大いいですよ　いいんですよ　あなたと言う「
# だけでいいかも
# だったいたもいいんですか　いいんですか
# こんなに人を信じいもいいんですか?
#
# 大し
#
# --------------------------------------------------
# 繰り返し回数:  18
# Epoch 1/1
# 2306/2306 [==============================] - 8s 3ms/step - loss: 0.0046
#
# -----diveristy 0.2
# ----- Seedを生成しました: "くれんぼ　はぐれっこ　はもういいよ
#
# 君は派手なクライヤー　その涙　止めてみたい"
# くれんぼ　はぐれっこ　はもういいよ
#
# 君は派手なクライヤー　その涙　止めてみたいんだっそんそどもう少しだけでいいかも
# いんですか
# こんなに人を信じいももいいんでわか?
#
# いいんですよ　あなんですよ　あなんですよ　あなんですよ　いいんですよ　いいんですよ　いいんですよ　いいんですよ
#
# -----diveristy 0.5
# ----- Seedを生成しました: "くれんぼ　はぐれっこ　はもういいよ
#
# 君は派手なクライヤー　その涙　止めてみたい"
# くれんぼ　はぐれっこ　はもういいよ
#
# 君は派手なクライヤー　その涙　止めてみたいんだだ僕らを信じゃもいいんですか?
#
# いいんですよ　あなんですよ　あないけでいそんなに人を信じももいいんですか?
#
# いいんですよ　あなんですよ　あないけですよ　大い出が分から　あなが　後ないいかは
# こ
#
# -----diveristy 1.0
# ----- Seedを生成しました: "くれんぼ　はぐれっこ　はもういいよ
#
# 君は派手なクライヤー　その涙　止めてみたい"
# くれんぼ　はぐれっこ　はもういいよ
#
# 君は派手なクライヤー　その涙　止めてみたいようだった君にもを信じゃももんな顔うから　そうなる前
# 特のないいか
#
# えいいですか　いいんですか
# こんなに人を信じゃもいいんでもか?
#
# いいんですよ　あなんですよ　あなくこさも ってがいいか
#
# 僕の
#
# -----diveristy 1.2
# ----- Seedを生成しました: "くれんぼ　はぐれっこ　はもういいよ
#
# 君は派手なクライヤー　その涙　止めてみたい"
# くれんぼ　はぐれっこ　はもういいよ
#
# 君は派手なクライヤー　その涙　止めてみたいんですか
# こんなに人を信じゃもいいんで男か?
#
# いなんですよ　あなんですよ　あなしけ出すせも いいんですか　いいんですか
# こんなに人を信じいももいいんですか?
#
# いいんですよ　あなが　特はないいかも
#
#
# --------------------------------------------------
# 繰り返し回数:  19
# Epoch 1/1
# 2306/2306 [==============================] - 8s 3ms/step - loss: 0.0014
#
# -----diveristy 0.2
# ----- Seedを生成しました: "から　僕は嬉しくて　泣く 泣く
#
# 明日を呪う人間不信者は 明日を夢見る人間信者"
# から　僕は嬉しくて　泣く 泣く
#
# 明日を呪う人間不信者は 明日を夢見る人間信者に 繋いいんで
#
# いいんですよ　んなに
# この声を 響いいんですか
# こんなに人を信じゃもいいんでわか?
#
# 大した人を信じい越いいんですか?
#
# 大した人を信じゃもいいど
#
# 僕が笑顔ないよ
#
#
# 本が笑　この
#
# -----diveristy 0.5
# ----- Seedを生成しました: "から　僕は嬉しくて　泣く 泣く
#
# 明日を呪う人間不信者は 明日を夢見る人間信者"
# から　僕は嬉しくて　泣く 泣く
#
# 明日を呪う人間不信者は 明日を夢見る人間信者に そう先にもならば
#
# あなった僕にもってもいいんですか
# こんなに人を信じゃもいいんでわか?
#
# 大した人を信じゃもいいど　?」を探う　いない　もないよ
#
# いい出ですよ　あないけでい富もう
# だって君手を
#
# -----diveristy 1.0
# ----- Seedを生成しました: "から　僕は嬉しくて　泣く 泣く
#
# 明日を呪う人間不信者は 明日を夢見る人間信者"
# から　僕は嬉しくて　泣く 泣く
#
# 明日を呪う人間不信者は 明日を夢見る人間信者に 繋いいんですから
#
# いいんですよ　いいんですよ　あなっころうに人を信じゃもいいんですか?
#
# いいんですよ　あないけでも答いいんですよ　あないここに来そを上になって
# いいんですか　いいんですか
# こん
#
# -----diveristy 1.2
# ----- Seedを生成しました: "から　僕は嬉しくて　泣く 泣く
#
# 明日を呪う人間不信者は 明日を夢見る人間信者"
# から　僕は嬉しくて　泣く 泣く
#
# 明日を呪う人間不信者は 明日を夢見る人間信者に 繋いいで
#
# 大もたは歌た一けでいいか
#
# 僕の少しだけでいい　あと誰　手を探したらるしたセで。
#
#
# いいんですよ　んな『このものこと　白知い　あと嬉してるように人をば
#
# 語この声」
# もう少しだけでい
#
# --------------------------------------------------
# 繰り返し回数:  20
# Epoch 1/1
# 2306/2306 [==============================] - 10s 4ms/step - loss: 0.0183
#
# -----diveristy 0.2
# ----- Seedを生成しました: "
#
# リアルと夢と永遠と今と幻想が
# 束になって僕を胴上げしてんだ
# あの日僕らを染め"
#
#
# リアルと夢と永遠と今と幻想が
# 束になって僕を胴上げしてんだ
# あの日僕らを染め上に
#
# 大ものは嬉しだけでいいか
#
# あなっと　探いい　もう少したとけでいいか
#
# あなyと　溢れるる前な
#
# いつもは尖尖たた
# 　それないこのない　嘘)ならば 時を垂くらば
#
# いいんですよ　いいこの色は笑
#
# -----diveristy 0.5
# ----- Seedを生成しました: "
#
# リアルと夢と永遠と今と幻想が
# 束になって僕を胴上げしてんだ
# あの日僕らを染め"
#
#
# リアルと夢と永遠と今と幻想が
# 束になって僕を胴上げしてんだ
# あの日僕らを染め上に
#
# 大ものは嬉しだけでいいか
#
# あなっと　探いい　もう少しだけでいいか
#
# あなyと　溢るよ
#
# いいんですよ　あなっこののは」
#
# 大ども今まうちらかしてっていいかもうぬれがしたと
# 探ら々
#
# 大今　想
#
# -----diveristy 1.0
# ----- Seedを生成しました: "
#
# リアルと夢と永遠と今と幻想が
# 束になって僕を胴上げしてんだ
# あの日僕らを染め"
#
#
# リアルと夢と永遠と今と幻想が
# 束になって僕を胴上げしてんだ
# あの日僕らを染め上を
#
# いつもは尖尖とた僕の言えた
# 君がいいいは 僕が歌った  色は笑していてい出が救aようないら　もう少しだけでいいか
#
# あなっといついると
#
# いいんですよ　いいんですよ　あないけよう「いいんですよ
#
# -----diveristy 1.2
# ----- Seedを生成しました: "
#
# リアルと夢と永遠と今と幻想が
# 束になって僕を胴上げしてんだ
# あの日僕らを染め"
#
#
# リアルと夢と永遠と今と幻想が
# 束になって僕を胴上げしてんだ
# あの日僕らを染め上に
# 上らば
#
# あ何に この先に 僕らせように
# 何にももうしだけ　いいか
#
# いでせた
# 大今　いいですか　いいんですか
# こんなに人を信じともいいもいいんで
#
# 大ない　このなに 僕が受ない
#
# 愛しまの声だ
#
# --------------------------------------------------
# 繰り返し回数:  21
# Epoch 1/1
# 2306/2306 [==============================] - 9s 4ms/step - loss: 0.0031
#
# -----diveristy 0.2
# ----- Seedを生成しました: "きになっていいんですか?
# いいんですよ　いいんですよ
# あなたが選んだ人ならば
# あ"
# きになっていいんですか?
# いいんですよ　いいんですよ
# あなたが選んだ人ならば
# あなもいいんですか　こんなに人を信じゃもいいんでわか?
#
# いいんですよ　あないけでいよも
# いいんですよ　あなたが望をだ道ないば
# いいか そう確とと
# 愛いつないいんですか　いいんですか
# こんなに人を信じゃ
#
# -----diveristy 0.5
# ----- Seedを生成しました: "きになっていいんですか?
# いいんですよ　いいんですよ
# あなたが選んだ人ならば
# あ"
# きになっていいんですか?
# いいんですよ　いいんですよ
# あなたが選んだ人ならば
# あなんだと
# 君は命久人を信じゃもいいんでわか?
#
# 大させよ　だけでいいか
#
# 大れた一すよ　いいんですよ　あなたころですか　あながと　言ついいころうに僕を信じゃもいいんですか?
#
# 大ないんですよ　あなっこ
#
# -----diveristy 1.0
# ----- Seedを生成しました: "きになっていいんですか?
# いいんですよ　いいんですよ
# あなたが選んだ人ならば
# あ"
# きになっていいんですか?
# いいんですよ　いいんですよ
# あなたが選んだ人ならば
# あなもしいいんですか
# こんなに人を信じゃもいいんでわか?
#
# 大語ないいかで
# 夜
# か　そこの命に」
#
# いいんですよ　あなっころもう気が望分からば
# いいんですか　いいんですか
# こんなに人を信じゃもいいんでわ
#
# -----diveristy 1.2
# ----- Seedを生成しました: "きになっていいんですか?
# いいんですよ　いいんですよ
# あなたが選んだ人ならば
# あ"
# きになっていいんですか?
# いいんですよ　いいんですよ
# あなたが選んだ人ならば
# あなもいいんですか　いいんですか
# こんなに人を信じともいいんでo
# いいんですよ　あなっここに命」っていいんで
#
# いいんですよ　いいんですよ　あないころうに今まていていいい
#
# 湿はもう少しだけ　いいかは
#
# --------------------------------------------------
# 繰り返し回数:  22
# Epoch 1/1
# 2306/2306 [==============================] - 10s 4ms/step - loss: 0.0049
#
# -----diveristy 0.2
# ----- Seedを生成しました: "らず落ちた僕を
# 君が受け取ったんだ
#
# 苦いけど 苦しくはないよと 君は
# 酸っぱい"
# らず落ちた僕を
# 君が受け取ったんだ
#
# 苦いけど 苦しくはないよと 君は
# 酸っぱいいんですか
# こんなに人を信じゃもいいんでわか?
#
# いいんですよ　あながけ後うになって君いいんですか
# こんなに人を信じゃもいいんでわか?
#
# 大したすよ　あなってていいか
#
# あなした人　そんな顔人を信じい
#
# -----diveristy 0.5
# ----- Seedを生成しました: "らず落ちた僕を
# 君が受け取ったんだ
#
# 苦いけど 苦しくはないよと 君は
# 酸っぱい"
# らず落ちた僕を
# 君が受け取ったんだ
#
# 苦いけど 苦しくはないよと 君は
# 酸っぱいてみてっててるかか
#
# 本まな顔け出すよ　いいんですよ　あなってけいいか
#
# 僕が受けでいいか
#
# 愛した人になっていいんですか　こんなに人を信じゃもいいんでわか?
#
# 大したすよ　あなって手を
# 白したい　こ
#
# -----diveristy 1.0
# ----- Seedを生成しました: "らず落ちた僕を
# 君が受け取ったんだ
#
# 苦いけど 苦しくはないよと 君は
# 酸っぱい"
# らず落ちた僕を
# 君が受け取ったんだ
#
# 苦いけど 苦しくはないよと 君は
# 酸っぱいてんですか
# こんな顔でもないんですか　こんなに人を信じゃもいいんでわか?
#
# 大ないんですよ　あなたが選んだ人をらを信じゃもいいんで屋か?
#
# いいんですよ　あながけ後うになって君いいんですか
# こんなに人
#
# -----diveristy 1.2
# ----- Seedを生成しました: "らず落ちた僕を
# 君が受け取ったんだ
#
# 苦いけど 苦しくはないよと 君は
# 酸っぱい"
# らず落ちた僕を
# 君が受け取ったんだ
#
# 苦いけど 苦しくはないよと 君は
# 酸っぱいいんですか
# こんな顔人を信じいもいいんで男か?
#
# いいんですよ　あながけでいそんだに僕になっていいんですか　こんなに人を信じゃもいいんでわか?
#
# いいんですよ　あないけ選んな顔ば
# いいもいいかも
#
# 聖
#
# --------------------------------------------------
# 繰り返し回数:  23
# Epoch 1/1
# 2306/2306 [==============================] - 8s 3ms/step - loss: 9.8019e-04
#
# -----diveristy 0.2
# ----- Seedを生成しました: "いんですか?
# いいんですよ　いいんですよ
# あなたが選んだ人ならば
# あなたが愛した"
# いんですか?
# いいんですよ　いいんですよ
# あなたが選んだ人ならば
# あなたが愛した人を信じいもいいんですか?
#
# いいんですよ　あないけですよ　あないころうに人を信じゃもいいんですか?
#
# いいんですよ　あないけ選んですよ　あないころうに人を信じゃもいいんでわか?
#
# 大した一いた にま
#
# -----diveristy 0.5
# ----- Seedを生成しました: "いんですか?
# いいんですよ　いいんですよ
# あなたが選んだ人ならば
# あなたが愛した"
# いんですか?
# いいんですよ　いいんですよ
# あなたが選んだ人ならば
# あなたが愛した人を信じいもいいんですか?
#
# いいんですよ　あながけでいんですよ
# いいんですよ　あないけ」いついいんだよ。
# けいいけでいこんで」
# 僕にもう少しだけでいいか
#
# あなっとけ本りだと投を追い越したんだ
# 。る
#
# -----diveristy 1.0
# ----- Seedを生成しました: "いんですか?
# いいんですよ　いいんですよ
# あなたが選んだ人ならば
# あなたが愛した"
# いんですか?
# いいんですよ　いいんですよ
# あなたが選んだ人ならば
# あなたが愛した人を信じゃもいいんですか?
#
# いいんですよ　あながけですよ　あないこよにですよ　あなった
#
# 大れを止まてぬnたら僕に もう少しだけく
# 笑いいんですか　いいんですか
# こんなに人を信じゃもいいんでわか?
#
#
# -----diveristy 1.2
# ----- Seedを生成しました: "いんですか?
# いいんですよ　いいんですよ
# あなたが選んだ人ならば
# あなたが愛した"
# いんですか?
# いいんですよ　いいんですよ
# あなたが選んだ人ならば
# あなたが愛した人一て　いいんですか　いいんですか
# こんなに人を信じゃもいいんでわか?
#
# いいんですよ　あないけもうないや
#
# いいんですよ　あないいのはとからもう先に明日を
# きて待てて
#
# いいんですよ　こんですよ
#
#
# --------------------------------------------------
# 繰り返し回数:  24
# Epoch 1/1
# 2306/2306 [==============================] - 7s 3ms/step - loss: 9.9063e-04
#
# -----diveristy 0.2
# ----- Seedを生成しました: "かに 僕が受け取ったものだから
#
# 遥か先の 君に叫ぶ 「今から行くから待っててよ"
# かに 僕が受け取ったものだから
#
# 遥か先の 君に叫ぶ 「今から行くから待っててようから
# 君が笑した一す　いいんですよ　あないとよ
#
# いた一すよ　いいんですよ　あなっころうに人を信じゃもいいんですか?
#
# 大した一す　いいんですよ　あないけ出が分かたとさ」もう少しだけでいいか
#
# あな
#
# -----diveristy 0.5
# ----- Seedを生成しました: "かに 僕が受け取ったものだから
#
# 遥か先の 君に叫ぶ 「今から行くから待っててよ"
# かに 僕が受け取ったものだから
#
# 遥か先の 君に叫ぶ 「今から行くから待っててようから
# 君が笑した一す　いいんですよ　いいんですよ　あなっとけようにもう少しだけでいいか
#
# あなっとけ象いだ
#
# いつもは尖いたよ　いいい　もう少しだけでいいか
#
# あなっといついか　そんだとでもいいんで
#
# -----diveristy 1.0
# ----- Seedを生成しました: "かに 僕が受け取ったものだから
#
# 遥か先の 君に叫ぶ 「今から行くから待っててよ"
# かに 僕が受け取ったものだから
#
# 遥か先の 君に叫ぶ 「今から行くから待っててよ
#
# いいいですよ　いいんですよ　あなった眩のすよ　知らば ろううになって
#
# 大い　あした人　　いいんですよ　あなっころでも今までいこんだ」
# いつもいいか　特とないでいいか?
# 大れたこのもう少しだけで
#
# -----diveristy 1.2
# ----- Seedを生成しました: "かに 僕が受け取ったものだから
#
# 遥か先の 君に叫ぶ 「今から行くから待っててよ"
# かに 僕が受け取ったものだから
#
# 遥か先の 君に叫ぶ 「今から行くから待っててようか
#
# 僕が笑けでいいか
#
# あのやり向こえに目を
# 白い知は嬉しだけでいいか
#
# mったさがる前な僕のあのは　知は嬉してて泣くては探して
# 枯ろううしたよう
#
# いいんですよ　こないいいいに 僕は歌くずからば
#
# --------------------------------------------------
# 繰り返し回数:  25
# Epoch 1/1
# 2306/2306 [==============================] - 8s 3ms/step - loss: 9.0255e-04
#
# -----diveristy 0.2
# ----- Seedを生成しました: "手に次の
# 未来渡されてしまうんだから
#
# やり場に困ったその未来
# 仕方ないから取っ"
# 手に次の
# 未来渡されてしまうんだから
#
# やり場に困ったその未来
# 仕方ないから取ったホ
# どっと心を 響いたよ
#
# いいんですよ　あないいのは」僕を
# きてみててるこんだに僕らを信じ
# 一いいですか　こんなに人を信じゃもいいんでわか?
#
# いいんですよ　あながが選んだ人を君になっていいんです
#
# -----diveristy 0.5
# ----- Seedを生成しました: "手に次の
# 未来渡されてしまうんだから
#
# やり場に困ったその未来
# 仕方ないから取っ"
# 手に次の
# 未来渡されてしまうんだから
#
# やり場に困ったその未来
# 仕方ないから取ったホ
# どっといていかか
#
# いいんですよ　こんなに人を信じゃもいいんでわか?
#
# いいんですよ　あないけ選んだ人を君になっていいんですか
# こんなに人を信じゃもいいんでわか?
#
# いいんですよ　あないけですよ
#
# -----diveristy 1.0
# ----- Seedを生成しました: "手に次の
# 未来渡されてしまうんだから
#
# やり場に困ったその未来
# 仕方ないから取っ"
# 手に次の
# 未来渡されてしまうんだから
#
# やり場に困ったその未来
# 仕方ないから取ったホの残い　いると
#
# 聖がけでいいかもいいんで
# おか　そう　なっといいんですか　こんだに人を信じゃもいいんですか?
#
# いいんですよ　あながが選んだ人屋らばをい越したんだ
# 手当そんな顔にいない　世界など
#
# -----diveristy 1.2
# ----- Seedを生成しました: "手に次の
# 未来渡されてしまうんだから
#
# やり場に困ったその未来
# 仕方ないから取っ"
# 手に次の
# 未来渡されてしまうんだから
#
# やり場に困ったその未来
# 仕方ないから取ったホ
# 大したよ
#
# いまのいよう　いない　いよ」
# いい越してんだ
# 夜るク
# だとは　知ここでもういいか　特したよ でいいかっ
#
# いいんですよ　こんなくと
# 探ら　待すよ　いをて
#
# 大れた先にも そんできる限
#
# --------------------------------------------------
# 繰り返し回数:  26
# Epoch 1/1
# 2306/2306 [==============================] - 8s 3ms/step - loss: 9.3728e-04
#
# -----diveristy 0.2
# ----- Seedを生成しました: "君に叫ぶ 「今から行くから待っててよ」
# その瞳に涙 浮かべた君は
# 僕の未来そのも"
# 君に叫ぶ 「今から行くから待っててよ」
# その瞳に涙 浮かべた君は
# 僕の未来そのものいど　それるないといども
#
# 聖が語このは」
# そんな顔人を信じゃもいいんですか?
#
# 大させよ　だが分から待ってていいんだ
# 夜るそんな顔とな血　もう少しだけでいいか
#
# あなっとけ象い
#
# いいんですよ
#
# -----diveristy 0.5
# ----- Seedを生成しました: "君に叫ぶ 「今から行くから待っててよ」
# その瞳に涙 浮かべた君は
# 僕の未来そのも"
# 君に叫ぶ 「今から行くから待っててよ」
# その瞳に涙 浮かべた君は
# 僕の未来そのものいど　それるないそのもない　いいい
#
# いつもいいんですか　いいんですか
# こんなに人を信じゃもいいんでわか?
#
# 大ないんですよ　あながが分から　いいんですか　いいんですか
# こんなに人を信じゃもいいんで
#
# -----diveristy 1.0
# ----- Seedを生成しました: "君に叫ぶ 「今から行くから待っててよ」
# その瞳に涙 浮かべた君は
# 僕の未来そのも"
# 君に叫ぶ 「今から行くから待っててよ」
# その瞳に涙 浮かべた君は
# 僕の未来そのものいど　それをきないいいか
#
# 大響いいんですよ　いいんですよ　あなっころうに人を信じゃもいいんですか?
#
# いいんですよ　あなっが選んだ人を信じゃもいいんですか?
#
# いいんですよ　あないけ選んですよ　あ
#
# -----diveristy 1.2
# ----- Seedを生成しました: "君に叫ぶ 「今から行くから待っててよ」
# その瞳に涙 浮かべた君は
# 僕の未来そのも"
# 君に叫ぶ 「今から行くから待っててよ」
# その瞳に涙 浮かべた君は
# 僕の未来そのものい出が望んだよ
# 左っにまってみていれとるわだだけジらそこをないたいたは　変の手の手来そう今きってて
# 枯きな言とややと　溢るるよ
#
# 僕らも ぶう
# だけ　いいも
# いうどっと　手当もないい　世界など　夏が
#
# --------------------------------------------------
# 繰り返し回数:  27
# Epoch 1/1
# 2306/2306 [==============================] - 10s 4ms/step - loss: 0.0012
#
# -----diveristy 0.2
# ----- Seedを生成しました: "　転がってる
# 叶えたい夢も　今日で100個できたよ　たった一つといつか　交換こし"
# 　転がってる
# 叶えたい夢も　今日で100個できたよ　たった一つといつか　交換こしない人は」
# いいんですよ　いいんですよ　あないけでい富もういいかで
# 富るとどもう少しだけでいいか
#
# あながと　知くこの機と　溢るよると
#
# いつもは尖いたよ　いいいけども今ない　世界な　夏がうの?」
# だ
#
# -----diveristy 0.5
# ----- Seedを生成しました: "　転がってる
# 叶えたい夢も　今日で100個できたよ　たった一つといつか　交換こし"
# 　転がってる
# 叶えたい夢も　今日で100個できたよ　たった一つといつか　交換こしない人は信ですいてしそうにと
# 君は見つけない　世界など　夏が分か?けいいけれいなれ　いなんでわないい　あと他しだけでいいかも
# 愛れが人を信じまでもこんんじろうにもう少しだけでいいか
#
# あなら 響い越し
#
# -----diveristy 1.0
# ----- Seedを生成しました: "　転がってる
# 叶えたい夢も　今日で100個できたよ　たった一つといつか　交換こし"
# 　転がってる
# 叶えたい夢も　今日で100個できたよ　たった一つといつか　交換こしすよ　いいんですよ　あないけでいよ
#
# いいもでいだかで
# 富るなっと君はもういいかは
#
# がしたいけ いようにいないんですか　こんだに人を信じゃもいいんでわか?
#
# 大した想 もいうのは」
# だけでいいかも
#
#
# -----diveristy 1.2
# ----- Seedを生成しました: "　転がってる
# 叶えたい夢も　今日で100個できたよ　たった一つといつか　交換こし"
# 　転がってる
# 叶えたい夢も　今日で100個できたよ　たった一つといつか　交換こしにも」きにをまうんだ
# 眩んそる分かないかで
#
#
# あがんな、おいいか
#
# いいんですよ　あながけでい富も
# いいんですよ　こんでい富は言ない
#
# いたん僕にま僕らば
# きるとな知とは」
# いいんですよ　いいんです
#
# --------------------------------------------------
# 繰り返し回数:  28
# Epoch 1/1
# 2306/2306 [==============================] - 9s 4ms/step - loss: 0.0191
#
# -----diveristy 0.2
# ----- Seedを生成しました: "んですか
# こんなに人を好きになっていいんですか?
# いいんですか　いいんですか
# こ"
# んですか
# こんなに人を好きになっていいんですか?
# いいんですか　いいんですか
# こんなに人を信じゃもいいんでいか?
#
# いいんですよ　あなっが選んだ人を信じゃもいいんでわか?
#
# 大した一す　いいんですよ　あないころうにもないこの機　いいんですよ　あないけ出すよ　分かしてていいんですか
#
# -----diveristy 0.5
# ----- Seedを生成しました: "んですか
# こんなに人を好きになっていいんですか?
# いいんですか　いいんですか
# こ"
# んですか
# こんなに人を好きになっていいんですか?
# いいんですか　いいんですか
# こんなに人を信じゃもいいんでいか?
#
# いいんですよ　あなっここに来を探していると
# 僕のおから
#
# 遥いいもういいから
# いない　あない　いないけでくよ
# に僕を見ていいんですか
# こんな顔と僕にも染てらば
#
# い
#
# -----diveristy 1.0
# ----- Seedを生成しました: "んですか
# こんなに人を好きになっていいんですか?
# いいんですか　いいんですか
# こ"
# んですか
# こんなに人を好きになっていいんですか?
# いいんですか　いいんですか
# こんなに人を信じゃもいいんでいかり
#
# 大った一させるよ出がと　知ら待くて
#
# いつい出がとと　知らでいこの機　知の先の最イやか?
#
# 大どもう少しだけでいいか
#
# あない　愛くれるこなにと」
# いつもは尖いたよ
#
# -----diveristy 1.2
# ----- Seedを生成しました: "んですか
# こんなに人を好きになっていいんですか?
# いいんですか　いいんですか
# こ"
# んですか
# こんなに人を好きになっていいんですか?
# いいんですか　いいんですか
# こんなに人を信じゃもいいんでぐいど
#
# いつも OH セプテンバー
#
# きるとどっていきか
#
# 大輪用このもう気い出がしてる前に僕を見て
# 枯えてみ二すいやって
# 枯起の大どうとあった4の手を 縦したんだ
# 手当を
#
# --------------------------------------------------
# 繰り返し回数:  29
# Epoch 1/1
# 2306/2306 [==============================] - 10s 4ms/step - loss: 0.0041
#
# -----diveristy 0.2
# ----- Seedを生成しました: "ない
# 仕方ないから頑張るけど もういい どうにでもなれ
#
# どれだけ後ろ向きに 歩"
# ない
# 仕方ないから頑張るけど もういい どうにでもなれ
#
# どれだけ後ろ向きに 歩きてみ 響くのは
#
# いいんですよ　あなががこんできた
#
#
# 二れた一す　いいんですよ　あなったい
# んだけ僕にもう少しだけでいいか
#
# あなたと起愛したいもたい湿んだよ。
# 逃
# いいんですよ　あながけ後にそっ
#
# -----diveristy 0.5
# ----- Seedを生成しました: "ない
# 仕方ないから頑張るけど もういい どうにでもなれ
#
# どれだけ後ろ向きに 歩"
# ない
# 仕方ないから頑張るけど もういい どうにでもなれ
#
# どれだけ後ろ向きに 歩きてみ 響くのは
#
# 大どれぬまうないたら
# どうせた
# いいんですよ　あながけ後いんですよ　いいんですよ　あなたが望はないこ々らにもう少しだけでいいかは
# あなったと　知はもういか　いいんですか
# こんなに人
#
# -----diveristy 1.0
# ----- Seedを生成しました: "ない
# 仕方ないから頑張るけど もういい どうにでもなれ
#
# どれだけ後ろ向きに 歩"
# ない
# 仕方ないから頑張るけど もういい どうにでもなれ
#
# どれだけ後ろ向きに 歩きてみてくくきると
#
#
# 二れたが望分かったホすぎ
# あなっここに一くこにもう少しだけでいいか
#
# あな拒　分からいいか
#
# 遥う少しだけでいいかは
# えの想と隙をcうbだけ 　をくれるこんだに 大otけcl
#
# -----diveristy 1.2
# ----- Seedを生成しました: "ない
# 仕方ないから頑張るけど もういい どうにでもなれ
#
# どれだけ後ろ向きに 歩"
# ない
# 仕方ないから頑張るけど もういい どうにでもなれ
#
# どれだけ後ろ向きに 歩歩てみちbかから
#
#
# いいんですよ　あないここ
# にも珍いどれことを
# 君のクない　いない
#
# いいんですよ　いいんですよ　あなっころうになって
# いいんですか　いいんですか
# こんなに人を信じゃもいいんでいか
#
# --------------------------------------------------
# 繰り返し回数:  30
# Epoch 1/1
# 2306/2306 [==============================] - 9s 4ms/step - loss: 0.0077
#
# -----diveristy 0.2
# ----- Seedを生成しました: " yet
#
# I hope you remember this word I sa"
#  yet
#
# I hope you remember this word I saide anoるも
# 今　想ど出がとと言え
# だけでいいかった
#
# いつも用に僕の声をらば
#
# あなっころうにも言えに
# 僕のもう少しだけでいいかは
# 白いいんですよ　いいんですよ　あならけ後にならば
# いいかは
#
#
# -----diveristy 0.5
# ----- Seedを生成しました: " yet
#
# I hope you remember this word I sa"
#  yet
#
# I hope you remember this word I saide anoるのいいんですよ　いいんですよ　あないころでもた目すよ　いいんですよ　あながががいいかも
# 僕のもう少しだけでいいかは
# 白いいんですか　いいんですか
# こんなに人を信じゃもいいんでいか?
#
#
#
# -----diveristy 1.0
# ----- Seedを生成しました: " yet
#
# I hope you remember this word I sa"
#  yet
#
# I hope you remember this word I saide anoるもいててTか?
#
# 大ど
# だけ後にた一つこか理ちらですか
# した人を探したら僕にをくれば そうぞれた先にも そうぞれいないい
#
#
#
# 聖ら僕にもを見つこのあとろううもう少しだけでいいかも
#
#
# -----diveristy 1.2
# ----- Seedを生成しました: " yet
#
# I hope you remember this word I sa"
#  yet
#
# I hope you remember this word I saide anoる救bai you ev you enerayou
#
#
# 晴一　この声だからば
# いいんですか　いいんですか
# こんなに人を信じももいいんで
# か?
#
# いきんですよ　あなが　選んだ道ならば
# い
#
# --------------------------------------------------
# 繰り返し回数:  31
# Epoch 1/1
# 2306/2306 [==============================] - 7s 3ms/step - loss: 0.0045
#
# -----diveristy 0.2
# ----- Seedを生成しました: "て追い越せやしないんだ
# 夜に浮かぶ月のようなもんなんだ
#
# 後にも 先にも 行かし"
# て追い越せやしないんだ
# 夜に浮かぶ月のようなもんなんだ
#
# 後にも 先にも 行かした
#
#
# 二の先の手から
#
# どれらいまう
# 僕が笑うのはない　嘘れななくない
#
# いたんだけでいいか
# あないここに来それをないそうにい信で
#
# いいんですよ　あながが分からば
# いあなると
# 僕にもう少しだけで
#
# -----diveristy 0.5
# ----- Seedを生成しました: "て追い越せやしないんだ
# 夜に浮かぶ月のようなもんなんだ
#
# 後にも 先にも 行かし"
# て追い越せやしないんだ
# 夜に浮かぶ月のようなもんなんだ
#
# 後にも 先にも 行かした
#
#
# 遥の手の手るクきなった一け　いいんですか　いいんですか
# こんなに人を信じゃもいいんですか?
#
# 大してみて
#
# いいんですよ　あながが分からば
# いいんですか　いいんですか
# こんなに人を信じゃもいい
#
# -----diveristy 1.0
# ----- Seedを生成しました: "て追い越せやしないんだ
# 夜に浮かぶ月のようなもんなんだ
#
# 後にも 先にも 行かし"
# て追い越せやしないんだ
# 夜に浮かぶ月のようなもんなんだ
#
# 後にも 先にも 行かした
#
#
# 二のに僕が笑も
# いからぬない　世界など　夏がmののの上り方からぬない　世界なが　夏がと　特ないないよ
#
# 大言ならば
#
# あなったと　特はないついいよう
# いいんですよ　あながが分からば
# い越したた
#
# -----diveristy 1.2
# ----- Seedを生成しました: "て追い越せやしないんだ
# 夜に浮かぶ月のようなもんなんだ
#
# 後にも 先にも 行かし"
# て追い越せやしないんだ
# 夜に浮かぶ月のようなもんなんだ
#
# 後にも 先にも 行かした
#
#
# 二りー
# 　溢ること命っとされとを追い越したんだ
# 眩っそれる前ないとか
#
#
# 大んだけた一僕にも綺麗て泣くたは　あとど　余れ分から
# いいかはそう　残ない　いないけは
# れくてけでいい寂しだけでいいか
#
# --------------------------------------------------
# 繰り返し回数:  32
# Epoch 1/1
# 2306/2306 [==============================] - 7s 3ms/step - loss: 0.0010
#
# -----diveristy 0.2
# ----- Seedを生成しました: "のだったんだ。
#
#
# 揺れたこの想いの向かう先を
# なにも言わず僕は眺めているよ
#
# "
# のだったんだ。
#
#
# 揺れたこの想いの向かう先を
# なにも言わず僕は眺めているよ
#
#
# いいんですよ　あなががんなに人をできてみて
#
# いいんですよ　あながけ後にもの先の気に
# ３っていいんですか
# こんなに人を信じゃもいいんでもか?
#
# 大した一の想の
# 僕のもう少しだけでいいか
# 枯えの言え
#
# -----diveristy 0.5
# ----- Seedを生成しました: "のだったんだ。
#
#
# 揺れたこの想いの向かう先を
# なにも言わず僕は眺めているよ
#
# "
# のだったんだ。
#
#
# 揺れたこの想いの向かう先を
# なにも言わず僕は眺めているよ
#
#
# いいんですよ　あながが分から　いない
#
# 僕が笑のは嬉してて泣くくはくれるよ
#
# いいんですよ　あながけ後にももたと　知はもう少しだけでいいか
# 枯えの言イさ　言うに今まい　僕の言えた
#
# だけでいいもも
#
# -----diveristy 1.0
# ----- Seedを生成しました: "のだったんだ。
#
#
# 揺れたこの想いの向かう先を
# なにも言わず僕は眺めているよ
#
# "
# のだったんだ。
#
#
# 揺れたこの想いの向かう先を
# なにも言わず僕は眺めているよ
# いいんですよ　あながが選んだ道ななら
#
# いいいですよ　いいんですよ　あながが分かべきてしてんですか?
#
# 大ね
# 君は派球の最の最する
# 信じゃもいいんでわか?
#
# いつかが救しだけでいいか
# 僕のもの?」
#
# -----diveristy 1.2
# ----- Seedを生成しました: "のだったんだ。
#
#
# 揺れたこの想いの向かう先を
# なにも言わず僕は眺めているよ
#
# "
# のだったんだ。
#
#
# 揺れたこの想いの向かう先を
# なにも言わず僕は眺めているよ
#
#
# いようかした
#
# 僕の言えた
#
# あなんな顔僕にも男いいんですよ　いないけくよ
#
# いいんですよ　あなっがsいんですか　いいんですか
# こんなに人を信じゃもいいんでuか?
#
# 大してみて運ば
# いしたんだ
# ろう
#
# --------------------------------------------------
# 繰り返し回数:  33
# Epoch 1/1
# 2306/2306 [==============================] - 7s 3ms/step - loss: 8.5877e-04
#
# -----diveristy 0.2
# ----- Seedを生成しました: "か?
# いいんですか　いいんですか
# こんなにのめりこんじゃっていいんですか?
#
# い"
# か?
# いいんですか　いいんですか
# こんなにのめりこんじゃっていいんですか?
#
# いいんですよ　あながが選んだ人を君は見いいかで
#
# いいんですよ　いいんですよ　あないころうにも何にも染まらぬをた
# るもり方から言
# だけれるそいにないいいんですよ　あながけたいんですか　いいんですか
# こん
#
# -----diveristy 0.5
# ----- Seedを生成しました: "か?
# いいんですか　いいんですか
# こんなにのめりこんじゃっていいんですか?
#
# い"
# か?
# いいんですか　いいんですか
# こんなにのめりこんじゃっていいんですか?
#
# いいんですよ　あながが選んだ人を君は　知いいくはかいて
# いいんですか　いいんですか
# こんなに人を信じゃもいいんでもか?
#
# いいんですよ　あながが選んだ人を君は　知いいいかで
#
# 聖れたこのもう少しだけでい
#
# -----diveristy 1.0
# ----- Seedを生成しました: "か?
# いいんですか　いいんですか
# こんなにのめりこんじゃっていいんですか?
#
# い"
# か?
# いいんですか　いいんですか
# こんなにのめりこんじゃっていいんですか?
#
# いいんですよ　あながが選んだ人を君はないこの先にいない　嘘れななくないい
#
#
# いいんですよ　いいんですよ　あなしけがいい僕は嬉してて泣くれるように
# 聖れが笑顔な僕らない
# 驚たそ僕らを賞り繋を信じいもいる
#
# -----diveristy 1.2
# ----- Seedを生成しました: "か?
# いいんですか　いいんですか
# こんなにのめりこんじゃっていいんですか?
#
# い"
# か?
# いいんですか　いいんですか
# こんなにのめりこんじゃっていいんですか?
#
# いまで先の奇すよ　あながが'いを」ってみいこかうにって君いいかは
#
# 大言えもいいんですか　いいんですか　こんだっら君ッい出 そうんな顔とないいのもいいんですよ　前は今まらぬg それぞれた色の色は　それを
#
# --------------------------------------------------
# 繰り返し回数:  34
# Epoch 1/1
# 2306/2306 [==============================] - 8s 3ms/step - loss: 8.5546e-04
#
# -----diveristy 0.2
# ----- Seedを生成しました: "もう分かってて　悲しくなった
#
# どうせいつかは嫌われるなら　愛した人に憎まれるな"
# もう分かってて　悲しくなった
#
# どうせいつかは嫌われるなら　愛した人に憎まれるないそれそうないこのでに
# 他うに生きるととさ 響いいけでいこんだに
# 君は命のは嬉してるそんだった君にものクにもう少しだけでいいか
# あなったと　特はないつないいんだ
# 僕にもうに 何う少しだけでいいか
#
#
# -----diveristy 0.5
# ----- Seedを生成しました: "もう分かってて　悲しくなった
#
# どうせいつかは嫌われるなら　愛した人に憎まれるな"
# もう分かってて　悲しくなった
#
# どうせいつかは嫌われるなら　愛した人に憎まれるなないそうそれぞれた色いていいんだ
# 僕にも染ててしたんだ。
#
#
# 大いいんですよ　いいんですよ　あないころうに今ま 「何にものは嬉してるそんだと僕らもう少しだけでいいか
# あなったとさ起とと
# 起愛した人僕
#
# -----diveristy 1.0
# ----- Seedを生成しました: "もう分かってて　悲しくなった
#
# どうせいつかは嫌われるなら　愛した人に憎まれるな"
# もう分かってて　悲しくなった
#
# どうせいつかは嫌われるなら　愛した人に憎まれるなないそうそれぞれた先にも そう今ならば
#
# 今までヘ出が語と　をとムしだけでいいか そうがとな空と幻
#
#
# 今までヘないそう望をラとないこれがしたんならば
# いいかは嬉しだ
# いいんですか　いいんですか
# こん
#
# -----diveristy 1.2
# ----- Seedを生成しました: "もう分かってて　悲しくなった
#
# どうせいつかは嫌われるなら　愛した人に憎まれるな"
# もう分かってて　悲しくなった
#
# どうせいつかは嫌われるなら　愛した人に憎まれるないそれそうないか　た
# 手当れなったいいんですか　いいんですか
# こんなに人を信じゃもいいんでo
#
#
# いいんですよ　あなががあない　嘘れないきないけもう
# 今ままたこの手に繋のっと
#
# 手当れく伝なったよ
#
#
#
# --------------------------------------------------
# 繰り返し回数:  35
# Epoch 1/1
# 2306/2306 [==============================] - 7s 3ms/step - loss: 8.7178e-04
#
# -----diveristy 0.2
# ----- Seedを生成しました: "long side
# Both you and me and let's slid"
# long side
# Both you and me and let's slide anone alone saide anone んor en you enerayou en tode
# ing tode anome taide anoる
# いいんですよ　あながけ後にも染まらぬを
#
# -----diveristy 0.5
# ----- Seedを生成しました: "long side
# Both you and me and let's slid"
# long side
# Both you and me and let's slide anone saide anone んit
# cから　それぞれと?
#
# いまで
# 目僕が笑してみてて
#
# いいや向こんだよ。
#
#
# いつも先に泣くこの想を
#
# それくれるもないこから頑した人を待った
#
# あった
#
# -----diveristy 1.0
# ----- Seedを生成しました: "long side
# Both you and me and let's slid"
# long side
# Both you and me and let's slide aidならTsaayou 大を そうぞれた先にも それぞれた色が笑 いいで この今　らば
#
# 今　いやったホだよ。
#
#
# 逃い　想したが　　知様更いいと言え
# あなった一ない　もう少しだけでいいかは
# ず
#
# -----diveristy 1.2
# ----- Seedを生成しました: "long side
# Both you and me and let's slid"
# long side
# Both you and me and let's slid Tene aid mope見e
# 聖れらば
#  響いなんですか?
#
# いまですよ　いいんですよ　あながががいんですよ　あならこうもういいから
# それを今まで1してしてした
#
# いいんですよ　あながが分なにな
#
# --------------------------------------------------
# 繰り返し回数:  36
# Epoch 1/1
# 2306/2306 [==============================] - 7s 3ms/step - loss: 0.0051
#
# -----diveristy 0.2
# ----- Seedを生成しました: "黒に身を預けるほどの懐などなくて
# どちらにせよ潔さが 求められることを知った
#
# "
# 黒に身を預けるほどの懐などなくて
# どちらにせよ潔さが 求められることを知った
#
# 聖が笑顔なは　僕の手か繋ぐにもいいんでもか　た
# 歌ったとさ起このもう少しだけでいいかも
# 白れた一つ　いない　いなんですか　いいんですか
# こんなに人を信じゃもいんでもか?
#
# 大した人を信じたもいんでもか
#
# -----diveristy 0.5
# ----- Seedを生成しました: "黒に身を預けるほどの懐などなくて
# どちらにせよ潔さが 求められることを知った
#
# "
# 黒に身を預けるほどの懐などなくて
# どちらにせよ潔さが 求められることを知った
#
# 聖が笑顔なは　僕の手け繋く
# けでいいかった
#
# あなっころうに今まらぬ言に　を　そんできるの
#
# 愛しみていいか
#
# 僕が笑顔なは　鳥の先の前の声の声だからば 大愛した人人を信じゃもいいんでもか?
#
# 大した
#
# -----diveristy 1.0
# ----- Seedを生成しました: "黒に身を預けるほどの懐などなくて
# どちらにせよ潔さが 求められることを知った
#
# "
# 黒に身を預けるほどの懐などなくて
# どちらにせよ潔さが 求められることを知った
#
# 聖れがした人を探したらかったホいつか?
#
# 大れたと　それをないばはあない　あなっとが
# いいんですか　いいんですか
# こんなに人を信じゃもいんでもか?
#
# 大hでいいか
#
# 大は　分から空かくのの髄と　溢して
#
# -----diveristy 1.2
# ----- Seedを生成しました: "黒に身を預けるほどの懐などなくて
# どちらにせよ潔さが 求められることを知った
#
# "
# 黒に身を預けるほどの懐などなくて
# どちらにせよ潔さが 求められることを知った
#
# 聖が笑くこのですか
# いるあな大とと言う「んだと僕らば
# 血見きんだった一聖気がるんだ向ならば
# いいんですか　いいんですか
# こんなに人そうらばもいいんですから
#
# 更分からないと 僕が受ならば
#
#
# ののやり
#
# --------------------------------------------------
# 繰り返し回数:  37
# Epoch 1/1
# 2306/2306 [==============================] - 5584s 2s/step - loss: 0.0163
#
# -----diveristy 0.2
# ----- Seedを生成しました: "のだったんだ。
#
#
# 揺れたこの想いの向かう先を
# なにも言わず僕は眺めているよ
#
# "
# のだったんだ。
#
#
# 揺れたこの想いの向かう先を
# なにも言わず僕は眺めているよ
#
# いいんですよ　あながいたんだ
# 僕が笑顔のはない　」ってみていいか
#
# いいんですよ　いいんですよ　あないな
# いいんですよ　いいんですよ　あないころううきなった
#
# いいんですよ　いいんですよ　あないけでい
#
# -----diveristy 0.5
# ----- Seedを生成しました: "のだったんだ。
#
#
# 揺れたこの想いの向かう先を
# なにも言わず僕は眺めているよ
#
# "
# のだったんだ。
#
#
# 揺れたこの想いの向かう先を
# なにも言わず僕は眺めているよ
#
# いいんですよ　いいんですよ　あないけでい富
# いいんですか　いいんですか
# こんなに人を信じゃもいいんでもか?
#
# 大れた先にも そんな顔とないこのじとど らいつい出して
#
#
# いついしてして
# 枯えの瞳と
#
#
#
# -----diveristy 1.0
# ----- Seedを生成しました: "のだったんだ。
#
#
# 揺れたこの想いの向かう先を
# なにも言わず僕は眺めているよ
#
# "
# のだったんだ。
#
#
# 揺れたこの想いの向かう先を
# なにも言わず僕は眺めているよ
#
# いく意味を探した
# するとの隙すよ 言えに
# 失らを　そんできたよ
#
# いいんですよ　あな失い預は　言う少しだけでいいかも
# いいんですか　いいんですか
# こんなに人を信じゃもいいんでもか?
#
# いいんですよ　あ
#
# -----diveristy 1.2
# ----- Seedを生成しました: "のだったんだ。
#
#
# 揺れたこの想いの向かう先を
# なにも言わず僕は眺めているよ
#
# "
# のだったんだ。
#
#
# 揺れたこの想いの向かう先を
# なにも言わず僕は眺めているよ
#
# いいんですよ　んなにでこんだ
# 君の手け後のは　知らもう少しだけでいいか
# あなった一すか　いいんですか　こんなに人を信じゃもいいんでもか?
#
# いつもは尖派聖僕らなっと他あと思が笑けは尖とと　鳥のいつく
#
# --------------------------------------------------
# 繰り返し回数:  38
# Epoch 1/1
# 2306/2306 [==============================] - 12s 5ms/step - loss: 0.0090
#
# -----diveristy 0.2
# ----- Seedを生成しました: "今日
# 眠らせて 腐らせるくらいならばと
# 青いままでヘタもとらず落ちた僕を
# 君が受"
# 今日
# 眠らせて 腐らせるくらいならばと
# 青いままでヘタもとらず落ちた僕を
# 君が受けでいこのに
# もう少しだけでいいか
#
# あなにと　君は命は」
# いいんですよ　いいんですよ　あないころうにも何にものいいか
#
# 僕らもこに向きる限りにだよう
# 失らないで そう「いいんですよ　いいんですよ　あ
#
# -----diveristy 0.5
# ----- Seedを生成しました: "今日
# 眠らせて 腐らせるくらいならばと
# 青いままでヘタもとらず落ちた僕を
# 君が受"
# 今日
# 眠らせて 腐らせるくらいならばと
# 青いままでヘタもとらず落ちた僕を
# 君が受けとないいか
#
# 大は やっその手を繋ぐっていると
#
# 聖れた一僕らばは」
# いいんですか　いいんですか
# こんなに人を信じゃもいんでもか?
#
# 大いいんですよ　あながころできて
#
# いいんですよ　いいんですよ
#
# -----diveristy 1.0
# ----- Seedを生成しました: "今日
# 眠らせて 腐らせるくらいならばと
# 青いままでヘタもとらず落ちた僕を
# 君が受"
# 今日
# 眠らせて 腐らせるくらいならばと
# 青いままでヘタもとらず落ちた僕を
# 君が受け後たと僕見つここと来じそれくれないて
#
# いつい1た 成は　たホけれるきなを 愛を見つこからば
# 聖の声り大と言は
#
# あの手の手り方からば
#
# いいんですか　いいんですか
# こんなに人を信じ
# 一いこんじと
#
#
# -----diveristy 1.2
# ----- Seedを生成しました: "今日
# 眠らせて 腐らせるくらいならばと
# 青いままでヘタもとらず落ちた僕を
# 君が受"
# 今日
# 眠らせて 腐らせるくらいならばと
# 青いままでヘタもとらず落ちた僕を
# 君が受けれとこのにもう少しだけくいつか
# こんだにらもう少しだけでいいか
#
# あなにと作ったいいんですか　いいんですか
# こんなに人を信じゃもいいんでもか?
#
# 大れを運ばば
#
# ありしとさぁ気てがいいか
#
# 僕らんな
#
# --------------------------------------------------
# 繰り返し回数:  39
# Epoch 1/1
# 2306/2306 [==============================] - 10s 4ms/step - loss: 0.0018
#
# -----diveristy 0.2
# ----- Seedを生成しました: "you and me and let's slide along side。
#
# "
# you and me and let's slide along side。
#
# い晴か　それぞれないな
#
#
# 今まで1目の声だを待て
#
# いいんですよ　いいんですよ　あないいようにいていいんですよ　いいんですよ　あながいた
# 今　想を出が分からば
# いいんですか　いいんですか
# こんなに人
#
# -----diveristy 0.5
# ----- Seedを生成しました: "you and me and let's slide along side。
#
# "
# you and me and let's slide along side。
#
# い晴か　それぞれない
#
#
# 僕らものごと　それくれるもいいんですか?
#
# 大れたとさせ
# もう少しだけくいつか
# こんなった人を信じももいんでわか?
#
# いいんですよ　あなが　あなが　いいんですよ　あながけ後に
#
# -----diveristy 1.0
# ----- Seedを生成しました: "you and me and let's slide along side。
#
# "
# you and me and let's slide along side。
#
# い晴ない出が救しだ
#
# いいんですよ　いいんですよ　いいんですよ　あなんですよ　あながころできてる
#
# いいんですよ　あながいようにい色は見い
# すからば
#
# あのこの声の気ないこのでも
# いいんですか　いいん
#
# -----diveristy 1.2
# ----- Seedを生成しました: "you and me and let's slide along side。
#
# "
# you and me and let's slide along side。
#
# 大いい想 喋ったホす今からば響いないた
#
# いいんですよ　いいんですよ　分から君は 僕は」
#
# いいんですよ　いいんですよ　あないころう」ってて笑いんですか
# こんなに人を信じゃもいいんでもか?
#
# いやか
#
#
# --------------------------------------------------
# 繰り返し回数:  40
# Epoch 1/1
# 2306/2306 [==============================] - 10s 4ms/step - loss: 0.0012
#
# -----diveristy 0.2
# ----- Seedを生成しました: " 捨てよう。
#
#
# 二人の間　通り過ぎた風は　どこから寂しさを運んできたの
# 泣いた"
#  捨てよう。
#
#
# 二人の間　通り過ぎた風は　どこから寂しさを運んできたの
# 泣いたんだ
# 手当前の声も
# どいないで 喋ない
#
# いいんですよ　いいんですよ　あながいたんだすよ
# 左らば
#
# そんな顔人を信じいもいいんでもか?
#
# 大れた一僕らば
#
# どれせた
# だけでいいも い遥は見のおからば
#
#
# -----diveristy 0.5
# ----- Seedを生成しました: " 捨てよう。
#
#
# 二人の間　通り過ぎた風は　どこから寂しさを運んできたの
# 泣いた"
#  捨てよう。
#
#
# 二人の間　通り過ぎた風は　どこから寂しさを運んできたの
# 泣いたんだ
# 手当前の声も
# どったさの手当を 響いいんでいか
#
# いいんですか　いいんですか
# こんなに人を信じゃもいいんでもか?
#
# 大したさが笑顔なすよ　　いいんですよ　あなたくけならば
# いいんですか　いいんで
#
# -----diveristy 1.0
# ----- Seedを生成しました: " 捨てよう。
#
#
# 二人の間　通り過ぎた風は　どこから寂しさを運んできたの
# 泣いた"
#  捨てよう。
#
#
# 二人の間　通り過ぎた風は　どこから寂しさを運んできたの
# 泣いたんだ人　君の命けでいこもを信じゃも
# いいんですか　いいんですか
# こんなに人を信じゃもいいんでもか?
#
# 大hで笑このすからば響いない
#
# たんな顔人を信じいもいいんでもか?
#
# いいんですよ　あながが選んだ
#
# -----diveristy 1.2
# ----- Seedを生成しました: " 捨てよう。
#
#
# 二人の間　通り過ぎた風は　どこから寂しさを運んできたの
# 泣いた"
#  捨てよう。
#
#
# 二人の間　通り過ぎた風は　どこから寂しさを運んできたの
# 泣いたんだけが　今ない　々う　いなんできてるそうんな顔僕のきる前なbと「さ人を信じ
# すいど そうならば
#
# あなっととけ当り掻やっててもうんだ人か　知は　いつはは球止をまてもう少しだけでいいかも
# 白いいんです
#
# --------------------------------------------------
# 繰り返し回数:  41
# Epoch 1/1
# 2306/2306 [==============================] - 10s 4ms/step - loss: 9.4902e-04
#
# -----diveristy 0.2
# ----- Seedを生成しました: "てる君も望んでる
# そんな声もかき消すほどに　膨れるこの万象を
#
# 「意味はないんだ"
# てる君も望んでる
# そんな声もかき消すほどに　膨れるこの万象を
#
# 「意味はないんだっないいいすか
# こんなに人を信じゃもいいんでもか?
#
# 大れた先にも そんな顔ないないい
#
# いいんですよ　いいんですよ　あながいけどいなく人を信じももいんでわか?
#
# 大からば
#
# あなっと　手当れるないそ
#
# -----diveristy 0.5
# ----- Seedを生成しました: "てる君も望んでる
# そんな声もかき消すほどに　膨れるこの万象を
#
# 「意味はないんだ"
# てる君も望んでる
# そんな声もかき消すほどに　膨れるこの万象を
#
# 「意味はないんだっないいいよ
#
# いいんですよ　あながいようにい色は
# 白知いももいいんですか　いいんですか
# こんなに人を信じゃもいんでもか
#
# いいんですよ　あなが　あなが　夏が分からば
# いいんですか　いいんですか
# こん
#
# -----diveristy 1.0
# ----- Seedを生成しました: "てる君も望んでる
# そんな声もかき消すほどに　膨れるこの万象を
#
# 「意味はないんだ"
# てる君も望んでる
# そんな声もかき消すほどに　膨れるこの万象を
#
# 「意味はないんだったころですい　あないと思愛した人を信じたもいんでもか?
#
# いまでヘ出して笑われと　白とのは」
#
# 大今まですか　いいんですか
# こんなに人を信じ
# もいんでもか?
#
# 大からぬしたH 懐しきない
#
#
#
# いい
#
# -----diveristy 1.2
# ----- Seedを生成しました: "てる君も望んでる
# そんな声もかき消すほどに　膨れるこの万象を
#
# 「意味はないんだ"
# てる君も望んでる
# そんな声もかき消すほどに　膨れるこの万象を
#
# 「意味はないんだっないいかった
#
# あなっと僕に」
# どれにも男ればきいんですか
# いきんですか　乗いんですか
# こんなに人を信じをもいんでもか
#
# いいんですよ　あなが　いない　嘘知ない　りと　　愛を探そんですか　いいんで
#
# --------------------------------------------------
# 繰り返し回数:  42
# Epoch 1/1
# 2306/2306 [==============================] - 8s 4ms/step - loss: 0.0010
#
# -----diveristy 0.2
# ----- Seedを生成しました: "欲しいんですよ
#
# いいんですか　いいんですか
# こんなに人を好きになっていいんです"
# 欲しいんですよ
#
# いいんですか　いいんですか
# こんなに人を好きになっていいんですか　いいんですか
# こんなに人を信じゃもいんでもか?
#
# 大からば
#
# あなったと　手当をなっと
#
# いいんですよ　いいんですよ　あながけ後とと言えたいと 　うのないいいで
#
# 愛した人
# いいんですよ　いいんで
#
# -----diveristy 0.5
# ----- Seedを生成しました: "欲しいんですよ
#
# いいんですか　いいんですか
# こんなに人を好きになっていいんです"
# 欲しいんですよ
#
# いいんですか　いいんですか
# こんなに人を好きになっていいんですか　いいんですか
# こんなに人を信じ
# いいんですか?
#
# 大した人を信じゃもいんでもか?
#
# 大かした
# けれくれるこんだに
# 手当をなったホいつい出した気にで
# いいんですか　いいんですか
# こんなに人を信じ
# も
#
# -----diveristy 1.0
# ----- Seedを生成しました: "欲しいんですよ
#
# いいんですか　いいんですか
# こんなに人を好きになっていいんです"
# 欲しいんですよ
#
# いいんですか　いいんですか
# こんなに人を好きになっていいんですか　いいんですか
# こんなに人を信じ
# 一いんですか　いいんですか
# こんなに人を信じたもいんでもか?
#
# いいんですよ　あなががうんだ道ならば
# いいんですか　いいんですか
# こんなに人を信じゃもいんでもか?
#
#
# -----diveristy 1.2
# ----- Seedを生成しました: "欲しいんですよ
#
# いいんですか　いいんですか
# こんなに人を好きになっていいんです"
# 欲しいんですよ
#
# いいんですか　いいんですか
# こんなに人を好きになっていいんですか　いいんですか
# こんなに人を信じゃもいんでもか?
#
# 大いいんですよ　あなががうんだ道なf　いいんですか　こんな」
# この声でもばキnた人を信じとはいいんでo
# 大からですか?
#
# いなんですよ　んなったこ
#
# --------------------------------------------------
# 繰り返し回数:  43
# Epoch 1/1
# 2306/2306 [==============================] - 7s 3ms/step - loss: 0.0079
#
# -----diveristy 0.2
# ----- Seedを生成しました: "信者は　明日の死を待つ自殺志願者に
# ３分前の僕が　また顔を出す
#
# 息を止めると心"
# 信者は　明日の死を待つ自殺志願者に
# ３分前の僕が　また顔を出す
#
# 息を止めると心を 響いんですか　いいんですか
# こんなに人を信じ
# もいんですか?
#
# いなんですよ　いいんですよ　あなっころうに来だ
# 君が笑かですか　いいんですか
# こんなに人を信じゃもいんですか?
#
# いいんですよ　あな
#
# -----diveristy 0.5
# ----- Seedを生成しました: "信者は　明日の死を待つ自殺志願者に
# ３分前の僕が　また顔を出す
#
# 息を止めると心"
# 信者は　明日の死を待つ自殺志願者に
# ３分前の僕が　また顔を出す
#
# 息を止めると心を
# 強うせた一る前の僕の 界ない　嘘どならない　嘘なななくこの信と
# 君はもう少しだけでいいかも
# あなったと
# 起この声だから 響いそんな顔 aすから
#
# いつな
#
# 愛した人　君はものい出 そう今ないこの
#
#
# -----diveristy 1.0
# ----- Seedを生成しました: "信者は　明日の死を待つ自殺志願者に
# ３分前の僕が　また顔を出す
#
# 息を止めると心"
# 信者は　明日の死を待つ自殺志願者に
# ３分前の僕が　また顔を出す
#
# 息を止めると心を 響いんですか　いいんですか
# こんなに人を信じゃもいんですか?
#
# いなんですよ　あなが　あなが　望なをない越したんだ
# 君はもの?と
# いいですか
# いいんですか　いいんですか
# こんなに人を信じももいんで
#
# -----diveristy 1.2
# ----- Seedを生成しました: "信者は　明日の死を待つ自殺志願者に
# ３分前の僕が　また顔を出す
#
# 息を止めると心"
# 信者は　明日の死を待つ自殺志願者に
# ３分前の僕が　また顔を出す
#
# 息を止めると心を 繋いそんですか
# こんなに人を信じ
# 先にももうんだ人を信じゃもいんですか?
#
# いいんですよ　あないい選んだす人　膨ないこかでもないんですか
# こんなに人を信じももいんでもか?
#
# 大したが もう男いたに
#
# --------------------------------------------------
# 繰り返し回数:  44
# Epoch 1/1
# 2306/2306 [==============================] - 9s 4ms/step - loss: 0.0031
#
# -----diveristy 0.2
# ----- Seedを生成しました: "
# I hope your coming with me today
# It's a"
#
# I hope your coming with me today
# It's ait's sano come alone alone lide anouv
# e you ene alone lide anou いんですか
# こんな顔人を信じゃもいいんでも
#
#
# いいんですよ　あなっころ
#
# -----diveristy 0.5
# ----- Seedを生成しました: "
# I hope your coming with me today
# It's a"
#
# I hope your coming with me today
# It's ait's sano come
# 白い笑もない　々が
#
# いいんですよ　いいんですよ　あなたいよう望んだ道ならば
# いいんですか　いいんですか
# こんなに人を信じゃもいんですか?
#
# いなんですよ　あなっころうう
#
# -----diveristy 1.0
# ----- Seedを生成しました: "
# I hope your coming with me today
# It's a"
#
# I hope your coming with me today
# It's aいつから 悪う確 you evme 何にも溶いなる
#
# 大どもの先にもの声だから 響う少しだけくは笑いいかは
# 僕の声のもの声だから 響いそんなに 僕が受 とないか wit's saide ban いvが
#
# -----diveristy 1.2
# ----- Seedを生成しました: "
# I hope your coming with me today
# It's a"
#
# I hope your coming with me today
# It's ait's saido et's sayou eneryou esayou
# けじゃももうホってて　てるんだよ
#
# 逃る前は泣くてみていいか
#
# いや　行くよだだ
# 手当る認ですか　僕を受けていて
# あない　世
#
# --------------------------------------------------
# 繰り返し回数:  45
# Epoch 1/1
# 2306/2306 [==============================] - 9s 4ms/step - loss: 0.0014
#
# -----diveristy 0.2
# ----- Seedを生成しました: "君は拒んだ　零れるままの涙を見てわかった
#
# 嬉しくて泣くのは　悲しくて　笑うのは"
# 君は拒んだ　零れるままの涙を見てわかった
#
# 嬉しくて泣くのは　悲しくて　笑うのは　僕の手を」
# そのものは嬉しだけでいいか
# 愛れがいいんですか　いいんですか
# こんなに人を信じゃもいんですか?
#
# 大かした
#
# 本今　もを追い越してして」ってみて　あとが　　れるの向とと誰を」
# いいんで
#
# -----diveristy 0.5
# ----- Seedを生成しました: "君は拒んだ　零れるままの涙を見てわかった
#
# 嬉しくて泣くのは　悲しくて　笑うのは"
# 君は拒んだ　零れるままの涙を見てわかった
#
# 嬉しくて泣くのは　悲しくて　笑うのは嬉しだけでいいか
# 愛れ人を信じゃもうんだ人からば
# いいんですか　いいんですか
# こんなに人を信じゃもいんでもか?
#
# 大からば
#
# 大今　想が　　知ないい　も男いいけでい富もうんだけでいいか
# いいんです
#
# -----diveristy 1.0
# ----- Seedを生成しました: "君は拒んだ　零れるままの涙を見てわかった
#
# 嬉しくて泣くのは　悲しくて　笑うのは"
# 君は拒んだ　零れるままの涙を見てわかった
#
# 嬉しくて泣くのは　悲しくて　笑うのは嬉してら待ってていいんですか?
#
# 大意味は笑してみて笑ってみてったよ
#
# 大あなっと僕見るかな出と」を歌っと君はいかですか
# いいんですか　いいんですか
# こんなに人を信じゃもいんでもな?
#
# 大いんですよ
#
# -----diveristy 1.2
# ----- Seedを生成しました: "君は拒んだ　零れるままの涙を見てわかった
#
# 嬉しくて泣くのは　悲しくて　笑うのは"
# 君は拒んだ　零れるままの涙を見てわかった
#
# 嬉しくて泣くのは　悲しくて　笑うのは嬉してら待く伝
# だ
# 顔の手の手からば
# 今まのなが　たを止めて待って
# 枯い
# 」
# ややり方が教今なんでき
# 愛を信じゃもいいんでも
# ?
#
# 大した想 僕が笑 いないそ」ないいけど　そう先にもないこの命にもう少
#
# --------------------------------------------------
# 繰り返し回数:  46
# Epoch 1/1
# 2306/2306 [==============================] - 7s 3ms/step - loss: 0.0010
#
# -----diveristy 0.2
# ----- Seedを生成しました: "そのもどかしさに抱かれぬよう　せめて僕は笑ってみせた
#
# 「何もないんだってここに"
# そのもどかしさに抱かれぬよう　せめて僕は笑ってみせた
#
# 「何もないんだってここになっていいんですか
# こんなに人を信じももいんですか?
#
# 大かした
# けれた一僕らばは」
#
# いいんですよ　いいんですよ　あなたいよう望んだ道ないば
#
# あなに 愛した人を運ば
#
# どれぞれたよ
# 声の声だからば
#
# -----diveristy 0.5
# ----- Seedを生成しました: "そのもどかしさに抱かれぬよう　せめて僕は笑ってみせた
#
# 「何もないんだってここに"
# そのもどかしさに抱かれぬよう　せめて僕は笑ってみせた
#
# 「何もないんだってここになっばいいんですか　いいんですか
# こんなに人を信じゃもいんですか?
#
# 大かした
#
# 本のいいんですよ　あながが望んだ道ななば
# いあなラと　膨う少しだけでいいか
# あな顔の手の手のクの声もの気すから乗りが
#
# -----diveristy 1.0
# ----- Seedを生成しました: "そのもどかしさに抱かれぬよう　せめて僕は笑ってみせた
#
# 「何もないんだってここに"
# そのもどかしさに抱かれぬよう　せめて僕は笑ってみせた
#
# 「何もないんだってここになっ人っていいんですか
# こんなに人を信じゃもいいんでも
# ?
#
# 大した想 泣くこにないばT
#
# いでいから
#
# 愛した人人を信じゃもいんですか
# こんなに人を信じゃもいんですか?
#
# いいんですよ　あなっが選ん
#
# -----diveristy 1.2
# ----- Seedを生成しました: "そのもどかしさに抱かれぬよう　せめて僕は笑ってみせた
#
# 「何もないんだってここに"
# そのもどかしさに抱かれぬよう　せめて僕は笑ってみせた
#
# 「何もないんだってここになっていいんですか
# こんなに人を信じともいいんでも
# 大んない僕らすよ　あながが望を人を信じいももいいんでもか?
#
# 大ないんですよ　あなっがムたんだ
# 君は命いいた思
# 大んな顔けないなクわわずとさにって俺
#
# --------------------------------------------------
# 繰り返し回数:  47
# Epoch 1/1
# 2306/2306 [==============================] - 7s 3ms/step - loss: 8.2895e-04
#
# -----diveristy 0.2
# ...
# すると灰の色の僕を眺め 綺麗と言ったんだ
# 虹の色を掻き混"
# 君に僕は見つかったんだ
# すると灰の色の僕を眺め 綺麗と言ったんだ
# 虹の色を掻き混ぜ 色は笑くては言
#
# いていゃ　してみてもうに
# 僕が笑われるようにこってってんでる
#
# あなんですか　いいんですか
# こんなに人を信じももいいんですか?
#
# 大う少しだけ　いいかは
#
# 本が笑のやよう今ない
#
# -----diveristy 1.2
# ----- Seedを生成しました: "君に僕は見つかったんだ
# すると灰の色の僕を眺め 綺麗と言ったんだ
# 虹の色を掻き混"
# 君に僕は見つかったんだ
# すると灰の色の僕を眺め 綺麗と言ったんだ
# 虹の色を掻き混ぜ 色は笑くていよ
#
#
#
# 僕の声だから 響いけど　今悪意味はた4よ　全は。
#
# いつんですか　いいんですか　いいんですか
# こんなに人を信じももいいんですか?
#
# 大終わんなるとそんだ人僕らを 歩うを見つか
#
# --------------------------------------------------
# 繰り返し回数:  105
# Epoch 1/1
# 2306/2306 [==============================] - 7s 3ms/step - loss: 8.0768e-04
#
# -----diveristy 0.2
# ----- Seedを生成しました: "いたんだよ
# 左心房に君が居るから　問題はない　ない　ないよね
#
# ２秒前までの自殺"
# いたんだよ
# 左心房に君が居るから　問題はない　ない　ないよね
#
# ２秒前までの自殺　だをた
#
# 手当をなったよ
# にもう少しだけ　いいんですか　いいんですか　いいんですか　いいんですか
# こんなに人を信じゃもいんですか?
#
# 大かした
# だ
# 投いいんですか　いいんですか
# こんなに人を信じもも
#
# -----diveristy 0.5
# ----- Seedを生成しました: "いたんだよ
# 左心房に君が居るから　問題はない　ない　ないよね
#
# ２秒前までの自殺"
# いたんだよ
# 左心房に君が居るから　問題はない　ない　ないよね
#
# ２秒前までの自殺　いつのは尖いたた　そんだ人をらば
# いいんですか　いいんですか　いいんですか　いいんですか　いいんですか　いいんですか
# こんなに人を信じももいいんですか?
#
# いいんですよ　あながが選んだ人人を信じもも
#
# -----diveristy 1.0
# ----- Seedを生成しました: "いたんだよ
# 左心房に君が居るから　問題はない　ない　ないよね
#
# ２秒前までの自殺"
# いたんだよ
# 左心房に君が居るから　問題はない　ない　ないよね
#
# ２秒前までの自殺に
# 僕にもう先にも そう今ない　いない
#
#
# う少しだけ　いいんですか　いいんですか
# こんなに人を信じももいいんですか?
#
# いいんですよ　あながが望んだすよ　　いいんですよ
#
# いどんですか　いいんですか
#
# -----diveristy 1.2
# ----- Seedを生成しました: "いたんだよ
# 左心房に君が居るから　問題はない　ない　ないよね
#
# ２秒前までの自殺"
# いたんだよ
# 左心房に君が居るから　問題はない　ない　ないよね
#
# ２秒前までの自殺から
# どれを探したよ
# ているんだよ。
#
#
# 二からぬかした
# けれた瞳のがいいかはないとかったいいんですか　いいんですか
# こんなに人を信じももいいんですか?
#
# いいんですよ　あながが選んだ人屋っていていよ
#
# --------------------------------------------------
# 繰り返し回数:  106
# Epoch 1/1
# 2306/2306 [==============================] - 8s 3ms/step - loss: 8.1036e-04
#
# -----diveristy 0.2
# ----- Seedを生成しました: "また
# 空になったその手に次の
# 未来渡されてしまうんだから
#
# やり場に困ったその未"
# また
# 空になったその手に次の
# 未来渡されてしまうんだから
#
# やり場に困ったその未来ないそんですか　いいんですか
# こんなに人を信じゃもいんですか?
#
# 大ど　夏が分かべきないいのすから
# この声もう
# この声」らかっていいんだ
# 夜
# 気が笑かのやっぱそう今から君は　ものいい　世界など　夏が
#
# -----diveristy 0.5
# ----- Seedを生成しました: "また
# 空になったその手に次の
# 未来渡されてしまうんだから
#
# やり場に困ったその未"
# また
# 空になったその手に次の
# 未来渡されてしまうんだから
#
# やり場に困ったその未来ないばいいんですか　いいんですか
# こんなに人を信じももいいんですか?
#
# いいんですよ　あながが選んだ人人を信じももいいんですか?
#
# 大ども今またんだよ。
#
#
# いつもは尖とだけでいいかは
# この声　おか
#
# -----diveristy 1.0
# ----- Seedを生成しました: "また
# 空になったその手に次の
# 未来渡されてしまうんだから
#
# やり場に困ったその未"
# また
# 空になったその手に次の
# 未来渡されてしまうんだから
#
# やり場に困ったその未来ないこのすよ　いいんですよ　あながこんですか
# こんなに人を信じゃもいんですか?
#
# 大ど　夏が分かべきないいのすから
# いいんですか　いいんですか
# こんなに人を信じももこんなに人を信じももいいんですか?
#
# -----diveristy 1.2
# ----- Seedを生成しました: "また
# 空になったその手に次の
# 未来渡されてしまうんだから
#
# やり場に困ったその未"
# また
# 空になったその手に次の
# 未来渡されてしまうんだから
#
# やり場に困ったその未来ないそんですか　いいんですか
# こんなに人を信じももいいんですか?
#
# いいんですよ　あながが選んだ人そらば
# いいんですか　いいんですか
# こんなに人を信じゃももから
#
# 聖瞳のやからば 時をだないとと
#
#
#
# --------------------------------------------------
# 繰り返し回数:  107
# Epoch 1/1
# 2306/2306 [==============================] - 10s 4ms/step - loss: 8.2482e-04
#
# -----diveristy 0.2
# ----- Seedを生成しました: "うにできてた
# そのもどかしさに抱かれぬよう　せめて僕は笑ってみせた
#
# 「何もない"
# うにできてた
# そのもどかしさに抱かれぬよう　せめて僕は笑ってみせた
#
# 「何もない　世界な　　いいですか
# こんなに人を信じゃもいんですか?
#
# 大ど　夏が分かべきないいのすから
# この声もう
# いいんですか　いいんですか
# こんなに人を信じゃもいんですか?
#
# 大ども今ないこの「ようないんで
#
# -----diveristy 0.5
# ----- Seedを生成しました: "うにできてた
# そのもどかしさに抱かれぬよう　せめて僕は笑ってみせた
#
# 「何もない"
# うにできてた
# そのもどかしさに抱かれぬよう　せめて僕は笑ってみせた
#
# 「何もない　世界な　　いいですか
# こんなに人を信じももいいんですか?
#
# いいんですよ　あながが選んだ人ジらば
# いいんですか　いいんですか　いいんですか　いいんですか　いいんですか
# こんなに人を信じゃもいんですか
#
# -----diveristy 1.0
# ----- Seedを生成しました: "うにできてた
# そのもどかしさに抱かれぬよう　せめて僕は笑ってみせた
#
# 「何もない"
# うにできてた
# そのもどかしさに抱かれぬよう　せめて僕は笑ってみせた
#
# 「何もない　いないけれいいか
#
# いいんですか　いいんですか
# こんなに人を信じももいいんですか?
#
# 大した想だ
# 君の?つか　たを賞しそう今すかここにもって
# すいんですか　いいんですか
# こんなに人を信じももいいんで
#
# -----diveristy 1.2
# ----- Seedを生成しました: "うにできてた
# そのもどかしさに抱かれぬよう　せめて僕は笑ってみせた
#
# 「何もない"
# うにできてた
# そのもどかしさに抱かれぬよう　せめて僕は笑ってみせた
#
# 「何もない　世界など　夏がでいいか やる答えになったよ
# 瞳の瞳の色す僕にも溶教
# てみて笑
# だよ。
#
#
# 今まの声けないいいは
# たらすよ　いいんですよ　いいんですよ　あな顔とだろでい?」をモいいんですか
# こんなに人
#
# --------------------------------------------------
# 繰り返し回数:  108
# Epoch 1/1
# 2306/2306 [==============================] - 8s 3ms/step - loss: 0.0013
#
# -----diveristy 0.2
# ----- Seedを生成しました: "らば
# いいんですよ　いいんですよ　あなたが望んだ道ならば
#
# あなたといる意味を探"
# らば
# いいんですよ　いいんですよ　あなたが望んだ道ならば
#
# あなたといる意味を探たらばキいたとすよ
#
# いいんですよ　いいんですよ　あながいいんですよ　あな顔く富の声」
# 今まらぬようにっこよを 悪い出していくくまで
#
# 何にも染まらぬように
# 色を掻 そう今僕らば
# いいんですか　いいん
#
# -----diveristy 0.5
# ----- Seedを生成しました: "らば
# いいんですよ　いいんですよ　あなたが望んだ道ならば
#
# あなたといる意味を探"
# らば
# いいんですよ　いいんですよ　あなたが望んだ道ならば
#
# あなたといる意味を探たら　言と OH セプテンバー
#
# 『今からば 時のをるの1探した人を信じゃももんなに人を信じゃもいんですか?
#
# 大ども分「何なて笑れれ言ように
# きたよ
# 声のおから
# いようか
# 僕の声だからばくてい　いい
#
# -----diveristy 1.0
# ----- Seedを生成しました: "らば
# いいんですよ　いいんですよ　あなたが望んだ道ならば
#
# あなたといる意味を探"
# らば
# いいんですよ　いいんですよ　あなたが望んだ道ならば
#
# あなたといる意味を探
# 白われくれたそる今またたセプテンバー
#
# 本見つかいたんだ
#
# 僕にも染まらぬように
# 色を掻ってているととをとパるとと言空に
# 僕にも染まらぬようにも染まらぬ歌ったよ　だいでいいか
# あなっになったよ
# あ
#
# -----diveristy 1.2
# ----- Seedを生成しました: "らば
# いいんですよ　いいんですよ　あなたが望んだ道ならば
#
# あなたといる意味を探"
# らば
# いいんですよ　いいんですよ　あなたが望んだ道ならば
#
# あなたといる意味を探たら　言ないとと
#
# いつこは尖た僕のすよ　いいんですよ　あながいてすかか
#
# いいんですよ　いいんですよ　あな顔く富の声だらばって笑いんだよ。
#
#
# 大いい晴できたよ
#
# いんですよ　いいんですよ　あながが
#
# --------------------------------------------------
# 繰り返し回数:  109
# Epoch 1/1
# 2306/2306 [==============================] - 7s 3ms/step - loss: 0.0040
#
# -----diveristy 0.2
# ----- Seedを生成しました: "ら　愛した人に憎まれるなら
# そうなる前に僕の方から嫌った　僕だった
#
# だけどいつ"
# ら　愛した人に憎まれるなら
# そうなる前に僕の方から嫌った　僕だった
#
# だけどいつかはいいんですか
# こんなに人を信じゃもいんですか?
#
# 大どれせた
#
# 聖が　今ない　ころないないそんだ
# ないそんな顔ないい驚はない　嘘れななくなない
#
#
# 愛んなに人を信じゃもいいんですか?
#
# 大どれでる
#
# -----diveristy 0.5
# ----- Seedを生成しました: "ら　愛した人に憎まれるなら
# そうなる前に僕の方から嫌った　僕だった
#
# だけどいつ"
# ら　愛した人に憎まれるなら
# そうなる前に僕の方から嫌った　僕だった
#
# だけどいつかはは　いつ意味は探した言　それく比る限りがとそれくれるよ
#
# いいんですか　いいんですか
# こんなに人を信じゃももいんですか?
#
# いいんですよ　あな顔が選んだ人をそんだ人を
# 君は望球はりないいんですか
#
# -----diveristy 1.0
# ----- Seedを生成しました: "ら　愛した人に憎まれるなら
# そうなる前に僕の方から嫌った　僕だった
#
# だけどいつ"
# ら　愛した人に憎まれるなら
# そうなる前に僕の方から嫌った　僕だった
#
# だけどいつかは分かしててってるもうどれぞれい出が手んだ。
#
#
# いつもは尖とだけでいい　もう少しだけでいいかは
#
# い　想の気が　いつか
# こんだ道ないこと　それくなると
# だんなっ人が笑いんですか　いいんですか
# こん
#
# -----diveristy 1.2
# ----- Seedを生成しました: "ら　愛した人に憎まれるなら
# そうなる前に僕の方から嫌った　僕だった
#
# だけどいつ"
# ら　愛した人に憎まれるなら
# そうなる前に僕の方から嫌った　僕だった
#
# だけどいつかはいいんですか　いいんですか
# こんなに人を信じものいいんですか?
#
# いいんですよ　あな顔が選んだ人すになっち他!それをれるの富よう
#
# いいんですか　いいんですか
# こんなに人を信じももいいんですか?
#
#
# --------------------------------------------------
# 繰り返し回数:  110
# Epoch 1/1
# 2306/2306 [==============================] - 7s 3ms/step - loss: 0.0043
#
# -----diveristy 0.2
# ----- Seedを生成しました: "しだけでいいからもう少しだけでいい　あと少しだけでいいもう少しだけ　くっついてい"
# しだけでいいからもう少しだけでいい　あと少しだけでいいもう少しだけ　くっついていようかか?
#
# いいんですよ　あなががキいかした
#
# だけもいいも そうなる前は
# 僕の命たと　そう今ないば
#
# あなになったよ
# 向きる前な僕らをなうに
# 僕にもっててもうんだ。
#
#
#
# 逃
#
# いいんですよ　いい
#
# -----diveristy 0.5
# ----- Seedを生成しました: "しだけでいいからもう少しだけでいい　あと少しだけでいいもう少しだけ　くっついてい"
# しだけでいいからもう少しだけでいい　あと少しだけでいいもう少しだけ　くっついていようか
#
# 僕らを繋ぐっていいんですか
# こんなに人を信じゃもいんですか?
#
# 大どれでも溶いいよう
# いいんですよ　あなしてんて
#
# いいんですか　いいんですか
# こんなに人を信じゃもいんですか?
#
# 大どれせた
#
# -----diveristy 1.0
# ----- Seedを生成しました: "しだけでいいからもう少しだけでいい　あと少しだけでいいもう少しだけ　くっついてい"
# しだけでいいからもう少しだけでいい　あと少しだけでいいもう少しだけ　くっついていようかか?
#
# 大どれぬ僕にもう少しだけでいいか
# いついた
# 僕らもう少しだけでいいかに
# いいんですか　いいんですか
# こんなに人を信じゃもいんですか?
#
# いいんですよ　あなががキいかもたいんですか　いい
#
# -----diveristy 1.2
# ----- Seedを生成しました: "しだけでいいからもう少しだけでいい　あと少しだけでいいもう少しだけ　くっついてい"
# しだけでいいからもう少しだけでいい　あと少しだけでいいもう少しだけ　くっついていようか
# 用僕にを預も
# どれせようか
#
# 何にもっこの先にも そう今なくて
#
# いいんですよ　いいんですよ　あながいいんですよ　あな顔なさせよ
# 声を見てらいまうに僕の声を 響いいいいて
#
# いいんですよ　いい
#
# --------------------------------------------------
# 繰り返し回数:  111
# Epoch 1/1
# 2306/2306 [==============================] - 7s 3ms/step - loss: 0.0014
#
# -----diveristy 0.2
# ----- Seedを生成しました: "もういい どうにでもなれ
#
# どれだけ後ろ向きに 歩いてみても未来に
# 向かってって"
# もういい どうにでもなれ
#
# どれだけ後ろ向きに 歩いてみても未来に
# 向かってってて笑うせ
#
# 本りないいとと
# 君は派のかの声　声を 繋なったホ
#
#
# いいんですか　いいんですか
# こんなに人を信じゃもいんですか?
#
# 大どれでも溶いいよ
#
# いいんですよ　いいんですよ　あなしたんだ
#
# 手当
#
# -----diveristy 0.5
# ----- Seedを生成しました: "もういい どうにでもなれ
#
# どれだけ後ろ向きに 歩いてみても未来に
# 向かってって"
# もういい どうにでもなれ
#
# どれだけ後ろ向きに 歩いてみても未来に
# 向かってっててる
#
# 本まれぬ笑顔の手る前の声を そう今ならば
#
# 大どれ一つないいか
#
# いついいですか
# この声もう少しだけでいいか
# 大が　今　もう少しだけでいいかは
# いいんですか　いいんですか　いいんですか　いい
#
# -----diveristy 1.0
# ----- Seedを生成しました: "もういい どうにでもなれ
#
# どれだけ後ろ向きに 歩いてみても未来に
# 向かってって"
# もういい どうにでもなれ
#
# どれだけ後ろ向きに 歩いてみても未来に
# 向かってっててる
#
# 本秒と　それくれるもいいんですか?
#
# いなんですよ　いいんですよ　あなががようから頑　そうなる前の僕の声だからばです
# 他んだ人らを信じゃもいいんですか?
#
# いいんですよ　あながが選んだ人人を信
#
# -----diveristy 1.2
# ----- Seedを生成しました: "もういい どうにでもなれ
#
# どれだけ後ろ向きに 歩いてみても未来に
# 向かってって"
# もういい どうにでもなれ
#
# どれだけ後ろ向きに 歩いてみても未来に
# 向かってっててる
#
# っち空にだから
# 君は派のか　その できれぞう
# ヘな?
# いても
# いいんですか　いいんですか
# こんなに人を信じももいいんですか?
#
# いなんですよ　あな顔が選んだ人人を信じゃもいんですか?
#
# いいん
#
# --------------------------------------------------
# 繰り返し回数:  112
# Epoch 1/1
# 2306/2306 [==============================] - 7s 3ms/step - loss: 8.9678e-04
#
# -----diveristy 0.2
# ----- Seedを生成しました: "こと 追い抜いてやろう
# なんて息巻いたところでまた
# 決して追い越せやしないんだ
# "
# こと 追い抜いてやろう
# なんて息巻いたところでまた
# 決して追い越せやしないんだ
# 夜
# この声とらば響いないいんですか　いいんですか　いいんですか
# こんなに人を信じゃもいんですか?
#
# いいんですよ　あながが選んだ人人を信じゃもいんですか?
#
# 大どれでもたんだよ
# 左ら澄からば連れるなっ
#
# -----diveristy 0.5
# ----- Seedを生成しました: "こと 追い抜いてやろう
# なんて息巻いたところでまた
# 決して追い越せやしないんだ
# "
# こと 追い抜いてやろう
# なんて息巻いたところでまた
# 決して追い越せやしないんだ
# 夜
# そったよさ　あなっと愛してていいんですか　いいんですか
# こんなに人を信じゃもいんですか?
#
# 大ども今ない　あなが　いないいいかはでいいんですか　いいんですか
# こんなに人を信じゃもいんですか?
#
# 大
#
# -----diveristy 1.0
# ----- Seedを生成しました: "こと 追い抜いてやろう
# なんて息巻いたところでまた
# 決して追い越せやしないんだ
# "
# こと 追い抜いてやろう
# なんて息巻いたところでまた
# 決して追い越せやしないんだ
# 夜
# そる前な。
#
#
# 今まらぬ他う　知がおかやり作っていいんですか
# こんなに人を信じゃもももう少しだけでいいか
# いいんですよ　あながが望んだ道ないいいに
# いいんですか　いいんですか
# こんなに人を信じも
#
# -----diveristy 1.2
# ----- Seedを生成しました: "こと 追い抜いてやろう
# なんて息巻いたところでまた
# 決して追い越せやしないんだ
# "
# こと 追い抜いてやろう
# なんて息巻いたところでまた
# 決して追い越せやしないんだ
# 夜
# 駄いまただよう こんな顔ない　嘘りな空に　そこの命た顔ならば
#
# あなったと　その手なれもない　あとよ　いいどもないよ々ども
# だけでいいかは
# この声をかく最比率なク　嘘受ないでいいか
#
# 愛した人に
#
# --------------------------------------------------
# 繰り返し回数:  113
# Epoch 1/1
# 2306/2306 [==============================] - 7s 3ms/step - loss: 8.4921e-04
#
# -----diveristy 0.2
# ----- Seedを生成しました: "この機会に　どのご家庭にも
# 一つは用意して頂きたい
# こりゃ買わない手はない　嘘で"
# この機会に　どのご家庭にも
# 一つは用意して頂きたい
# こりゃ買わない手はない　嘘でないない　世界など　夏が手か　特を見つか　いないいいかは
#
# 愛した人にもをていいんですか?
#
# 大ど　夏が気るのないて
#
# 愛した人を信じゃもいんですか?
#
# いいんですよ　あながが選んだ人人を信じゃもいん
#
# -----diveristy 0.5
# ----- Seedを生成しました: "この機会に　どのご家庭にも
# 一つは用意して頂きたい
# こりゃ買わない手はない　嘘で"
# この機会に　どのご家庭にも
# 一つは用意して頂きたい
# こりゃ買わない手はない　嘘でないない　世界など　夏がこの手るよ　いいんですよ　あながといいんですよ　あな顔くように
# 僕を見つ越してんだ。く
# そんだ人でいいんですか　いいんですか
# こんなに人を信じゃもいんですか?
#
# 大どもですか
#
#
# -----diveristy 1.0
# ----- Seedを生成しました: "この機会に　どのご家庭にも
# 一つは用意して頂きたい
# こりゃ買わない手はない　嘘で"
# この機会に　どのご家庭にも
# 一つは用意して頂きたい
# こりゃ買わない手はない　嘘でないない　世界など　夏がこの言くよ
# にいつな　僕が笑してからぬきたホ　歌のつここに来そって起いいんですか
# こんなに人を信じゃもいんですか?
#
# いいんですよ　あながが選んだ人人を信じゃもいんですか?
#
#
#
# -----diveristy 1.2
# ----- Seedを生成しました: "この機会に　どのご家庭にも
# 一つは用意して頂きたい
# こりゃ買わない手はない　嘘で"
# この機会に　どのご家庭にも
# 一つは用意して頂きたい
# こりゃ買わない手はない　嘘でいいない　嘘べななクならば
#
# あなになった人をくは 泣くくはかした
# 大麗い想 セプテンバー
#
# いくのは派た 次の声　らば 響いなんですか
# こんなに人を信じゃももんなう望を探した 来なんです
# よ
#
# いい
#
# --------------------------------------------------
# 繰り返し回数:  114
# Epoch 1/1
# 2306/2306 [==============================] - 7s 3ms/step - loss: 0.0081
#
# -----diveristy 0.2
# ----- Seedを生成しました: "んでくことと
# それくらいです
# 他にも何かないかと思いまして　歌を歌ってるわけです"
# んでくことと
# それくらいです
# 他にも何かないかと思いまして　歌を歌ってるわけですか
#
# 立あなったよ
# 　いいんですよ　いいんですよ　あな顔く明て
#
# いいんですよ　いいんですよ　あな顔の
#
# 愛し止いてうう
# 失なるならば いいと
#
# いいんですよ　いいんですよ　あな顔が語いんですか
# こん
#
# -----diveristy 0.5
# ----- Seedを生成しました: "んでくことと
# それくらいです
# 他にも何かないかと思いまして　歌を歌ってるわけです"
# んでくことと
# それくらいです
# 他にも何かないかと思いまして　歌を歌ってるわけですか
#
# 立あなったよ
# 　いいんですよ　いいんですよ　あな顔く明て
#
# いいんですよ　いいんですよ　あな顔の
#
# 愛し止いてうbい越してんだった
# 立んだ道ないいんですか　いいんですか
# こんなに人を信じゃもいん
#
# -----diveristy 1.0
# ----- Seedを生成しました: "んでくことと
# それくらいです
# 他にも何かないかと思いまして　歌を歌ってるわけです"
# んでくことと
# それくらいです
# 他にも何かないかと思いまして　歌を歌ってるわけですか
# こんなに人を信じゃもいんですか?
#
# 大からぬしてみて笑わのは　と言えいいいでい
# この声もう少しだけ　いいんですか　いいんですか
# こんなに人を信じゃもいんですか?
#
# いいんですよ　あな顔が選んだ人そ
#
# -----diveristy 1.2
# ----- Seedを生成しました: "んでくことと
# それくらいです
# 他にも何かないかと思いまして　歌を歌ってるわけです"
# んでくことと
# それくらいです
# 他にも何かないかと思いまして　歌を歌ってるわけですか
#
# あなっことと言知い　いないい
#
# 僕にもう少しだけでいいか
# 大んな顔 aるとないない
#
#
#
# 愛した人にもう少しだけでいいかに
# 負が笑のとと僕らいれは 頑っていいんですか
#
# 大どれないと 僕が受け
#
# --------------------------------------------------
# 繰り返し回数:  115
# Epoch 1/1
# 2306/2306 [==============================] - 7s 3ms/step - loss: 0.0077
#
# -----diveristy 0.2
# ----- Seedを生成しました: "ようなもんなんだ
#
# 後にも 先にも 行かしてはくれないんだ
# ちっちゃな箱に詰め込"
# ようなもんなんだ
#
# 後にも 先にも 行かしてはくれないんだ
# ちっちゃな箱に詰め込んな顔変ののすよ1
# 何にの声だから
# できるかな
# だが　成かないなくけ　いない　いないけれた
# 僕にもっての声だから
# どってわれるように
# だいでもいいんですよ　いいんですよ　あな顔の色は笑わてるようないま
#
# -----diveristy 0.5
# ----- Seedを生成しました: "ようなもんなんだ
#
# 後にも 先にも 行かしてはくれないんだ
# ちっちゃな箱に詰め込"
# ようなもんなんだ
#
# 後にも 先にも 行かしてはくれないんだ
# ちっちゃな箱に詰め込んな顔変ののす
# あすか
# この声もから
# 語う　いか 僕の声のおから
# どうせ
#
# いついいいですか
# こんなに人を信じゃもいんですか?
#
# いいんですよ　あな顔が選んだ人人を信じゃもいんですか?
#
# 大からぬして
#
# -----diveristy 1.0
# ----- Seedを生成しました: "ようなもんなんだ
#
# 後にも 先にも 行かしてはくれないんだ
# ちっちゃな箱に詰め込"
# ようなもんなんだ
#
# 後にも 先にも 行かしてはくれないんだ
# ちっちゃな箱に詰め込んな顔変ののすよ
#
# あなっに望をる限りだだようにまって笑いのは　 来る僕の声ッから 響いとは やor
# いき消
#
# いいですよ
#
# 大どした
# 君は派のかの声ヤク　そイ知くように
# 色は笑僕のする僕らば
#
# あ
#
# -----diveristy 1.2
# ----- Seedを生成しました: "ようなもんなんだ
#
# 後にも 先にも 行かしてはくれないんだ
# ちっちゃな箱に詰め込"
# ようなもんなんだ
#
# 後にも 先にも 行かしてはくれないんだ
# ちっちゃな箱に詰め込んな顔 a
# me lide ane llloし いない　嘘な　あなe
#
# いいんですよ　いいんですよ　あな顔が語
# 今まで動かしていんですか?
#
# いいんですよ　あなしして
# いいいいすよ
#
# 大どないけでいて
#
# --------------------------------------------------
# 繰り返し回数:  116
# Epoch 1/1
# 2306/2306 [==============================] - 7s 3ms/step - loss: 0.0014
#
# -----diveristy 0.2
# ----- Seedを生成しました: "はくれないんだ
# ちっちゃな箱に詰め込まれ 運ばれるしかないんだ
# 後にも 先にも "
# はくれないんだ
# ちっちゃな箱に詰め込まれ 運ばれるしかないんだ
# 後にも 先にも そう今なないい
#
#
# 愛愛は拒つる　だすよ
# 日
# 今までヘなった
#
# 起このもう少しだけでいいか
# 本が笑のこの手ないいも々
# たらすから
# 負が笑かのは　　おから待かして
#
# いつい　いない　いないけいない
#
#
#
# -----diveristy 0.5
# ----- Seedを生成しました: "はくれないんだ
# ちっちゃな箱に詰め込まれ 運ばれるしかないんだ
# 後にも 先にも "
# はくれないんだ
# ちっちゃな箱に詰め込まれ 運ばれるしかないんだ
# 後にも 先にも そう今なないい
#
#
# 愛愛は拒止るないいい
# う前の声「君もいいいですか
# いいんですか　いいんですか
# こんなに人を信じゃもいんですか?
#
# 大ども分かないこの運から 響いいけど
#
# いいんですよ　いいです
#
# -----diveristy 1.0
# ----- Seedを生成しました: "はくれないんだ
# ちっちゃな箱に詰め込まれ 運ばれるしかないんだ
# 後にも 先にも "
# はくれないんだ
# ちっちゃな箱に詰め込まれ 運ばれるしかないんだ
# 後にも 先にも そう今なないい
#
# 愛したいて 僕が受けで1このあとか　たい　いいんですか
# こんなに人を信じゃもいんですか?
#
# いいんですよ　あな顔が選んだ人人を信じゃもいんですか?
#
# いいんですよ　あな顔が選んだ人人
#
# -----diveristy 1.2
# ----- Seedを生成しました: "はくれないんだ
# ちっちゃな箱に詰め込まれ 運ばれるしかないんだ
# 後にも 先にも "
# はくれないんだ
# ちっちゃな箱に詰め込まれ 運ばれるしかないんだ
# 後にも 先にも そう今ない
#
# 「真少しだけでいいか
# 本　手んだと言えになったよ
# 声のおから
# どないか　先にかな
#
# 愛あなな先のすかやここんなに人を信じゃもいんですか?
#
# いんですか　この笑して猛確いんですか
# いいん
#
# --------------------------------------------------
# 繰り返し回数:  117
# Epoch 1/1
# 2306/2306 [==============================] - 7s 3ms/step - loss: 0.0025
#
# -----diveristy 0.2
# ----- Seedを生成しました: "
# 変えてくれた　そんな君はもういない　いない　いない　いないけど…
#
# この心臓に"
#
# 変えてくれた　そんな君はもういない　いない　いない　いないけど…
#
# この心臓に　それぞれいでいこかに
# 僕にもっている意味を探ら 悪いいんですか　いいんですか
#
# いいんですよ　あなこの
# いいんですよ　いいんですよ　あなたて
#
# いいんですか　いいんですか
# こんなに人を信じゃもいんで
#
# -----diveristy 0.5
# ----- Seedを生成しました: "
# 変えてくれた　そんな君はもういない　いない　いない　いないけど…
#
# この心臓に"
#
# 変えてくれた　そんな君はもういない　いない　いない　いないけど…
#
# この心臓に　その手を繋ぐてもいいんですか
#
# いいんですか　いいんですか
#
# いいんですか　いいんですか
# こんなに人を信じゃもいんですか?
#
# 大ど　夏が分か?
#
# いいんですよ　いいんですよ　あな顔の色は涙 もう少し
#
# -----diveristy 1.0
# ----- Seedを生成しました: "
# 変えてくれた　そんな君はもういない　いない　いない　いないけど…
#
# この心臓に"
#
# 変えてくれた　そんな君はもういない　いない　いない　いないけど…
#
# この心臓にも今いいか
#
# いいんですか　いいんですか
# こんなに人を信じゃもいんですか?
#
# いいんですよ　あな顔が選んだ人屋らば
# いいんですか　いいんですか
# こんなに人を信じゃもいんですか?
#
# いいんですよ　あな顔
#
# -----diveristy 1.2
# ----- Seedを生成しました: "
# 変えてくれた　そんな君はもういない　いない　いない　いないけど…
#
# この心臓に"
#
# 変えてくれた　そんな君はもういない　いない　いない　いないけど…
#
# この心臓に
# 僕にもう響い　すからいいんですか
# いいんですか　いいんですか
#
# いいんですよ　あな顔がr心が　ないい　あとか　変な意いいです
#
# いいんですよ　いいですよ
# 言えになったよ
# 声の最ですか
# この声すから
#
# --------------------------------------------------
# 繰り返し回数:  118
# Epoch 1/1
# 2306/2306 [==============================] - 8s 3ms/step - loss: 0.0026
#
# -----diveristy 0.2
# ----- Seedを生成しました: " そう君となら 何もないけれど そう今ならば
# この声ならば そう君となら 響く気"
#  そう君となら 何もないけれど そう今ならば
# この声ならば そう君となら 響く気がこんな」
# いつもは尖と　それくれですいないいんだ
# 僕にもってみていれいだから
# どってわれるように
# だだ
#
# 手当ればキいいかかた
# いいんですか　いいんですか
# こんなに人を信じゃもいんですか?
#
# いいん
#
# -----diveristy 0.5
# ----- Seedを生成しました: " そう君となら 何もないけれど そう今ならば
# この声ならば そう君となら 響く気"
#  そう君となら 何もないけれど そう今ならば
# この声ならば そう君となら 響く気がこんな」
# いつもは尖と　それくればでもこんだ
# 僕の手るないいいよ
#
# たら　その手と思いてみて起て　歌を嬉してて泣くてるそんだと僕が受けでいいか
#
# 遥　今の　この命に　歌ないいのは  時はをくついで
#
# -----diveristy 1.0
# ----- Seedを生成しました: " そう君となら 何もないけれど そう今ならば
# この声ならば そう君となら 響く気"
#  そう君となら 何もないけれど そう今ならば
# この声ならば そう君となら 響く気がいいんですか
# いつもは尖いたた　そんですた
# いいんですよ　いいんですよ　あな顔の色は涙 そんな顔後にない出が　それを待て
#
# いいんですよ　いいんですよ　あな顔の仕いいか
#
# いいんですよ　あなしがっ
#
# -----diveristy 1.2
# ----- Seedを生成しました: " そう君となら 何もないけれど そう今ならば
# この声ならば そう君となら 響く気"
#  そう君となら 何もないけれど そう今ならば
# この声ならば そう君となら 響く気がこの声もばキあとと 知がったセプテンバー
#
# 『今ま。と
#
# 遥の手け後と　いつくは　いいいいいんですか　いいんですか
# こんなに人を信じゃももから
# いつんですよ
#
# いいんですよ　あな顔の色は笑わのは　知
#
# --------------------------------------------------
# 繰り返し回数:  119
# Epoch 1/1
# 2306/2306 [==============================] - 12s 5ms/step - loss: 0.0022
#
# -----diveristy 0.2
# ----- Seedを生成しました: "れた　そんな君はもういない　いない　いない　いないけど…
#
# この心臓に君がいるん"
# れた　そんな君はもういない　いない　いない　いないけど…
#
# この心臓に君がいるんだ
#
# いつもは尖とた時の気が　たこの想とですか
# このあなくとム
#
# いいんですよ　いいんですよ　あな顔の色は笑わのは　白の手の日のばきた
#
# 今まらぬ僕が受けできるかして時くてな
#
# いいんですよ　あなしが
#
# -----diveristy 0.5
# ----- Seedを生成しました: "れた　そんな君はもういない　いない　いない　いないけど…
#
# この心臓に君がいるん"
# れた　そんな君はもういない　いない　いない　いないけど…
#
# この心臓に君がいるんだ
#
# いつもは尖とすよ　いいんですよ　あながとさぁ今なっしてしてて
# もいいんですか　いいんですか
# こんなに人を信じゃもいんですか?
# 大んですよ　いいんですよ　あな顔の髄えない夢と
# きて笑わてる限りが
#
# -----diveristy 1.0
# ----- Seedを生成しました: "れた　そんな君はもういない　いない　いない　いないけど…
#
# この心臓に君がいるん"
# れた　そんな君はもういない　いない　いない　いないけど…
#
# この心臓に君がいるんだ
#
# 本らを賞た人を信じももいいんですか?
#
# いいんですよ　あなしが選んだ人もう少しだけ　いいもは 悪りになった僕の声「かていいんですか
# いいんですか　いいんですか
# こんなに人を信じゃもいんですか?
#
# -----diveristy 1.2
# ----- Seedを生成しました: "れた　そんな君はもういない　いない　いない　いないけど…
#
# この心臓に君がいるん"
# れた　そんな君はもういない　いない　いない　いないけど…
#
# この心臓に君がいるんだ
#
# 聖らかでも見るけど
#
# いいですか　いいんですか
#
# いつい先のすよ　いどんですよ　あな顔が望を見き消してんだ
# てい　この待とも
# てるように
# だだ
# 君は派ののにのり次のじきすか
#
# いんですか　いいん
